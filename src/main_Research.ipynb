# %% [markdown]
# # Deep Fundamental Factor Models
#
# #### Author: Matthew Dixon
# #### Email: matthew.dixon@iit.edu
# #### License: MIT license
# #### Date: 10.13.2019
# #### Citation: If you use this code for your research, please cite the following paper

# %% [raw]
# @misc{dixon2019deep, title={Deep Fundamental Factor Models},
#     author={Matthew F. Dixon and Nicholas G. Polson},
#     year={2019},
#     eprint={1903.07677},
#     archivePrefix={arXiv},
#     primaryClass={stat.ML}
# }

# %% [markdown]
# ##### Description

# %% [raw]
# This notebook demonstrates the application of deep learning to fundamental factor modeling and compares the performance with OLS factor models. The outputs are monthly excess returns, the inputs are fundamental factors combined with dummy variables for industry group and sub-industry group-sectors. The Russell 1000 index data provided has already been re-scaled and the features have been anonymized, for data licensing reasons.
#
# The notebook describes the data loading, training using walk-forward optimization, performance evaluation and comparison with OLS regression, and finally strategy performance based on information ratios. The data can be downloaded from:
# https://www.dropbox.com/s/pqqz49xlqgit4h9/X_new.csv?dl=0 (factor exposures)
# https://www.dropbox.com/s/0z51jj6xfy1ndsn/Y_new.csv?dl=0 (stock excess returns)

# %%
import csv
import pickle
import pandas as pd
import numpy as np
import re
import math
import random
from keras.models import Sequential, load_model, save_model
from keras.layers import Dense, Dropout
from keras.utils import to_categorical
from keras.regularizers import l1,l2
from keras.wrappers.scikit_learn import KerasRegressor, KerasClassifier
from sklearn.model_selection import KFold, StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.preprocessing import LabelEncoder, PolynomialFeatures
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import linear_model
from keras.callbacks import EarlyStopping
import os
#from utilities import *
#from view import *
import statsmodels.api as sm
#import datetime as dt
import time
from dateutil.relativedelta import *

# comment these if running python instead of ipython
#%load_ext autoreload
# %matplotlib inline
#%autoreload 1

# %% [markdown]
# # Loading

# %% [markdown]
# ## Models Loading

# %%
models = {}
models['linear']=[]
models['NN']=[]
models['PLS_NN']=[]

# %%
betas = {}
betas['NN'] =[]
betas['linear'] =[]
betas['PLS_NN'] =[]

# %%
xs = {}
ys = {}

# %%
xs['train_PLS']=[]
xs['test_PLS']=[]
ys['train_PLS']=[]
ys['test_PLS']=[]

# %%
xs['train_linear'] = []
xs['test_linear']=[]
ys['train_linear']=[]
ys['test_linear']=[]

# %%
xs['train']=[]
xs['test']=[]
ys['train']=[]
ys['test']=[]

# %%
NN_models_folder = '../models/NN'
PLS_models_folder = '../models/PLS_NN'
vars_explained = [50, 80, 95]

# %%
def load_PLS(models, vars_explained = os.listdir(PLS_models_folder)):
    for var in vars_explained:
        models_folder = '%s/%s' % (PLS_models_folder, var)
        models_saved = os.listdir(models_folder)
        for training_periods, model_name in enumerate(models_saved):
            model_loc = '%s/%s/%s' % (PLS_models_folder, var, model_name)
            print(model_loc)
            model = load_model(model_loc)
            models['PLS_NN'].append(model)
    return models, training_periods+1

def load_NN(models):
    models_saved = os.listdir(NN_models_folder)
    for model_name in models_saved:
        model_loc = '%s/%s' % (NN_models_folder, model_name)
        print(model_loc)
        model = load_model(model_loc)
        models['NN'].append(model)
    return models

def load_all_models(models, vars_explained):
    models, training_periods = load_PLS(models, vars_explained)
    models = load_NN(models)
    return models, training_periods

# %%
models, training_periods = load_PLS(models, vars_explained)
# Out:
# ../models/PLS_NN/50/model_1989-12-01
# ../models/PLS_NN/50/model_1990-01-01
# ../models/PLS_NN/50/model_1990-02-01
# ../models/PLS_NN/50/model_1990-03-01
# ../models/PLS_NN/50/model_1990-04-01
# ../models/PLS_NN/50/model_1990-05-01
# ../models/PLS_NN/50/model_1990-06-01
# ../models/PLS_NN/50/model_1990-07-01
# ../models/PLS_NN/50/model_1990-08-01
# ../models/PLS_NN/50/model_1990-09-01
# ../models/PLS_NN/50/model_1990-10-01
# ../models/PLS_NN/50/model_1990-11-01
# ../models/PLS_NN/50/model_1990-12-01
# ../models/PLS_NN/50/model_1991-01-01
# ../models/PLS_NN/50/model_1991-02-01
# ../models/PLS_NN/50/model_1991-03-01
# ../models/PLS_NN/50/model_1991-04-01
# ../models/PLS_NN/50/model_1991-05-01
# ../models/PLS_NN/50/model_1991-06-01
# ../models/PLS_NN/50/model_1991-07-01
# ../models/PLS_NN/50/model_1991-08-01
# ../models/PLS_NN/50/model_1991-09-01
# ../models/PLS_NN/50/model_1991-10-01
# ../models/PLS_NN/50/model_1991-11-01
# ../models/PLS_NN/50/model_1991-12-01
# ../models/PLS_NN/50/model_1992-01-01
# ../models/PLS_NN/50/model_1992-02-01
# ../models/PLS_NN/50/model_1992-03-01
# ../models/PLS_NN/50/model_1992-04-01
# ../models/PLS_NN/50/model_1992-05-01
# ../models/PLS_NN/50/model_1992-06-01
# ../models/PLS_NN/50/model_1992-07-01
# ../models/PLS_NN/50/model_1992-08-01
# ../models/PLS_NN/50/model_1992-09-01
# ../models/PLS_NN/50/model_1992-10-01
# ../models/PLS_NN/50/model_1992-11-01
# ../models/PLS_NN/50/model_1992-12-01
# ../models/PLS_NN/50/model_1993-01-01
# ../models/PLS_NN/50/model_1993-02-01
# ../models/PLS_NN/50/model_1993-03-01
# ../models/PLS_NN/50/model_1993-04-01
# ../models/PLS_NN/50/model_1993-05-01
# ../models/PLS_NN/50/model_1993-06-01
# ../models/PLS_NN/50/model_1993-07-01
# ../models/PLS_NN/50/model_1993-08-01
# ../models/PLS_NN/50/model_1993-09-01
# ../models/PLS_NN/50/model_1993-10-01
# ../models/PLS_NN/50/model_1993-11-01
# ../models/PLS_NN/50/model_1993-12-01
# ../models/PLS_NN/50/model_1994-01-01
# ../models/PLS_NN/50/model_1994-02-01
# ../models/PLS_NN/50/model_1994-03-01
# ../models/PLS_NN/50/model_1994-04-01
# ../models/PLS_NN/50/model_1994-05-01
# ../models/PLS_NN/50/model_1994-06-01
# ../models/PLS_NN/50/model_1994-07-01
# ../models/PLS_NN/50/model_1994-08-01
# ../models/PLS_NN/50/model_1994-09-01
# ../models/PLS_NN/50/model_1994-10-01
# ../models/PLS_NN/50/model_1994-11-01
# ../models/PLS_NN/50/model_1994-12-01
# ../models/PLS_NN/50/model_1995-01-01
# ../models/PLS_NN/50/model_1995-02-01
# ../models/PLS_NN/50/model_1995-03-01
# ../models/PLS_NN/50/model_1995-04-01
# ../models/PLS_NN/50/model_1995-05-01
# ../models/PLS_NN/50/model_1995-06-01
# ../models/PLS_NN/50/model_1995-07-01
# ../models/PLS_NN/50/model_1995-08-01
# ../models/PLS_NN/50/model_1995-09-01
# ../models/PLS_NN/50/model_1995-10-01
# ../models/PLS_NN/50/model_1995-11-01
# ../models/PLS_NN/50/model_1995-12-01
# ../models/PLS_NN/50/model_1996-01-01
# ../models/PLS_NN/50/model_1996-02-01
# ../models/PLS_NN/50/model_1996-03-01
# ../models/PLS_NN/50/model_1996-04-01
# ../models/PLS_NN/50/model_1996-05-01
# ../models/PLS_NN/50/model_1996-06-01
# ../models/PLS_NN/50/model_1996-07-01
# ../models/PLS_NN/50/model_1996-08-01
# ../models/PLS_NN/50/model_1996-09-01
# ../models/PLS_NN/50/model_1996-10-01
# ../models/PLS_NN/50/model_1996-11-01
# ../models/PLS_NN/50/model_1996-12-01
# ../models/PLS_NN/50/model_1997-01-01
# ../models/PLS_NN/50/model_1997-02-01
# ../models/PLS_NN/50/model_1997-03-01
# ../models/PLS_NN/50/model_1997-04-01
# ../models/PLS_NN/50/model_1997-05-01
# ../models/PLS_NN/50/model_1997-06-01
# ../models/PLS_NN/50/model_1997-07-01
# ../models/PLS_NN/50/model_1997-08-01
# ../models/PLS_NN/50/model_1997-09-01
# ../models/PLS_NN/50/model_1997-10-01
# ../models/PLS_NN/50/model_1997-11-01
# ../models/PLS_NN/50/model_1997-12-01
# ../models/PLS_NN/50/model_1998-01-01
# ../models/PLS_NN/50/model_1998-02-01
# ../models/PLS_NN/50/model_1998-03-01
# ../models/PLS_NN/50/model_1998-04-01
# ../models/PLS_NN/50/model_1998-05-01
# ../models/PLS_NN/50/model_1998-06-01
# ../models/PLS_NN/50/model_1998-07-01
# ../models/PLS_NN/50/model_1998-08-01
# ../models/PLS_NN/50/model_1998-09-01
# ../models/PLS_NN/50/model_1998-10-01
# ../models/PLS_NN/50/model_1998-11-01
# ../models/PLS_NN/50/model_1998-12-01
# ../models/PLS_NN/50/model_1999-01-01
# ../models/PLS_NN/50/model_1999-02-01
# ../models/PLS_NN/50/model_1999-03-01
# ../models/PLS_NN/50/model_1999-04-01
# ../models/PLS_NN/50/model_1999-05-01
# ../models/PLS_NN/50/model_1999-06-01
# ../models/PLS_NN/50/model_1999-07-01
# ../models/PLS_NN/50/model_1999-08-01
# ../models/PLS_NN/50/model_1999-09-01
# ../models/PLS_NN/50/model_1999-10-01
# ../models/PLS_NN/50/model_1999-11-01
# ../models/PLS_NN/50/model_1999-12-01
# ../models/PLS_NN/50/model_2000-01-01
# ../models/PLS_NN/50/model_2000-02-01
# ../models/PLS_NN/50/model_2000-03-01
# ../models/PLS_NN/50/model_2000-04-01
# ../models/PLS_NN/50/model_2000-05-01
# ../models/PLS_NN/50/model_2000-06-01
# ../models/PLS_NN/50/model_2000-07-01
# ../models/PLS_NN/50/model_2000-08-01
# ../models/PLS_NN/50/model_2000-09-01
# ../models/PLS_NN/50/model_2000-10-01
# ../models/PLS_NN/50/model_2000-11-01
# ../models/PLS_NN/50/model_2000-12-01
# ../models/PLS_NN/50/model_2001-01-01
# ../models/PLS_NN/50/model_2001-02-01
# ../models/PLS_NN/50/model_2001-03-01
# ../models/PLS_NN/50/model_2001-04-01
# ../models/PLS_NN/50/model_2001-05-01
# ../models/PLS_NN/50/model_2001-06-01
# ../models/PLS_NN/50/model_2001-07-01
# ../models/PLS_NN/50/model_2001-08-01
# ../models/PLS_NN/50/model_2001-09-01
# ../models/PLS_NN/50/model_2001-10-01
# ../models/PLS_NN/50/model_2001-11-01
# ../models/PLS_NN/50/model_2001-12-01
# ../models/PLS_NN/50/model_2002-01-01
# ../models/PLS_NN/50/model_2002-02-01
# ../models/PLS_NN/50/model_2002-03-01
# ../models/PLS_NN/50/model_2002-04-01
# ../models/PLS_NN/50/model_2002-05-01
# ../models/PLS_NN/50/model_2002-06-01
# ../models/PLS_NN/50/model_2002-07-01
# ../models/PLS_NN/50/model_2002-08-01
# ../models/PLS_NN/50/model_2002-09-01
# ../models/PLS_NN/50/model_2002-10-01
# ../models/PLS_NN/50/model_2002-11-01
# ../models/PLS_NN/50/model_2002-12-01
# ../models/PLS_NN/50/model_2003-01-01
# ../models/PLS_NN/50/model_2003-02-01
# ../models/PLS_NN/50/model_2003-03-01
# ../models/PLS_NN/50/model_2003-04-01
# ../models/PLS_NN/50/model_2003-05-01
# ../models/PLS_NN/50/model_2003-06-01
# ../models/PLS_NN/50/model_2003-07-01
# ../models/PLS_NN/50/model_2003-08-01
# ../models/PLS_NN/50/model_2003-09-01
# ../models/PLS_NN/50/model_2003-10-01
# ../models/PLS_NN/50/model_2003-11-01
# ../models/PLS_NN/50/model_2003-12-01
# ../models/PLS_NN/50/model_2004-01-01
# ../models/PLS_NN/50/model_2004-02-01
# ../models/PLS_NN/50/model_2004-03-01
# ../models/PLS_NN/50/model_2004-04-01
# ../models/PLS_NN/50/model_2004-05-01
# ../models/PLS_NN/50/model_2004-06-01
# ../models/PLS_NN/50/model_2004-07-01
# ../models/PLS_NN/50/model_2004-08-01
# ../models/PLS_NN/50/model_2004-09-01
# ../models/PLS_NN/50/model_2004-10-01
# ../models/PLS_NN/50/model_2004-11-01
# ../models/PLS_NN/50/model_2004-12-01
# ../models/PLS_NN/50/model_2005-01-01
# ../models/PLS_NN/50/model_2005-02-01
# ../models/PLS_NN/50/model_2005-03-01
# ../models/PLS_NN/50/model_2005-04-01
# ../models/PLS_NN/50/model_2005-05-01
# ../models/PLS_NN/50/model_2005-06-01
# ../models/PLS_NN/50/model_2005-07-01
# ../models/PLS_NN/50/model_2005-08-01
# ../models/PLS_NN/50/model_2005-09-01
# ../models/PLS_NN/50/model_2005-10-01
# ../models/PLS_NN/50/model_2005-11-01
# ../models/PLS_NN/50/model_2005-12-01
# ../models/PLS_NN/50/model_2006-01-01
# ../models/PLS_NN/50/model_2006-02-01
# ../models/PLS_NN/50/model_2006-03-01
# ../models/PLS_NN/50/model_2006-04-01
# ../models/PLS_NN/50/model_2006-05-01
# ../models/PLS_NN/50/model_2006-06-01
# ../models/PLS_NN/50/model_2006-07-01
# ../models/PLS_NN/50/model_2006-08-01
# ../models/PLS_NN/50/model_2006-09-01
# ../models/PLS_NN/50/model_2006-10-01
# ../models/PLS_NN/50/model_2006-11-01
# ../models/PLS_NN/50/model_2006-12-01
# ../models/PLS_NN/50/model_2007-01-01
# ../models/PLS_NN/50/model_2007-02-01
# ../models/PLS_NN/50/model_2007-03-01
# ../models/PLS_NN/50/model_2007-04-01
# ../models/PLS_NN/50/model_2007-05-01
# ../models/PLS_NN/50/model_2007-06-01
# ../models/PLS_NN/50/model_2007-07-01
# ../models/PLS_NN/50/model_2007-08-01
# ../models/PLS_NN/50/model_2007-09-01
# ../models/PLS_NN/50/model_2007-10-01
# ../models/PLS_NN/50/model_2007-11-01
# ../models/PLS_NN/50/model_2007-12-01
# ../models/PLS_NN/50/model_2008-01-01
# ../models/PLS_NN/50/model_2008-02-01
# ../models/PLS_NN/50/model_2008-03-01
# ../models/PLS_NN/50/model_2008-04-01
# ../models/PLS_NN/50/model_2008-05-01
# ../models/PLS_NN/50/model_2008-06-01
# ../models/PLS_NN/50/model_2008-07-01
# ../models/PLS_NN/50/model_2008-08-01
# ../models/PLS_NN/50/model_2008-09-01
# ../models/PLS_NN/50/model_2008-10-01
# ../models/PLS_NN/50/model_2008-11-01
# ../models/PLS_NN/50/model_2008-12-01
# ../models/PLS_NN/50/model_2009-01-01
# ../models/PLS_NN/50/model_2009-02-01
# ../models/PLS_NN/50/model_2009-03-01
# ../models/PLS_NN/50/model_2009-04-01
# ../models/PLS_NN/50/model_2009-05-01
# ../models/PLS_NN/50/model_2009-06-01
# ../models/PLS_NN/50/model_2009-07-01
# ../models/PLS_NN/50/model_2009-08-01
# ../models/PLS_NN/50/model_2009-09-01
# ../models/PLS_NN/50/model_2009-10-01
# ../models/PLS_NN/50/model_2009-11-01
# ../models/PLS_NN/50/model_2009-12-01
# ../models/PLS_NN/50/model_2010-01-01
# ../models/PLS_NN/50/model_2010-02-01
# ../models/PLS_NN/50/model_2010-03-01
# ../models/PLS_NN/50/model_2010-04-01
# ../models/PLS_NN/50/model_2010-05-01
# ../models/PLS_NN/50/model_2010-06-01
# ../models/PLS_NN/50/model_2010-07-01
# ../models/PLS_NN/50/model_2010-08-01
# ../models/PLS_NN/50/model_2010-09-01
# ../models/PLS_NN/50/model_2010-10-01
# ../models/PLS_NN/50/model_2010-11-01
# ../models/PLS_NN/50/model_2010-12-01
# ../models/PLS_NN/50/model_2011-01-01
# ../models/PLS_NN/50/model_2011-02-01
# ../models/PLS_NN/50/model_2011-03-01
# ../models/PLS_NN/50/model_2011-04-01
# ../models/PLS_NN/50/model_2011-05-01
# ../models/PLS_NN/50/model_2011-06-01
# ../models/PLS_NN/50/model_2011-07-01
# ../models/PLS_NN/50/model_2011-08-01
# ../models/PLS_NN/50/model_2011-09-01
# ../models/PLS_NN/50/model_2011-10-01
# ../models/PLS_NN/50/model_2011-11-01
# ../models/PLS_NN/50/model_2011-12-01
# ../models/PLS_NN/50/model_2012-01-01
# ../models/PLS_NN/50/model_2012-02-01
# ../models/PLS_NN/50/model_2012-03-01
# ../models/PLS_NN/50/model_2012-04-01
# ../models/PLS_NN/50/model_2012-05-01
# ../models/PLS_NN/50/model_2012-06-01
# ../models/PLS_NN/50/model_2012-07-01
# ../models/PLS_NN/50/model_2012-08-01
# ../models/PLS_NN/50/model_2012-09-01
# ../models/PLS_NN/50/model_2012-10-01
# ../models/PLS_NN/50/model_2012-11-01
# ../models/PLS_NN/50/model_2012-12-01
# ../models/PLS_NN/50/model_2013-01-01
# ../models/PLS_NN/50/model_2013-02-01
# ../models/PLS_NN/50/model_2013-03-01
# ../models/PLS_NN/50/model_2013-04-01
# ../models/PLS_NN/50/model_2013-05-01
# ../models/PLS_NN/50/model_2013-06-01
# ../models/PLS_NN/50/model_2013-07-01
# ../models/PLS_NN/50/model_2013-08-01
# ../models/PLS_NN/50/model_2013-09-01
# ../models/PLS_NN/50/model_2013-10-01
# ../models/PLS_NN/50/model_2013-11-01
# ../models/PLS_NN/50/model_2013-12-01
# ../models/PLS_NN/50/model_2014-01-01
# ../models/PLS_NN/50/model_2014-02-01
# ../models/PLS_NN/50/model_2014-03-01
# ../models/PLS_NN/50/model_2014-04-01
# ../models/PLS_NN/50/model_2014-05-01
# ../models/PLS_NN/50/model_2014-06-01
# ../models/PLS_NN/50/model_2014-07-01
# ../models/PLS_NN/50/model_2014-08-01
# ../models/PLS_NN/50/model_2014-09-01
# ../models/PLS_NN/50/model_2014-10-01
# ../models/PLS_NN/50/model_2014-11-01
# ../models/PLS_NN/50/model_2014-12-01
# ../models/PLS_NN/50/model_2015-01-01
# ../models/PLS_NN/50/model_2015-02-01
# ../models/PLS_NN/50/model_2015-03-01
# ../models/PLS_NN/50/model_2015-04-01
# ../models/PLS_NN/50/model_2015-05-01
# ../models/PLS_NN/50/model_2015-06-01
# ../models/PLS_NN/50/model_2015-07-01
# ../models/PLS_NN/50/model_2015-08-01
# ../models/PLS_NN/50/model_2015-09-01
# ../models/PLS_NN/50/model_2015-10-01
# ../models/PLS_NN/50/model_2015-11-01
# ../models/PLS_NN/50/model_2015-12-01
# ../models/PLS_NN/50/model_2016-01-01
# ../models/PLS_NN/50/model_2016-02-01
# ../models/PLS_NN/50/model_2016-03-01
# ../models/PLS_NN/50/model_2016-04-01
# ../models/PLS_NN/50/model_2016-05-01
# ../models/PLS_NN/50/model_2016-06-01
# ../models/PLS_NN/50/model_2016-07-01
# ../models/PLS_NN/50/model_2016-08-01
# ../models/PLS_NN/50/model_2016-09-01
# ../models/PLS_NN/50/model_2016-10-01
# ../models/PLS_NN/50/model_2016-11-01
# ../models/PLS_NN/50/model_2016-12-01
# ../models/PLS_NN/50/model_2017-01-01
# ../models/PLS_NN/50/model_2017-02-01
# ../models/PLS_NN/50/model_2017-03-01
# ../models/PLS_NN/50/model_2017-04-01
# ../models/PLS_NN/50/model_2017-05-01
# ../models/PLS_NN/50/model_2017-06-01
# ../models/PLS_NN/50/model_2017-07-01
# ../models/PLS_NN/80/model_1989-12-01
# ../models/PLS_NN/80/model_1990-01-01
# ../models/PLS_NN/80/model_1990-02-01
# ../models/PLS_NN/80/model_1990-03-01
# ../models/PLS_NN/80/model_1990-04-01
# ../models/PLS_NN/80/model_1990-05-01
# ../models/PLS_NN/80/model_1990-06-01
# ../models/PLS_NN/80/model_1990-07-01
# ../models/PLS_NN/80/model_1990-08-01
# ../models/PLS_NN/80/model_1990-09-01
# ../models/PLS_NN/80/model_1990-10-01
# ../models/PLS_NN/80/model_1990-11-01
# ../models/PLS_NN/80/model_1990-12-01
# ../models/PLS_NN/80/model_1991-01-01
# ../models/PLS_NN/80/model_1991-02-01
# ../models/PLS_NN/80/model_1991-03-01
# ../models/PLS_NN/80/model_1991-04-01
# ../models/PLS_NN/80/model_1991-05-01
# ../models/PLS_NN/80/model_1991-06-01
# ../models/PLS_NN/80/model_1991-07-01
# ../models/PLS_NN/80/model_1991-08-01
# ../models/PLS_NN/80/model_1991-09-01
# ../models/PLS_NN/80/model_1991-10-01
# ../models/PLS_NN/80/model_1991-11-01
# ../models/PLS_NN/80/model_1991-12-01
# ../models/PLS_NN/80/model_1992-01-01
# ../models/PLS_NN/80/model_1992-02-01
# ../models/PLS_NN/80/model_1992-03-01
# ../models/PLS_NN/80/model_1992-04-01
# ../models/PLS_NN/80/model_1992-05-01
# ../models/PLS_NN/80/model_1992-06-01
# ../models/PLS_NN/80/model_1992-07-01
# ../models/PLS_NN/80/model_1992-08-01
# ../models/PLS_NN/80/model_1992-09-01
# ../models/PLS_NN/80/model_1992-10-01
# ../models/PLS_NN/80/model_1992-11-01
# ../models/PLS_NN/80/model_1992-12-01
# ../models/PLS_NN/80/model_1993-01-01
# ../models/PLS_NN/80/model_1993-02-01
# ../models/PLS_NN/80/model_1993-03-01
# ../models/PLS_NN/80/model_1993-04-01
# ../models/PLS_NN/80/model_1993-05-01
# ../models/PLS_NN/80/model_1993-06-01
# ../models/PLS_NN/80/model_1993-07-01
# ../models/PLS_NN/80/model_1993-08-01
# ../models/PLS_NN/80/model_1993-09-01
# ../models/PLS_NN/80/model_1993-10-01
# ../models/PLS_NN/80/model_1993-11-01
# ../models/PLS_NN/80/model_1993-12-01
# ../models/PLS_NN/80/model_1994-01-01
# ../models/PLS_NN/80/model_1994-02-01
# ../models/PLS_NN/80/model_1994-03-01
# ../models/PLS_NN/80/model_1994-04-01
# ../models/PLS_NN/80/model_1994-05-01
# ../models/PLS_NN/80/model_1994-06-01
# ../models/PLS_NN/80/model_1994-07-01
# ../models/PLS_NN/80/model_1994-08-01
# ../models/PLS_NN/80/model_1994-09-01
# ../models/PLS_NN/80/model_1994-10-01
# ../models/PLS_NN/80/model_1994-11-01
# ../models/PLS_NN/80/model_1994-12-01
# ../models/PLS_NN/80/model_1995-01-01
# ../models/PLS_NN/80/model_1995-02-01
# ../models/PLS_NN/80/model_1995-03-01
# ../models/PLS_NN/80/model_1995-04-01
# ../models/PLS_NN/80/model_1995-05-01
# ../models/PLS_NN/80/model_1995-06-01
# ../models/PLS_NN/80/model_1995-07-01
# ../models/PLS_NN/80/model_1995-08-01
# ../models/PLS_NN/80/model_1995-09-01
# ../models/PLS_NN/80/model_1995-10-01
# ../models/PLS_NN/80/model_1995-11-01
# ../models/PLS_NN/80/model_1995-12-01
# ../models/PLS_NN/80/model_1996-01-01
# ../models/PLS_NN/80/model_1996-02-01
# ../models/PLS_NN/80/model_1996-03-01
# ../models/PLS_NN/80/model_1996-04-01
# ../models/PLS_NN/80/model_1996-05-01
# ../models/PLS_NN/80/model_1996-06-01
# ../models/PLS_NN/80/model_1996-07-01
# ../models/PLS_NN/80/model_1996-08-01
# ../models/PLS_NN/80/model_1996-09-01
# ../models/PLS_NN/80/model_1996-10-01
# ../models/PLS_NN/80/model_1996-11-01
# ../models/PLS_NN/80/model_1996-12-01
# ../models/PLS_NN/80/model_1997-01-01
# ../models/PLS_NN/80/model_1997-02-01
# ../models/PLS_NN/80/model_1997-03-01
# ../models/PLS_NN/80/model_1997-04-01
# ../models/PLS_NN/80/model_1997-05-01
# ../models/PLS_NN/80/model_1997-06-01
# ../models/PLS_NN/80/model_1997-07-01
# ../models/PLS_NN/80/model_1997-08-01
# ../models/PLS_NN/80/model_1997-09-01
# ../models/PLS_NN/80/model_1997-10-01
# ../models/PLS_NN/80/model_1997-11-01
# ../models/PLS_NN/80/model_1997-12-01
# ../models/PLS_NN/80/model_1998-01-01
# ../models/PLS_NN/80/model_1998-02-01
# ../models/PLS_NN/80/model_1998-03-01
# ../models/PLS_NN/80/model_1998-04-01
# ../models/PLS_NN/80/model_1998-05-01
# ../models/PLS_NN/80/model_1998-06-01
# ../models/PLS_NN/80/model_1998-07-01
# ../models/PLS_NN/80/model_1998-08-01
# ../models/PLS_NN/80/model_1998-09-01
# ../models/PLS_NN/80/model_1998-10-01
# ../models/PLS_NN/80/model_1998-11-01
# ../models/PLS_NN/80/model_1998-12-01
# ../models/PLS_NN/80/model_1999-01-01
# ../models/PLS_NN/80/model_1999-02-01
# ../models/PLS_NN/80/model_1999-03-01
# ../models/PLS_NN/80/model_1999-04-01
# ../models/PLS_NN/80/model_1999-05-01
# ../models/PLS_NN/80/model_1999-06-01
# ../models/PLS_NN/80/model_1999-07-01
# ../models/PLS_NN/80/model_1999-08-01
# ../models/PLS_NN/80/model_1999-09-01
# ../models/PLS_NN/80/model_1999-10-01
# ../models/PLS_NN/80/model_1999-11-01
# ../models/PLS_NN/80/model_1999-12-01
# ../models/PLS_NN/80/model_2000-01-01
# ../models/PLS_NN/80/model_2000-02-01
# ../models/PLS_NN/80/model_2000-03-01
# ../models/PLS_NN/80/model_2000-04-01
# ../models/PLS_NN/80/model_2000-05-01
# ../models/PLS_NN/80/model_2000-06-01
# ../models/PLS_NN/80/model_2000-07-01
# ../models/PLS_NN/80/model_2000-08-01
# ../models/PLS_NN/80/model_2000-09-01
# ../models/PLS_NN/80/model_2000-10-01
# ../models/PLS_NN/80/model_2000-11-01
# ../models/PLS_NN/80/model_2000-12-01
# ../models/PLS_NN/80/model_2001-01-01
# ../models/PLS_NN/80/model_2001-02-01
# ../models/PLS_NN/80/model_2001-03-01
# ../models/PLS_NN/80/model_2001-04-01
# ../models/PLS_NN/80/model_2001-05-01
# ../models/PLS_NN/80/model_2001-06-01
# ../models/PLS_NN/80/model_2001-07-01
# ../models/PLS_NN/80/model_2001-08-01
# ../models/PLS_NN/80/model_2001-09-01
# ../models/PLS_NN/80/model_2001-10-01
# ../models/PLS_NN/80/model_2001-11-01
# ../models/PLS_NN/80/model_2001-12-01
# ../models/PLS_NN/80/model_2002-01-01
# ../models/PLS_NN/80/model_2002-02-01
# ../models/PLS_NN/80/model_2002-03-01
# ../models/PLS_NN/80/model_2002-04-01
# ../models/PLS_NN/80/model_2002-05-01
# ../models/PLS_NN/80/model_2002-06-01
# ../models/PLS_NN/80/model_2002-07-01
# ../models/PLS_NN/80/model_2002-08-01
# ../models/PLS_NN/80/model_2002-09-01
# ../models/PLS_NN/80/model_2002-10-01
# ../models/PLS_NN/80/model_2002-11-01
# ../models/PLS_NN/80/model_2002-12-01
# ../models/PLS_NN/80/model_2003-01-01
# ../models/PLS_NN/80/model_2003-02-01
# ../models/PLS_NN/80/model_2003-03-01
# ../models/PLS_NN/80/model_2003-04-01
# ../models/PLS_NN/80/model_2003-05-01
# ../models/PLS_NN/80/model_2003-06-01
# ../models/PLS_NN/80/model_2003-07-01
# ../models/PLS_NN/80/model_2003-08-01
# ../models/PLS_NN/80/model_2003-09-01
# ../models/PLS_NN/80/model_2003-10-01
# ../models/PLS_NN/80/model_2003-11-01
# ../models/PLS_NN/80/model_2003-12-01
# ../models/PLS_NN/80/model_2004-01-01
# ../models/PLS_NN/80/model_2004-02-01
# ../models/PLS_NN/80/model_2004-03-01
# ../models/PLS_NN/80/model_2004-04-01
# ../models/PLS_NN/80/model_2004-05-01
# ../models/PLS_NN/80/model_2004-06-01
# ../models/PLS_NN/80/model_2004-07-01
# ../models/PLS_NN/80/model_2004-08-01
# ../models/PLS_NN/80/model_2004-09-01
# ../models/PLS_NN/80/model_2004-10-01
# ../models/PLS_NN/80/model_2004-11-01
# ../models/PLS_NN/80/model_2004-12-01
# ../models/PLS_NN/80/model_2005-01-01
# ../models/PLS_NN/80/model_2005-02-01
# ../models/PLS_NN/80/model_2005-03-01
# ../models/PLS_NN/80/model_2005-04-01
# ../models/PLS_NN/80/model_2005-05-01
# ../models/PLS_NN/80/model_2005-06-01
# ../models/PLS_NN/80/model_2005-07-01
# ../models/PLS_NN/80/model_2005-08-01
# ../models/PLS_NN/80/model_2005-09-01
# ../models/PLS_NN/80/model_2005-10-01
# ../models/PLS_NN/80/model_2005-11-01
# ../models/PLS_NN/80/model_2005-12-01
# ../models/PLS_NN/80/model_2006-01-01
# ../models/PLS_NN/80/model_2006-02-01
# ../models/PLS_NN/80/model_2006-03-01
# ../models/PLS_NN/80/model_2006-04-01
# ../models/PLS_NN/80/model_2006-05-01
# ../models/PLS_NN/80/model_2006-06-01
# ../models/PLS_NN/80/model_2006-07-01
# ../models/PLS_NN/80/model_2006-08-01
# ../models/PLS_NN/80/model_2006-09-01
# ../models/PLS_NN/80/model_2006-10-01
# ../models/PLS_NN/80/model_2006-11-01
# ../models/PLS_NN/80/model_2006-12-01
# ../models/PLS_NN/80/model_2007-01-01
# ../models/PLS_NN/80/model_2007-02-01
# ../models/PLS_NN/80/model_2007-03-01
# ../models/PLS_NN/80/model_2007-04-01
# ../models/PLS_NN/80/model_2007-05-01
# ../models/PLS_NN/80/model_2007-06-01
# ../models/PLS_NN/80/model_2007-07-01
# ../models/PLS_NN/80/model_2007-08-01
# ../models/PLS_NN/80/model_2007-09-01
# ../models/PLS_NN/80/model_2007-10-01
# ../models/PLS_NN/80/model_2007-11-01
# ../models/PLS_NN/80/model_2007-12-01
# ../models/PLS_NN/80/model_2008-01-01
# ../models/PLS_NN/80/model_2008-02-01
# ../models/PLS_NN/80/model_2008-03-01
# ../models/PLS_NN/80/model_2008-04-01
# ../models/PLS_NN/80/model_2008-05-01
# ../models/PLS_NN/80/model_2008-06-01
# ../models/PLS_NN/80/model_2008-07-01
# ../models/PLS_NN/80/model_2008-08-01
# ../models/PLS_NN/80/model_2008-09-01
# ../models/PLS_NN/80/model_2008-10-01
# ../models/PLS_NN/80/model_2008-11-01
# ../models/PLS_NN/80/model_2008-12-01
# ../models/PLS_NN/80/model_2009-01-01
# ../models/PLS_NN/80/model_2009-02-01
# ../models/PLS_NN/80/model_2009-03-01
# ../models/PLS_NN/80/model_2009-04-01
# ../models/PLS_NN/80/model_2009-05-01
# ../models/PLS_NN/80/model_2009-06-01
# ../models/PLS_NN/80/model_2009-07-01
# ../models/PLS_NN/80/model_2009-08-01
# ../models/PLS_NN/80/model_2009-09-01
# ../models/PLS_NN/80/model_2009-10-01
# ../models/PLS_NN/80/model_2009-11-01
# ../models/PLS_NN/80/model_2009-12-01
# ../models/PLS_NN/80/model_2010-01-01
# ../models/PLS_NN/80/model_2010-02-01
# ../models/PLS_NN/80/model_2010-03-01
# ../models/PLS_NN/80/model_2010-04-01
# ../models/PLS_NN/80/model_2010-05-01
# ../models/PLS_NN/80/model_2010-06-01
# ../models/PLS_NN/80/model_2010-07-01
# ../models/PLS_NN/80/model_2010-08-01
# ../models/PLS_NN/80/model_2010-09-01
# ../models/PLS_NN/80/model_2010-10-01
# ../models/PLS_NN/80/model_2010-11-01
# ../models/PLS_NN/80/model_2010-12-01
# ../models/PLS_NN/80/model_2011-01-01
# ../models/PLS_NN/80/model_2011-02-01
# ../models/PLS_NN/80/model_2011-03-01
# ../models/PLS_NN/80/model_2011-04-01
# ../models/PLS_NN/80/model_2011-05-01
# ../models/PLS_NN/80/model_2011-06-01
# ../models/PLS_NN/80/model_2011-07-01
# ../models/PLS_NN/80/model_2011-08-01
# ../models/PLS_NN/80/model_2011-09-01
# ../models/PLS_NN/80/model_2011-10-01
# ../models/PLS_NN/80/model_2011-11-01
# ../models/PLS_NN/80/model_2011-12-01
# ../models/PLS_NN/80/model_2012-01-01
# ../models/PLS_NN/80/model_2012-02-01
# ../models/PLS_NN/80/model_2012-03-01
# ../models/PLS_NN/80/model_2012-04-01
# ../models/PLS_NN/80/model_2012-05-01
# ../models/PLS_NN/80/model_2012-06-01
# ../models/PLS_NN/80/model_2012-07-01
# ../models/PLS_NN/80/model_2012-08-01
# ../models/PLS_NN/80/model_2012-09-01
# ../models/PLS_NN/80/model_2012-10-01
# ../models/PLS_NN/80/model_2012-11-01
# ../models/PLS_NN/80/model_2012-12-01
# ../models/PLS_NN/80/model_2013-01-01
# ../models/PLS_NN/80/model_2013-02-01
# ../models/PLS_NN/80/model_2013-03-01
# ../models/PLS_NN/80/model_2013-04-01
# ../models/PLS_NN/80/model_2013-05-01
# ../models/PLS_NN/80/model_2013-06-01
# ../models/PLS_NN/80/model_2013-07-01
# ../models/PLS_NN/80/model_2013-08-01
# ../models/PLS_NN/80/model_2013-09-01
# ../models/PLS_NN/80/model_2013-10-01
# ../models/PLS_NN/80/model_2013-11-01
# ../models/PLS_NN/80/model_2013-12-01
# ../models/PLS_NN/80/model_2014-01-01
# ../models/PLS_NN/80/model_2014-02-01
# ../models/PLS_NN/80/model_2014-03-01
# ../models/PLS_NN/80/model_2014-04-01
# ../models/PLS_NN/80/model_2014-05-01
# ../models/PLS_NN/80/model_2014-06-01
# ../models/PLS_NN/80/model_2014-07-01
# ../models/PLS_NN/80/model_2014-08-01
# ../models/PLS_NN/80/model_2014-09-01
# ../models/PLS_NN/80/model_2014-10-01
# ../models/PLS_NN/80/model_2014-11-01
# ../models/PLS_NN/80/model_2014-12-01
# ../models/PLS_NN/80/model_2015-01-01
# ../models/PLS_NN/80/model_2015-02-01
# ../models/PLS_NN/80/model_2015-03-01
# ../models/PLS_NN/80/model_2015-04-01
# ../models/PLS_NN/80/model_2015-05-01
# ../models/PLS_NN/80/model_2015-06-01
# ../models/PLS_NN/80/model_2015-07-01
# ../models/PLS_NN/80/model_2015-08-01
# ../models/PLS_NN/80/model_2015-09-01
# ../models/PLS_NN/80/model_2015-10-01
# ../models/PLS_NN/80/model_2015-11-01
# ../models/PLS_NN/80/model_2015-12-01
# ../models/PLS_NN/80/model_2016-01-01
# ../models/PLS_NN/80/model_2016-02-01
# ../models/PLS_NN/80/model_2016-03-01
# ../models/PLS_NN/80/model_2016-04-01
# ../models/PLS_NN/80/model_2016-05-01
# ../models/PLS_NN/80/model_2016-06-01
# ../models/PLS_NN/80/model_2016-07-01
# ../models/PLS_NN/80/model_2016-08-01
# ../models/PLS_NN/80/model_2016-09-01
# ../models/PLS_NN/80/model_2016-10-01
# ../models/PLS_NN/80/model_2016-11-01
# ../models/PLS_NN/80/model_2016-12-01
# ../models/PLS_NN/80/model_2017-01-01
# ../models/PLS_NN/80/model_2017-02-01
# ../models/PLS_NN/80/model_2017-03-01
# ../models/PLS_NN/80/model_2017-04-01
# ../models/PLS_NN/80/model_2017-05-01
# ../models/PLS_NN/80/model_2017-06-01
# ../models/PLS_NN/80/model_2017-07-01
# ../models/PLS_NN/95/model_1989-12-01
# ../models/PLS_NN/95/model_1990-01-01
# ../models/PLS_NN/95/model_1990-02-01
# ../models/PLS_NN/95/model_1990-03-01
# ../models/PLS_NN/95/model_1990-04-01
# ../models/PLS_NN/95/model_1990-05-01
# ../models/PLS_NN/95/model_1990-06-01
# ../models/PLS_NN/95/model_1990-07-01
# ../models/PLS_NN/95/model_1990-08-01
# ../models/PLS_NN/95/model_1990-09-01
# ../models/PLS_NN/95/model_1990-10-01
# ../models/PLS_NN/95/model_1990-11-01
# ../models/PLS_NN/95/model_1990-12-01
# ../models/PLS_NN/95/model_1991-01-01
# ../models/PLS_NN/95/model_1991-02-01
# ../models/PLS_NN/95/model_1991-03-01
# ../models/PLS_NN/95/model_1991-04-01
# ../models/PLS_NN/95/model_1991-05-01
# ../models/PLS_NN/95/model_1991-06-01
# ../models/PLS_NN/95/model_1991-07-01
# ../models/PLS_NN/95/model_1991-08-01
# ../models/PLS_NN/95/model_1991-09-01
# ../models/PLS_NN/95/model_1991-10-01
# ../models/PLS_NN/95/model_1991-11-01
# ../models/PLS_NN/95/model_1991-12-01
# ../models/PLS_NN/95/model_1992-01-01
# ../models/PLS_NN/95/model_1992-02-01
# ../models/PLS_NN/95/model_1992-03-01
# ../models/PLS_NN/95/model_1992-04-01
# ../models/PLS_NN/95/model_1992-05-01
# ../models/PLS_NN/95/model_1992-06-01
# ../models/PLS_NN/95/model_1992-07-01
# ../models/PLS_NN/95/model_1992-08-01
# ../models/PLS_NN/95/model_1992-09-01
# ../models/PLS_NN/95/model_1992-10-01
# ../models/PLS_NN/95/model_1992-11-01
# ../models/PLS_NN/95/model_1992-12-01
# ../models/PLS_NN/95/model_1993-01-01
# ../models/PLS_NN/95/model_1993-02-01
# ../models/PLS_NN/95/model_1993-03-01
# ../models/PLS_NN/95/model_1993-04-01
# ../models/PLS_NN/95/model_1993-05-01
# ../models/PLS_NN/95/model_1993-06-01
# ../models/PLS_NN/95/model_1993-07-01
# ../models/PLS_NN/95/model_1993-08-01
# ../models/PLS_NN/95/model_1993-09-01
# ../models/PLS_NN/95/model_1993-10-01
# ../models/PLS_NN/95/model_1993-11-01
# ../models/PLS_NN/95/model_1993-12-01
# ../models/PLS_NN/95/model_1994-01-01
# ../models/PLS_NN/95/model_1994-02-01
# ../models/PLS_NN/95/model_1994-03-01
# ../models/PLS_NN/95/model_1994-04-01
# ../models/PLS_NN/95/model_1994-05-01
# ../models/PLS_NN/95/model_1994-06-01
# ../models/PLS_NN/95/model_1994-07-01
# ../models/PLS_NN/95/model_1994-08-01
# ../models/PLS_NN/95/model_1994-09-01
# ../models/PLS_NN/95/model_1994-10-01
# ../models/PLS_NN/95/model_1994-11-01
# ../models/PLS_NN/95/model_1994-12-01
# ../models/PLS_NN/95/model_1995-01-01
# ../models/PLS_NN/95/model_1995-02-01
# ../models/PLS_NN/95/model_1995-03-01
# ../models/PLS_NN/95/model_1995-04-01
# ../models/PLS_NN/95/model_1995-05-01
# ../models/PLS_NN/95/model_1995-06-01
# ../models/PLS_NN/95/model_1995-07-01
# ../models/PLS_NN/95/model_1995-08-01
# ../models/PLS_NN/95/model_1995-09-01
# ../models/PLS_NN/95/model_1995-10-01
# ../models/PLS_NN/95/model_1995-11-01
# ../models/PLS_NN/95/model_1995-12-01
# ../models/PLS_NN/95/model_1996-01-01
# ../models/PLS_NN/95/model_1996-02-01
# ../models/PLS_NN/95/model_1996-03-01
# ../models/PLS_NN/95/model_1996-04-01
# ../models/PLS_NN/95/model_1996-05-01
# ../models/PLS_NN/95/model_1996-06-01
# ../models/PLS_NN/95/model_1996-07-01
# ../models/PLS_NN/95/model_1996-08-01
# ../models/PLS_NN/95/model_1996-09-01
# ../models/PLS_NN/95/model_1996-10-01
# ../models/PLS_NN/95/model_1996-11-01
# ../models/PLS_NN/95/model_1996-12-01
# ../models/PLS_NN/95/model_1997-01-01
# ../models/PLS_NN/95/model_1997-02-01
# ../models/PLS_NN/95/model_1997-03-01
# ../models/PLS_NN/95/model_1997-04-01
# ../models/PLS_NN/95/model_1997-05-01
# ../models/PLS_NN/95/model_1997-06-01
# ../models/PLS_NN/95/model_1997-07-01
# ../models/PLS_NN/95/model_1997-08-01
# ../models/PLS_NN/95/model_1997-09-01
# ../models/PLS_NN/95/model_1997-10-01
# ../models/PLS_NN/95/model_1997-11-01
# ../models/PLS_NN/95/model_1997-12-01
# ../models/PLS_NN/95/model_1998-01-01
# ../models/PLS_NN/95/model_1998-02-01
# ../models/PLS_NN/95/model_1998-03-01
# ../models/PLS_NN/95/model_1998-04-01
# ../models/PLS_NN/95/model_1998-05-01
# ../models/PLS_NN/95/model_1998-06-01
# ../models/PLS_NN/95/model_1998-07-01
# ../models/PLS_NN/95/model_1998-08-01
# ../models/PLS_NN/95/model_1998-09-01
# ../models/PLS_NN/95/model_1998-10-01
# ../models/PLS_NN/95/model_1998-11-01
# ../models/PLS_NN/95/model_1998-12-01
# ../models/PLS_NN/95/model_1999-01-01
# ../models/PLS_NN/95/model_1999-02-01
# ../models/PLS_NN/95/model_1999-03-01
# ../models/PLS_NN/95/model_1999-04-01
# ../models/PLS_NN/95/model_1999-05-01
# ../models/PLS_NN/95/model_1999-06-01
# ../models/PLS_NN/95/model_1999-07-01
# ../models/PLS_NN/95/model_1999-08-01
# ../models/PLS_NN/95/model_1999-09-01
# ../models/PLS_NN/95/model_1999-10-01
# ../models/PLS_NN/95/model_1999-11-01
# ../models/PLS_NN/95/model_1999-12-01
# ../models/PLS_NN/95/model_2000-01-01
# ../models/PLS_NN/95/model_2000-02-01
# ../models/PLS_NN/95/model_2000-03-01
# ../models/PLS_NN/95/model_2000-04-01
# ../models/PLS_NN/95/model_2000-05-01
# ../models/PLS_NN/95/model_2000-06-01
# ../models/PLS_NN/95/model_2000-07-01
# ../models/PLS_NN/95/model_2000-08-01
# ../models/PLS_NN/95/model_2000-09-01
# ../models/PLS_NN/95/model_2000-10-01
# ../models/PLS_NN/95/model_2000-11-01
# ../models/PLS_NN/95/model_2000-12-01
# ../models/PLS_NN/95/model_2001-01-01
# ../models/PLS_NN/95/model_2001-02-01
# ../models/PLS_NN/95/model_2001-03-01
# ../models/PLS_NN/95/model_2001-04-01
# ../models/PLS_NN/95/model_2001-05-01
# ../models/PLS_NN/95/model_2001-06-01
# ../models/PLS_NN/95/model_2001-07-01
# ../models/PLS_NN/95/model_2001-08-01
# ../models/PLS_NN/95/model_2001-09-01
# ../models/PLS_NN/95/model_2001-10-01
# ../models/PLS_NN/95/model_2001-11-01
# ../models/PLS_NN/95/model_2001-12-01
# ../models/PLS_NN/95/model_2002-01-01
# ../models/PLS_NN/95/model_2002-02-01
# ../models/PLS_NN/95/model_2002-03-01
# ../models/PLS_NN/95/model_2002-04-01
# ../models/PLS_NN/95/model_2002-05-01
# ../models/PLS_NN/95/model_2002-06-01
# ../models/PLS_NN/95/model_2002-07-01
# ../models/PLS_NN/95/model_2002-08-01
# ../models/PLS_NN/95/model_2002-09-01
# ../models/PLS_NN/95/model_2002-10-01
# ../models/PLS_NN/95/model_2002-11-01
# ../models/PLS_NN/95/model_2002-12-01
# ../models/PLS_NN/95/model_2003-01-01
# ../models/PLS_NN/95/model_2003-02-01
# ../models/PLS_NN/95/model_2003-03-01
# ../models/PLS_NN/95/model_2003-04-01
# ../models/PLS_NN/95/model_2003-05-01
# ../models/PLS_NN/95/model_2003-06-01
# ../models/PLS_NN/95/model_2003-07-01
# ../models/PLS_NN/95/model_2003-08-01
# ../models/PLS_NN/95/model_2003-09-01
# ../models/PLS_NN/95/model_2003-10-01
# ../models/PLS_NN/95/model_2003-11-01
# ../models/PLS_NN/95/model_2003-12-01
# ../models/PLS_NN/95/model_2004-01-01
# ../models/PLS_NN/95/model_2004-02-01
# ../models/PLS_NN/95/model_2004-03-01
# ../models/PLS_NN/95/model_2004-04-01
# ../models/PLS_NN/95/model_2004-05-01
# ../models/PLS_NN/95/model_2004-06-01
# ../models/PLS_NN/95/model_2004-07-01
# ../models/PLS_NN/95/model_2004-08-01
# ../models/PLS_NN/95/model_2004-09-01
# ../models/PLS_NN/95/model_2004-10-01
# ../models/PLS_NN/95/model_2004-11-01
# ../models/PLS_NN/95/model_2004-12-01
# ../models/PLS_NN/95/model_2005-01-01
# ../models/PLS_NN/95/model_2005-02-01
# ../models/PLS_NN/95/model_2005-03-01
# ../models/PLS_NN/95/model_2005-04-01
# ../models/PLS_NN/95/model_2005-05-01
# ../models/PLS_NN/95/model_2005-06-01
# ../models/PLS_NN/95/model_2005-07-01
# ../models/PLS_NN/95/model_2005-08-01
# ../models/PLS_NN/95/model_2005-09-01
# ../models/PLS_NN/95/model_2005-10-01
# ../models/PLS_NN/95/model_2005-11-01
# ../models/PLS_NN/95/model_2005-12-01
# ../models/PLS_NN/95/model_2006-01-01
# ../models/PLS_NN/95/model_2006-02-01
# ../models/PLS_NN/95/model_2006-03-01
# ../models/PLS_NN/95/model_2006-04-01
# ../models/PLS_NN/95/model_2006-05-01
# ../models/PLS_NN/95/model_2006-06-01
# ../models/PLS_NN/95/model_2006-07-01
# ../models/PLS_NN/95/model_2006-08-01
# ../models/PLS_NN/95/model_2006-09-01
# ../models/PLS_NN/95/model_2006-10-01
# ../models/PLS_NN/95/model_2006-11-01
# ../models/PLS_NN/95/model_2006-12-01
# ../models/PLS_NN/95/model_2007-01-01
# ../models/PLS_NN/95/model_2007-02-01
# ../models/PLS_NN/95/model_2007-03-01
# ../models/PLS_NN/95/model_2007-04-01
# ../models/PLS_NN/95/model_2007-05-01
# ../models/PLS_NN/95/model_2007-06-01
# ../models/PLS_NN/95/model_2007-07-01
# ../models/PLS_NN/95/model_2007-08-01
# ../models/PLS_NN/95/model_2007-09-01
# ../models/PLS_NN/95/model_2007-10-01
# ../models/PLS_NN/95/model_2007-11-01
# ../models/PLS_NN/95/model_2007-12-01
# ../models/PLS_NN/95/model_2008-01-01
# ../models/PLS_NN/95/model_2008-02-01
# ../models/PLS_NN/95/model_2008-03-01
# ../models/PLS_NN/95/model_2008-04-01
# ../models/PLS_NN/95/model_2008-05-01
# ../models/PLS_NN/95/model_2008-06-01
# ../models/PLS_NN/95/model_2008-07-01
# ../models/PLS_NN/95/model_2008-08-01
# ../models/PLS_NN/95/model_2008-09-01
# ../models/PLS_NN/95/model_2008-10-01
# ../models/PLS_NN/95/model_2008-11-01
# ../models/PLS_NN/95/model_2008-12-01
# ../models/PLS_NN/95/model_2009-01-01
# ../models/PLS_NN/95/model_2009-02-01
# ../models/PLS_NN/95/model_2009-03-01
# ../models/PLS_NN/95/model_2009-04-01
# ../models/PLS_NN/95/model_2009-05-01
# ../models/PLS_NN/95/model_2009-06-01
# ../models/PLS_NN/95/model_2009-07-01
# ../models/PLS_NN/95/model_2009-08-01
# ../models/PLS_NN/95/model_2009-09-01
# ../models/PLS_NN/95/model_2009-10-01
# ../models/PLS_NN/95/model_2009-11-01
# ../models/PLS_NN/95/model_2009-12-01
# ../models/PLS_NN/95/model_2010-01-01
# ../models/PLS_NN/95/model_2010-02-01
# ../models/PLS_NN/95/model_2010-03-01
# ../models/PLS_NN/95/model_2010-04-01
# ../models/PLS_NN/95/model_2010-05-01
# ../models/PLS_NN/95/model_2010-06-01
# ../models/PLS_NN/95/model_2010-07-01
# ../models/PLS_NN/95/model_2010-08-01
# ../models/PLS_NN/95/model_2010-09-01
# ../models/PLS_NN/95/model_2010-10-01
# ../models/PLS_NN/95/model_2010-11-01
# ../models/PLS_NN/95/model_2010-12-01
# ../models/PLS_NN/95/model_2011-01-01
# ../models/PLS_NN/95/model_2011-02-01
# ../models/PLS_NN/95/model_2011-03-01
# ../models/PLS_NN/95/model_2011-04-01
# ../models/PLS_NN/95/model_2011-05-01
# ../models/PLS_NN/95/model_2011-06-01
# ../models/PLS_NN/95/model_2011-07-01
# ../models/PLS_NN/95/model_2011-08-01
# ../models/PLS_NN/95/model_2011-09-01
# ../models/PLS_NN/95/model_2011-10-01
# ../models/PLS_NN/95/model_2011-11-01
# ../models/PLS_NN/95/model_2011-12-01
# ../models/PLS_NN/95/model_2012-01-01
# ../models/PLS_NN/95/model_2012-02-01
# ../models/PLS_NN/95/model_2012-03-01
# ../models/PLS_NN/95/model_2012-04-01
# ../models/PLS_NN/95/model_2012-05-01
# ../models/PLS_NN/95/model_2012-06-01
# ../models/PLS_NN/95/model_2012-07-01
# ../models/PLS_NN/95/model_2012-08-01
# ../models/PLS_NN/95/model_2012-09-01
# ../models/PLS_NN/95/model_2012-10-01
# ../models/PLS_NN/95/model_2012-11-01
# ../models/PLS_NN/95/model_2012-12-01
# ../models/PLS_NN/95/model_2013-01-01
# ../models/PLS_NN/95/model_2013-02-01
# ../models/PLS_NN/95/model_2013-03-01
# ../models/PLS_NN/95/model_2013-04-01
# ../models/PLS_NN/95/model_2013-05-01
# ../models/PLS_NN/95/model_2013-06-01
# ../models/PLS_NN/95/model_2013-07-01
# ../models/PLS_NN/95/model_2013-08-01
# ../models/PLS_NN/95/model_2013-09-01
# ../models/PLS_NN/95/model_2013-10-01
# ../models/PLS_NN/95/model_2013-11-01
# ../models/PLS_NN/95/model_2013-12-01
# ../models/PLS_NN/95/model_2014-01-01
# ../models/PLS_NN/95/model_2014-02-01
# ../models/PLS_NN/95/model_2014-03-01
# ../models/PLS_NN/95/model_2014-04-01
# ../models/PLS_NN/95/model_2014-05-01
# ../models/PLS_NN/95/model_2014-06-01
# ../models/PLS_NN/95/model_2014-07-01
# ../models/PLS_NN/95/model_2014-08-01
# ../models/PLS_NN/95/model_2014-09-01
# ../models/PLS_NN/95/model_2014-10-01
# ../models/PLS_NN/95/model_2014-11-01
# ../models/PLS_NN/95/model_2014-12-01
# ../models/PLS_NN/95/model_2015-01-01
# ../models/PLS_NN/95/model_2015-02-01
# ../models/PLS_NN/95/model_2015-03-01
# ../models/PLS_NN/95/model_2015-04-01
# ../models/PLS_NN/95/model_2015-05-01
# ../models/PLS_NN/95/model_2015-06-01
# ../models/PLS_NN/95/model_2015-07-01
# ../models/PLS_NN/95/model_2015-08-01
# ../models/PLS_NN/95/model_2015-09-01
# ../models/PLS_NN/95/model_2015-10-01
# ../models/PLS_NN/95/model_2015-11-01
# ../models/PLS_NN/95/model_2015-12-01
# ../models/PLS_NN/95/model_2016-01-01
# ../models/PLS_NN/95/model_2016-02-01
# ../models/PLS_NN/95/model_2016-03-01
# ../models/PLS_NN/95/model_2016-04-01
# ../models/PLS_NN/95/model_2016-05-01
# ../models/PLS_NN/95/model_2016-06-01
# ../models/PLS_NN/95/model_2016-07-01
# ../models/PLS_NN/95/model_2016-08-01
# ../models/PLS_NN/95/model_2016-09-01
# ../models/PLS_NN/95/model_2016-10-01
# ../models/PLS_NN/95/model_2016-11-01
# ../models/PLS_NN/95/model_2016-12-01
# ../models/PLS_NN/95/model_2017-01-01
# ../models/PLS_NN/95/model_2017-02-01
# ../models/PLS_NN/95/model_2017-03-01
# ../models/PLS_NN/95/model_2017-04-01
# ../models/PLS_NN/95/model_2017-05-01
# ../models/PLS_NN/95/model_2017-06-01
# ../models/PLS_NN/95/model_2017-07-01

# %%
models = load_NN(models)
# Out:
# ../models/NN/model_1989-12-01
# ../models/NN/model_1990-01-01
# ../models/NN/model_1990-02-01
# ../models/NN/model_1990-03-01
# ../models/NN/model_1990-04-01
# ../models/NN/model_1990-05-01
# ../models/NN/model_1990-06-01
# ../models/NN/model_1990-07-01
# ../models/NN/model_1990-08-01
# ../models/NN/model_1990-09-01
# ../models/NN/model_1990-10-01
# ../models/NN/model_1990-11-01
# ../models/NN/model_1990-12-01
# ../models/NN/model_1991-01-01
# ../models/NN/model_1991-02-01
# ../models/NN/model_1991-03-01
# ../models/NN/model_1991-04-01
# ../models/NN/model_1991-05-01
# ../models/NN/model_1991-06-01
# ../models/NN/model_1991-07-01
# ../models/NN/model_1991-08-01
# ../models/NN/model_1991-09-01
# ../models/NN/model_1991-10-01
# ../models/NN/model_1991-11-01
# ../models/NN/model_1991-12-01
# ../models/NN/model_1992-01-01
# ../models/NN/model_1992-02-01
# ../models/NN/model_1992-03-01
# ../models/NN/model_1992-04-01
# ../models/NN/model_1992-05-01
# ../models/NN/model_1992-06-01
# ../models/NN/model_1992-07-01
# ../models/NN/model_1992-08-01
# ../models/NN/model_1992-09-01
# ../models/NN/model_1992-10-01
# ../models/NN/model_1992-11-01
# ../models/NN/model_1992-12-01
# ../models/NN/model_1993-01-01
# ../models/NN/model_1993-02-01
# ../models/NN/model_1993-03-01
# ../models/NN/model_1993-04-01
# ../models/NN/model_1993-05-01
# ../models/NN/model_1993-06-01
# ../models/NN/model_1993-07-01
# ../models/NN/model_1993-08-01
# ../models/NN/model_1993-09-01
# ../models/NN/model_1993-10-01
# ../models/NN/model_1993-11-01
# ../models/NN/model_1993-12-01
# ../models/NN/model_1994-01-01
# ../models/NN/model_1994-02-01
# ../models/NN/model_1994-03-01
# ../models/NN/model_1994-04-01
# ../models/NN/model_1994-05-01
# ../models/NN/model_1994-06-01
# ../models/NN/model_1994-07-01
# ../models/NN/model_1994-08-01
# ../models/NN/model_1994-09-01
# ../models/NN/model_1994-10-01
# ../models/NN/model_1994-11-01
# ../models/NN/model_1994-12-01
# ../models/NN/model_1995-01-01
# ../models/NN/model_1995-02-01
# ../models/NN/model_1995-03-01
# ../models/NN/model_1995-04-01
# ../models/NN/model_1995-05-01
# ../models/NN/model_1995-06-01
# ../models/NN/model_1995-07-01
# ../models/NN/model_1995-08-01
# ../models/NN/model_1995-09-01
# ../models/NN/model_1995-10-01
# ../models/NN/model_1995-11-01
# ../models/NN/model_1995-12-01
# ../models/NN/model_1996-01-01
# ../models/NN/model_1996-02-01
# ../models/NN/model_1996-03-01
# ../models/NN/model_1996-04-01
# ../models/NN/model_1996-05-01
# ../models/NN/model_1996-06-01
# ../models/NN/model_1996-07-01
# ../models/NN/model_1996-08-01
# ../models/NN/model_1996-09-01
# ../models/NN/model_1996-10-01
# ../models/NN/model_1996-11-01
# ../models/NN/model_1996-12-01
# ../models/NN/model_1997-01-01
# ../models/NN/model_1997-02-01
# ../models/NN/model_1997-03-01
# ../models/NN/model_1997-04-01
# ../models/NN/model_1997-05-01
# ../models/NN/model_1997-06-01
# ../models/NN/model_1997-07-01
# ../models/NN/model_1997-08-01
# ../models/NN/model_1997-09-01
# ../models/NN/model_1997-10-01
# ../models/NN/model_1997-11-01
# ../models/NN/model_1997-12-01
# ../models/NN/model_1998-01-01
# ../models/NN/model_1998-02-01
# ../models/NN/model_1998-03-01
# ../models/NN/model_1998-04-01
# ../models/NN/model_1998-05-01
# ../models/NN/model_1998-06-01
# ../models/NN/model_1998-07-01
# ../models/NN/model_1998-08-01
# ../models/NN/model_1998-09-01
# ../models/NN/model_1998-10-01
# ../models/NN/model_1998-11-01
# ../models/NN/model_1998-12-01
# ../models/NN/model_1999-01-01
# ../models/NN/model_1999-02-01
# ../models/NN/model_1999-03-01
# ../models/NN/model_1999-04-01
# ../models/NN/model_1999-05-01
# ../models/NN/model_1999-06-01
# ../models/NN/model_1999-07-01
# ../models/NN/model_1999-08-01
# ../models/NN/model_1999-09-01
# ../models/NN/model_1999-10-01
# ../models/NN/model_1999-11-01
# ../models/NN/model_1999-12-01
# ../models/NN/model_2000-01-01
# ../models/NN/model_2000-02-01
# ../models/NN/model_2000-03-01
# ../models/NN/model_2000-04-01
# ../models/NN/model_2000-05-01
# ../models/NN/model_2000-06-01
# ../models/NN/model_2000-07-01
# ../models/NN/model_2000-08-01
# ../models/NN/model_2000-09-01
# ../models/NN/model_2000-10-01
# ../models/NN/model_2000-11-01
# ../models/NN/model_2000-12-01
# ../models/NN/model_2001-01-01
# ../models/NN/model_2001-02-01
# ../models/NN/model_2001-03-01
# ../models/NN/model_2001-04-01
# ../models/NN/model_2001-05-01
# ../models/NN/model_2001-06-01
# ../models/NN/model_2001-07-01
# ../models/NN/model_2001-08-01
# ../models/NN/model_2001-09-01
# ../models/NN/model_2001-10-01
# ../models/NN/model_2001-11-01
# ../models/NN/model_2001-12-01
# ../models/NN/model_2002-01-01
# ../models/NN/model_2002-02-01
# ../models/NN/model_2002-03-01
# ../models/NN/model_2002-04-01
# ../models/NN/model_2002-05-01
# ../models/NN/model_2002-06-01
# ../models/NN/model_2002-07-01
# ../models/NN/model_2002-08-01
# ../models/NN/model_2002-09-01
# ../models/NN/model_2002-10-01
# ../models/NN/model_2002-11-01
# ../models/NN/model_2002-12-01
# ../models/NN/model_2003-01-01
# ../models/NN/model_2003-02-01
# ../models/NN/model_2003-03-01
# ../models/NN/model_2003-04-01
# ../models/NN/model_2003-05-01
# ../models/NN/model_2003-06-01
# ../models/NN/model_2003-07-01
# ../models/NN/model_2003-08-01
# ../models/NN/model_2003-09-01
# ../models/NN/model_2003-10-01
# ../models/NN/model_2003-11-01
# ../models/NN/model_2003-12-01
# ../models/NN/model_2004-01-01
# ../models/NN/model_2004-02-01
# ../models/NN/model_2004-03-01
# ../models/NN/model_2004-04-01
# ../models/NN/model_2004-05-01
# ../models/NN/model_2004-06-01
# ../models/NN/model_2004-07-01
# ../models/NN/model_2004-08-01
# ../models/NN/model_2004-09-01
# ../models/NN/model_2004-10-01
# ../models/NN/model_2004-11-01
# ../models/NN/model_2004-12-01
# ../models/NN/model_2005-01-01
# ../models/NN/model_2005-02-01
# ../models/NN/model_2005-03-01
# ../models/NN/model_2005-04-01
# ../models/NN/model_2005-05-01
# ../models/NN/model_2005-06-01
# ../models/NN/model_2005-07-01
# ../models/NN/model_2005-08-01
# ../models/NN/model_2005-09-01
# ../models/NN/model_2005-10-01
# ../models/NN/model_2005-11-01
# ../models/NN/model_2005-12-01
# ../models/NN/model_2006-01-01
# ../models/NN/model_2006-02-01
# ../models/NN/model_2006-03-01
# ../models/NN/model_2006-04-01
# ../models/NN/model_2006-05-01
# ../models/NN/model_2006-06-01
# ../models/NN/model_2006-07-01
# ../models/NN/model_2006-08-01
# ../models/NN/model_2006-09-01
# ../models/NN/model_2006-10-01
# ../models/NN/model_2006-11-01
# ../models/NN/model_2006-12-01
# ../models/NN/model_2007-01-01
# ../models/NN/model_2007-02-01
# ../models/NN/model_2007-03-01
# ../models/NN/model_2007-04-01
# ../models/NN/model_2007-05-01
# ../models/NN/model_2007-06-01
# ../models/NN/model_2007-07-01
# ../models/NN/model_2007-08-01
# ../models/NN/model_2007-09-01
# ../models/NN/model_2007-10-01
# ../models/NN/model_2007-11-01
# ../models/NN/model_2007-12-01
# ../models/NN/model_2008-01-01
# ../models/NN/model_2008-02-01
# ../models/NN/model_2008-03-01
# ../models/NN/model_2008-04-01
# ../models/NN/model_2008-05-01
# ../models/NN/model_2008-06-01
# ../models/NN/model_2008-07-01
# ../models/NN/model_2008-08-01
# ../models/NN/model_2008-09-01
# ../models/NN/model_2008-10-01
# ../models/NN/model_2008-11-01
# ../models/NN/model_2008-12-01
# ../models/NN/model_2009-01-01
# ../models/NN/model_2009-02-01
# ../models/NN/model_2009-03-01
# ../models/NN/model_2009-04-01
# ../models/NN/model_2009-05-01
# ../models/NN/model_2009-06-01
# ../models/NN/model_2009-07-01
# ../models/NN/model_2009-08-01
# ../models/NN/model_2009-09-01
# ../models/NN/model_2009-10-01
# ../models/NN/model_2009-11-01
# ../models/NN/model_2009-12-01
# ../models/NN/model_2010-01-01
# ../models/NN/model_2010-02-01
# ../models/NN/model_2010-03-01
# ../models/NN/model_2010-04-01
# ../models/NN/model_2010-05-01
# ../models/NN/model_2010-06-01
# ../models/NN/model_2010-07-01
# ../models/NN/model_2010-08-01
# ../models/NN/model_2010-09-01
# ../models/NN/model_2010-10-01
# ../models/NN/model_2010-11-01
# ../models/NN/model_2010-12-01
# ../models/NN/model_2011-01-01
# ../models/NN/model_2011-02-01
# ../models/NN/model_2011-03-01
# ../models/NN/model_2011-04-01
# ../models/NN/model_2011-05-01
# ../models/NN/model_2011-06-01
# ../models/NN/model_2011-07-01
# ../models/NN/model_2011-08-01
# ../models/NN/model_2011-09-01
# ../models/NN/model_2011-10-01
# ../models/NN/model_2011-11-01
# ../models/NN/model_2011-12-01
# ../models/NN/model_2012-01-01
# ../models/NN/model_2012-02-01
# ../models/NN/model_2012-03-01
# ../models/NN/model_2012-04-01
# ../models/NN/model_2012-05-01
# ../models/NN/model_2012-06-01
# ../models/NN/model_2012-07-01
# ../models/NN/model_2012-08-01
# ../models/NN/model_2012-09-01
# ../models/NN/model_2012-10-01
# ../models/NN/model_2012-11-01
# ../models/NN/model_2012-12-01
# ../models/NN/model_2013-01-01
# ../models/NN/model_2013-02-01
# ../models/NN/model_2013-03-01
# ../models/NN/model_2013-04-01
# ../models/NN/model_2013-05-01
# ../models/NN/model_2013-06-01
# ../models/NN/model_2013-07-01
# ../models/NN/model_2013-08-01
# ../models/NN/model_2013-09-01
# ../models/NN/model_2013-10-01
# ../models/NN/model_2013-11-01
# ../models/NN/model_2013-12-01
# ../models/NN/model_2014-01-01
# ../models/NN/model_2014-02-01
# ../models/NN/model_2014-03-01
# ../models/NN/model_2014-04-01
# ../models/NN/model_2014-05-01
# ../models/NN/model_2014-06-01
# ../models/NN/model_2014-07-01
# ../models/NN/model_2014-08-01
# ../models/NN/model_2014-09-01
# ../models/NN/model_2014-10-01
# ../models/NN/model_2014-11-01
# ../models/NN/model_2014-12-01
# ../models/NN/model_2015-01-01
# ../models/NN/model_2015-02-01
# ../models/NN/model_2015-03-01
# ../models/NN/model_2015-04-01
# ../models/NN/model_2015-05-01
# ../models/NN/model_2015-06-01
# ../models/NN/model_2015-07-01
# ../models/NN/model_2015-08-01
# ../models/NN/model_2015-09-01
# ../models/NN/model_2015-10-01
# ../models/NN/model_2015-11-01
# ../models/NN/model_2015-12-01
# ../models/NN/model_2016-01-01
# ../models/NN/model_2016-02-01
# ../models/NN/model_2016-03-01
# ../models/NN/model_2016-04-01
# ../models/NN/model_2016-05-01
# ../models/NN/model_2016-06-01
# ../models/NN/model_2016-07-01
# ../models/NN/model_2016-08-01
# ../models/NN/model_2016-09-01
# ../models/NN/model_2016-10-01
# ../models/NN/model_2016-11-01
# ../models/NN/model_2016-12-01
# ../models/NN/model_2017-01-01
# ../models/NN/model_2017-02-01
# ../models/NN/model_2017-03-01
# ../models/NN/model_2017-04-01
# ../models/NN/model_2017-05-01
# ../models/NN/model_2017-06-01
# ../models/NN/model_2017-07-01

# %% [markdown]
# ## Datasets Loading

# %%
def load_datasets_PLS(training_periods, vars_explained = os.listdir(PLS_models_folder)):
    
    for var in vars_explained: 
        print(var)
        x_trains_folder = "%s/%i/x_train" % (PLS_data_folder, var)
        y_trains_folder = "%s/%i/y_train" % (PLS_data_folder, var)
        x_tests_folder = "%s/%i/x_test" % (PLS_data_folder, var)
        y_tests_folder = "%s/%i/y_test" % (PLS_data_folder, var)

        x_trains_files = os.listdir(x_trains_folder)
        y_trains_files = os.listdir(y_trains_folder)
        x_tests_files = os.listdir(x_tests_folder)
        y_tests_files = os.listdir(y_tests_folder)
        
        for i in range( training_periods ):
            x_train_file = "%s/%s" % (x_trains_folder, x_trains_files[i])
            y_train_file = "%s/%s" % (y_trains_folder, y_trains_files[i])
            x_test_file = "%s/%s" % (x_tests_folder, x_tests_files[i])
            y_test_file = "%s/%s" % (y_tests_folder, y_tests_files[i])

            x_train = pd.read_csv(x_train_file)
            y_train = pd.read_csv(y_train_file)
            x_test = pd.read_csv(x_test_file)
            y_test = pd.read_csv(y_test_file)

            x_train.drop(columns='Unnamed: 0', inplace=True)
            y_train.drop(columns='Unnamed: 0', inplace=True)
            x_test.drop(columns='Unnamed: 0', inplace=True)
            y_test.drop(columns='Unnamed: 0', inplace=True)
            
            n_inputs = x_train.shape[1]
            if n_inputs ==0:
                next
            
            xs['train_PLS'].append(x_train)
            ys['train_PLS'].append(y_train)
            xs['test_PLS'].append(x_test)
            ys['test_PLS'].append(y_test)
    
    return

# %%
def load_dataset_NN(X, Y, training_dates):
    
    for date in training_dates:
        #start_time = timeit.default_timer()  
        train_index = Y[Y['date']==date].index

        if len(train_index)==0:
            next

        date_next=pd.Timestamp(np.datetime64(date)).to_pydatetime() + relativedelta(months=+1)
        date_next = date_next.strftime('%Y-%m-%d')
        test_index  = Y[Y['date']==date_next].index
        
        if len(test_index)==0:
            next

        x_train = X.loc[train_index]
        x_train=x_train.drop("date", axis=1)
        y_train = Y.loc[train_index]
        y_train= y_train.drop("date", axis=1)
        x_test  = X.loc[test_index]
        x_test=x_test.drop("date", axis=1)
        y_test =  Y.loc[test_index]
        y_test=y_test.drop("date", axis=1)

        n_inputs = x_train.shape[1]
        if n_inputs ==0:
            next            

        xs['train'].append(x_train)
        xs['test'].append(x_test)
        ys['train'].append(y_train)
        ys['test'].append(y_test)
            
    return

# %%
print(ys['test'])
# Out:
# [      xs_return
# 976   -0.157558
# 977    0.050256
# 978   -0.014424
# 979   -0.043486
# 980    0.019946
# ...         ...
# 1941   0.033861
# 1942   0.181684
# 1943   0.192743
# 1944  -0.041043
# 1945  -0.156577
#
# [945 rows x 1 columns],       xs_return
# 1947  -0.074912
# 1948   0.345704
# 1949   0.144951
# 1950  -0.240155
# 1951  -0.131292
# ...         ...
# 2916  -0.015293
# 2917  -0.051648
# 2918  -0.199777
# 2919   0.080769
# 2920  -0.059249
#
# [947 rows x 1 columns],       xs_return
# 2921   0.096076
# 2922   0.205841
# 2923   0.067402
# 2924  -0.019490
# 2925  -0.089756
# ...         ...
# 3885   0.049919
# 3886  -0.130796
# 3887  -0.128335
# 3888  -0.051583
# 3889  -0.318678
#
# [946 rows x 1 columns],       xs_return
# 3890   0.001278
# 3891  -0.064058
# 3892   0.123117
# 3893  -0.188325
# 3894   0.092776
# ...         ...
# 4855   0.070254
# 4856  -0.032192
# 4857   0.023870
# 4858  -0.151788
# 4859   0.104951
#
# [947 rows x 1 columns],       xs_return
# 4860  -0.201126
# 4861   0.022738
# 4862  -0.280591
# 4863   0.437094
# 4864   0.214574
# ...         ...
# 5823  -0.070136
# 5824   0.086033
# 5825   0.091646
# 5826  -0.018534
# 5828  -0.271926
#
# [946 rows x 1 columns],       xs_return
# 5829  -0.135725
# 5830   0.095100
# 5831  -0.191923
# 5832   0.003601
# 5833  -0.278328
# ...         ...
# 6819   0.202389
# 6820   0.044396
# 6821   0.100054
# 6822   0.073682
# 6823   0.170733
#
# [974 rows x 1 columns],       xs_return
# 6824  -0.282890
# 6825  -0.173572
# 6826   0.222201
# 6827  -0.322937
# 6828   0.068541
# ...         ...
# 7813  -0.324862
# 7814  -0.151809
# 7815   0.037685
# 7816   0.075929
# 7817  -0.079144
#
# [972 rows x 1 columns],       xs_return
# 7818   0.028795
# 7819   0.205711
# 7820   0.108170
# 7821  -0.090219
# 7822   0.006756
# ...         ...
# 8801  -0.099453
# 8802  -0.306129
# 8803  -0.035931
# 8804  -0.070239
# 8805  -0.135039
#
# [967 rows x 1 columns],       xs_return
# 8806   0.210095
# 8807  -0.135233
# 8808   0.232562
# 8809   0.299054
# 8810  -0.094564
# ...         ...
# 9788   0.395956
# 9789  -0.005228
# 9790   0.260068
# 9791   0.189519
# 9792   0.208302
#
# [964 rows x 1 columns],        xs_return
# 9793   -0.076555
# 9794    0.199486
# 9795    0.072728
# 9796    0.053883
# 9797    0.019756
# ...          ...
# 10776   0.270604
# 10777  -0.081502
# 10778   0.092909
# 10779  -0.054484
# 10780   0.009461
#
# [966 rows x 1 columns],        xs_return
# 10781  -0.067716
# 10782   0.140800
# 10783   0.196810
# 10784   0.160478
# 10785  -0.132698
# ...          ...
# 11763   0.405696
# 11764   0.109084
# 11765  -0.008413
# 11766   0.010672
# 11767  -0.099930
#
# [969 rows x 1 columns],        xs_return
# 11768   0.652782
# 11769  -0.083362
# 11770  -0.188998
# 11771   0.051269
# 11772  -0.117788
# ...          ...
# 12749  -0.040353
# 12750  -0.194089
# 12751   0.004069
# 12752  -0.052457
# 12753   0.116892
#
# [966 rows x 1 columns],        xs_return
# 12754   0.081521
# 12755   0.023642
# 12756  -0.080511
# 12757  -0.010116
# 12758   0.155753
# ...          ...
# 13735  -0.098461
# 13737   0.589288
# 13738   0.142036
# 13739  -0.057817
# 13740  -0.082285
#
# [965 rows x 1 columns],        xs_return
# 13741   0.022875
# 13742  -0.053694
# 13743  -0.062595
# 13744  -0.035485
# 13745   0.027202
# ...          ...
# 14723  -0.208717
# 14724  -0.086872
# 14725   0.073119
# 14726   0.081325
# 14727   0.043283
#
# [965 rows x 1 columns],        xs_return
# 14728  -0.195762
# 14729  -0.104409
# 14730  -0.025126
# 14731  -0.062401
# 14732  -0.000939
# ...          ...
# 15708   0.044420
# 15710   0.014626
# 15711   0.059827
# 15712   0.005419
# 15713  -0.118759
#
# [961 rows x 1 columns],        xs_return
# 15714  -0.059473
# 15715   0.004255
# 15716   0.085201
# 15717   0.223437
# 15718   0.074246
# ...          ...
# 16696   0.034644
# 16697  -0.061396
# 16698   0.280531
# 16699   0.063256
# 16700  -0.009605
#
# [963 rows x 1 columns],        xs_return
# 16701  -0.022144
# 16702  -0.021019
# 16703   0.018456
# 16704   0.239060
# 16705   0.040747
# ...          ...
# 17683   0.315819
# 17684   0.047164
# 17685   0.027622
# 17686   0.027609
# 17687   0.054567
#
# [964 rows x 1 columns],        xs_return
# 17688   0.075653
# 17689   0.073041
# 17690   0.107381
# 17691   0.058398
# 17692   0.046506
# ...          ...
# 18677  -0.031218
# 18678  -0.030804
# 18679   0.059485
# 18680  -0.071382
# 18681   0.007706
#
# [973 rows x 1 columns],        xs_return
# 18682   0.018564
# 18683  -0.218013
# 18684  -0.155012
# 18685   0.018625
# 18686   0.289980
# ...          ...
# 19668  -0.154840
# 19669   0.169300
# 19670   0.130311
# 19671  -0.141611
# 19672   0.053422
#
# [973 rows x 1 columns],        xs_return
# 19673  -0.146697
# 19674  -0.091126
# 19675  -0.210121
# 19676  -0.204656
# 19677  -0.035013
# ...          ...
# 20661  -0.054862
# 20662   0.274493
# 20663   0.015320
# 20664  -0.007468
# 20665  -0.175478
#
# [975 rows x 1 columns],        xs_return
# 20666  -0.090372
# 20667  -0.068197
# 20668  -0.145743
# 20669   0.193479
# 20670  -0.139047
# ...          ...
# 21653  -0.072826
# 21654  -0.142074
# 21655   0.178754
# 21656   0.219965
# 21657  -0.106126
#
# [971 rows x 1 columns],        xs_return
# 21658   0.089692
# 21659   0.025275
# 21660   0.442711
# 21661   0.039898
# 21662  -0.015801
# ...          ...
# 22646   0.094132
# 22647  -0.102720
# 22648   0.047808
# 22649  -0.051646
# 22650   0.044571
#
# [972 rows x 1 columns],        xs_return
# 22651   0.143027
# 22652   0.288356
# 22653   0.013150
# 22654   0.070415
# 22655   0.019808
# ...          ...
# 23637   0.036502
# 23639  -0.045316
# 23640   0.304110
# 23641   0.008530
# 23642  -0.118258
#
# [970 rows x 1 columns],        xs_return
# 23643  -0.319274
# 23644   0.209614
# 23645   0.434117
# 23646   0.167035
# 23647   0.110699
# ...          ...
# 24626  -0.143868
# 24627   0.015031
# 24628   0.056570
# 24629  -0.183375
# 24630  -0.108906
#
# [966 rows x 1 columns],        xs_return
# 24631  -0.012235
# 24632  -0.089748
# 24633  -0.295494
# 24634  -0.027469
# 24635  -0.096435
# ...          ...
# 25612   0.047543
# 25613   0.045233
# 25614  -0.008922
# 25615   0.028717
# 25616   0.086008
#
# [965 rows x 1 columns],        xs_return
# 25617   0.057668
# 25618  -0.171413
# 25619  -0.068627
# 25620  -0.332555
# 25621   0.116229
# ...          ...
# 26597   0.204432
# 26598   0.018938
# 26599   0.146964
# 26600   0.100157
# 26601   0.052334
#
# [965 rows x 1 columns],        xs_return
# 26602  -0.162988
# 26604  -0.072554
# 26605  -0.484293
# 26606  -0.219597
# 26607   0.146631
# ...          ...
# 27581  -0.192362
# 27582   0.292746
# 27583   0.077644
# 27584  -0.094256
# 27585   0.125915
#
# [961 rows x 1 columns],        xs_return
# 27586   0.070405
# 27587   0.005999
# 27588   0.051553
# 27589  -0.161038
# 27590   0.071455
# ...          ...
# 28563   0.003668
# 28564  -0.190122
# 28565   0.053569
# 28566   0.016456
# 28567  -0.116039
#
# [960 rows x 1 columns],        xs_return
# 28568  -0.076283
# 28569  -0.179400
# 28570   0.037125
# 28571   0.097378
# 28572  -0.142754
# ...          ...
# 29545  -0.043800
# 29546   0.264350
# 29547   0.012738
# 29548  -0.583286
# 29549  -0.066933
#
# [960 rows x 1 columns],        xs_return
# 29550  -0.177482
# 29551   0.053508
# 29552   0.035019
# 29553   0.015115
# 29554  -0.168298
# ...          ...
# 30539   0.075305
# 30540  -0.007693
# 30541   0.085161
# 30542   0.213443
# 30543  -0.001097
#
# [971 rows x 1 columns],        xs_return
# 30544   0.088774
# 30545  -0.048644
# 30546   0.092057
# 30547   0.856382
# 30548   0.167330
# ...          ...
# 31537   0.009418
# 31538   0.003319
# 31539   0.119986
# 31540  -0.224265
# 31541  -0.116782
#
# [976 rows x 1 columns],        xs_return
# 31542   0.001908
# 31543   0.161733
# 31544  -0.060377
# 31545   0.110580
# 31546   0.103138
# ...          ...
# 32536  -0.126274
# 32537  -0.130514
# 32538   0.216498
# 32539  -0.430212
# 32540  -0.143843
#
# [977 rows x 1 columns],        xs_return
# 32541   0.015241
# 32542   0.085051
# 32544   0.118348
# 32545  -0.108861
# 32546  -0.085793
# ...          ...
# 33535   0.194352
# 33536  -0.062940
# 33537  -0.239394
# 33538  -0.010167
# 33539  -0.079916
#
# [977 rows x 1 columns],        xs_return
# 33540   0.069615
# 33542   2.651346
# 33543  -0.066766
# 33544   0.048765
# 33545  -0.039720
# ...          ...
# 34532   0.033250
# 34533  -0.049659
# 34534   0.040056
# 34535   0.159589
# 34536   0.084257
#
# [976 rows x 1 columns],        xs_return
# 34537  -0.104884
# 34538   0.072170
# 34539  -0.227567
# 34540   0.027585
# 34541  -0.061395
# ...          ...
# 35529  -0.166923
# 35530   0.007717
# 35531   0.047313
# 35532   0.065156
# 35533  -0.051520
#
# [976 rows x 1 columns],        xs_return
# 35534   0.014624
# 35535  -0.016138
# 35536   0.005064
# 35537   0.010862
# 35538  -0.065064
# ...          ...
# 36526   0.112166
# 36528   0.094211
# 36529  -0.055271
# 36530  -0.047346
# 36531  -0.036247
#
# [975 rows x 1 columns],        xs_return
# 36532   0.199561
# 36534   0.115508
# 36535   0.186669
# 36536   0.095169
# 36537   0.167083
# ...          ...
# 37524   0.021345
# 37525  -0.077436
# 37526   0.007942
# 37527   0.142564
# 37528   0.070436
#
# [974 rows x 1 columns],        xs_return
# 37529   0.029258
# 37530   0.022660
# 37532   0.066619
# 37533  -0.026596
# 37534  -0.000524
# ...          ...
# 38520   0.109551
# 38521  -0.158223
# 38522  -0.143632
# 38524  -0.204413
# 38525   0.006579
#
# [974 rows x 1 columns],        xs_return
# 38526  -0.090443
# 38527   0.013478
# 38528   0.001816
# 38529  -0.030318
# 38530  -0.126279
# ...          ...
# 39516  -0.320591
# 39517   0.080668
# 39518  -0.045755
# 39519   0.118361
# 39520  -0.062880
#
# [974 rows x 1 columns],        xs_return
# 39521  -0.104513
# 39522   0.002161
# 39523   0.030317
# 39524  -0.013324
# 39525  -0.292207
# ...          ...
# 40512  -0.073054
# 40513  -0.109380
# 40514   0.220588
# 40515   0.147156
# 40516   0.041463
#
# [975 rows x 1 columns],        xs_return
# 40517   0.096660
# 40518   0.756020
# 40519  -0.005880
# 40520  -0.092075
# 40521  -0.021356
# ...          ...
# 41508  -0.134733
# 41509  -0.038605
# 41510   0.104155
# 41511  -0.034052
# 41512  -0.290243
#
# [975 rows x 1 columns],        xs_return
# 41513  -0.010613
# 41514  -0.157015
# 41515   0.161500
# 41516   0.091937
# 41517   0.072752
# ...          ...
# 42499  -0.031988
# 42500  -0.046941
# 42501   0.006023
# 42502   0.041318
# 42503  -0.157779
#
# [968 rows x 1 columns],        xs_return
# 42504  -0.147241
# 42505  -0.061174
# 42506  -0.216818
# 42507   0.064671
# 42508   0.227364
# ...          ...
# 43493   0.113091
# 43494  -0.011470
# 43495  -0.148105
# 43496   0.070986
# 43497   0.109592
#
# [971 rows x 1 columns],        xs_return
# 43498   0.165590
# 43499   0.219599
# 43500  -0.098528
# 43501  -0.118146
# 43502  -0.132866
# ...          ...
# 44484   0.125547
# 44485  -0.333442
# 44486   0.095645
# 44487   0.278227
# 44488  -0.041026
#
# [969 rows x 1 columns],        xs_return
# 44491   0.093940
# 44492  -0.014511
# 44493  -0.071365
# 44494  -0.141999
# 44495  -0.069869
# ...          ...
# 45478  -0.083260
# 45479  -0.170975
# 45480   0.133576
# 45481   0.050685
# 45482  -0.155943
#
# [966 rows x 1 columns],        xs_return
# 45484   0.125393
# 45485  -0.058502
# 45486  -0.020587
# 45488   0.055836
# 45489   0.182680
# ...          ...
# 46469   0.115259
# 46470   0.117766
# 46471   0.235208
# 46472  -0.035416
# 46473   0.083178
#
# [966 rows x 1 columns],        xs_return
# 46474  -0.040868
# 46475  -0.018755
# 46476   0.087090
# 46477  -0.034213
# 46478  -0.084249
# ...          ...
# 47457  -0.078571
# 47458   0.148512
# 47459  -0.072941
# 47460   0.054609
# 47461  -0.107369
#
# [965 rows x 1 columns],        xs_return
# 47462  -0.084318
# 47463  -0.075740
# 47464  -0.060310
# 47465  -0.024106
# 47466  -0.034801
# ...          ...
# 48447  -0.011650
# 48448   0.104594
# 48449   0.047891
# 48450   0.107209
# 48451  -0.155786
#
# [968 rows x 1 columns],        xs_return
# 48452   0.190151
# 48453   0.017796
# 48454   0.087584
# 48455  -0.077941
# 48456  -0.132610
# ...          ...
# 49437  -0.090050
# 49438  -0.015751
# 49439  -0.103787
# 49440   0.033613
# 49441  -0.150208
#
# [970 rows x 1 columns],        xs_return
# 49443  -0.093807
# 49444   0.068609
# 49445  -0.007852
# 49446   0.057129
# 49447  -0.020008
# ...          ...
# 50428  -0.106833
# 50429   0.045199
# 50430   0.121305
# 50431   0.139253
# 50432   0.270560
#
# [968 rows x 1 columns],        xs_return
# 50433  -0.075566
# 50434  -0.013071
# 50435  -0.017429
# 50436   0.030628
# 50437  -0.057992
# ...          ...
# 51420   0.091861
# 51421   0.034600
# 51422  -0.101764
# 51423   0.135500
# 51424  -0.118404
#
# [972 rows x 1 columns],        xs_return
# 51425   0.038919
# 51426  -0.121248
# 51427   0.101769
# 51428  -0.028759
# 51429   0.349431
# ...          ...
# 52412   0.130034
# 52413   0.063940
# 52414  -0.061890
# 52415   0.073069
# 52416  -0.067271
#
# [972 rows x 1 columns],        xs_return
# 52417   0.013702
# 52418  -0.027858
# 52419  -0.113764
# 52420  -0.084315
# 52421   0.111701
# ...          ...
# 53407   0.129938
# 53408   0.060340
# 53409  -0.013762
# 53410   0.037469
# 53411  -0.095705
#
# [975 rows x 1 columns],        xs_return
# 53412   0.415525
# 53413   0.095716
# 53414  -0.095617
# 53415  -0.024386
# 53416   0.014114
# ...          ...
# 54401  -0.049778
# 54402  -0.044390
# 54403   0.005399
# 54404   0.035024
# 54405   0.022603
#
# [971 rows x 1 columns],        xs_return
# 54406   0.072276
# 54407  -0.072807
# 54408  -0.129208
# 54409   0.034159
# 54410  -0.022982
# ...          ...
# 55394   0.024934
# 55395   0.033831
# 55396  -0.041747
# 55397  -0.127299
# 55398   0.017689
#
# [971 rows x 1 columns],        xs_return
# 55399   0.096703
# 55400   0.039033
# 55401   0.011878
# 55402  -0.077346
# 55403   0.142743
# ...          ...
# 56379  -0.034909
# 56380  -0.007572
# 56381   0.107266
# 56382  -0.052116
# 56383  -0.046117
#
# [968 rows x 1 columns],        xs_return
# 56385  -0.011555
# 56386   0.055330
# 56387  -0.028349
# 56388  -0.190478
# 56389  -0.084488
# ...          ...
# 57362   0.018456
# 57363  -0.203920
# 57364   0.076937
# 57365   0.001935
# 57366  -0.060038
#
# [964 rows x 1 columns],        xs_return
# 57369   0.017468
# 57370   0.044507
# 57371  -0.077252
# 57372   0.002350
# 57373   0.060222
# ...          ...
# 58346   0.017872
# 58347   0.042627
# 58348  -0.219547
# 58349  -0.130953
# 58350  -0.046991
#
# [962 rows x 1 columns],        xs_return
# 58351  -0.200637
# 58352  -0.089927
# 58353   0.113259
# 58355  -0.117482
# 58356  -0.029675
# ...          ...
# 59325   0.017464
# 59326  -0.020199
# 59327  -0.074580
# 59328  -0.080992
# 59329   0.220458
#
# [959 rows x 1 columns],        xs_return
# 59330  -0.107949
# 59331   0.042064
# 59333  -0.289868
# 59334  -0.024932
# 59335  -0.086849
# ...          ...
# 60306   0.314087
# 60307  -0.064039
# 60308   0.009314
# 60309  -0.085210
# 60310  -0.088163
#
# [961 rows x 1 columns],        xs_return
# 60311  -0.004172
# 60312  -0.049039
# 60313   0.009484
# 60315  -0.021054
# 60316   0.019302
# ...          ...
# 61281  -0.021015
# 61282  -0.040589
# 61283  -0.105463
# 61284  -0.134352
# 61285   0.006465
#
# [959 rows x 1 columns],        xs_return
# 61288  -0.396612
# 61289  -0.074454
# 61290   0.050820
# 61291  -0.013669
# 61292  -0.010281
# ...          ...
# 62258  -0.072167
# 62259   0.143808
# 62260  -0.069890
# 62261   0.068691
# 62262   0.238770
#
# [958 rows x 1 columns],        xs_return
# 62263   0.007575
# 62264  -0.049368
# 62265  -0.095416
# 62266  -0.050878
# 62267   0.146972
# ...          ...
# 63230  -0.042820
# 63231  -0.091982
# 63232  -0.091625
# 63233   0.037916
# 63234   0.111079
#
# [954 rows x 1 columns],        xs_return
# 63235  -0.026533
# 63236   0.311070
# 63238  -0.028337
# 63239  -0.090572
# 63240   0.008704
# ...          ...
# 64197  -0.127155
# 64198  -0.347856
# 64199  -0.101656
# 64200  -0.082128
# 64201  -0.143533
#
# [951 rows x 1 columns],        xs_return
# 64202  -0.133331
# 64203   0.050270
# 64204   0.007619
# 64205  -0.051181
# 64206   0.022187
# ...          ...
# 65161   0.009324
# 65162  -0.068281
# 65163  -0.053344
# 65164  -0.099847
# 65165   0.117155
#
# [951 rows x 1 columns],        xs_return
# 65166  -0.101467
# 65167  -0.069733
# 65168   0.073384
# 65169   0.095104
# 65170  -0.146734
# ...          ...
# 66156  -0.091975
# 66157   0.155330
# 66158  -0.191492
# 66159  -0.001677
# 66160  -0.327693
#
# [977 rows x 1 columns],        xs_return
# 66161   0.036252
# 66162   0.078373
# 66163  -0.044275
# 66164   0.054774
# 66165  -0.033169
# ...          ...
# 67150   0.038558
# 67151  -0.012550
# 67152  -0.112722
# 67153  -0.080795
# 67154   0.032840
#
# [977 rows x 1 columns],        xs_return
# 67155  -0.067292
# 67156   0.016605
# 67157   0.070513
# 67158  -0.164311
# 67159   0.097919
# ...          ...
# 68139   0.018837
# 68140  -0.110954
# 68141  -0.106240
# 68142   0.051655
# 68143   0.252069
#
# [975 rows x 1 columns],        xs_return
# 68146  -0.053844
# 68147   0.033238
# 68148   0.004362
# 68149   0.034359
# 68150  -0.158986
# ...          ...
# 69129   0.140268
# 69130   0.021289
# 69131  -0.151514
# 69132  -0.331050
# 69133  -0.048347
#
# [965 rows x 1 columns],        xs_return
# 69135  -0.047218
# 69136  -0.308472
# 69137  -0.002778
# 69138   0.020053
# 69140   0.030698
# ...          ...
# 70116  -0.031419
# 70117  -0.067537
# 70118   0.100978
# 70119   0.104002
# 70120  -0.078194
#
# [966 rows x 1 columns],        xs_return
# 70121  -0.159490
# 70122   0.253894
# 70123   0.077695
# 70124   0.045305
# 70125   0.083959
# ...          ...
# 71099   0.185786
# 71100  -0.130673
# 71101  -0.000228
# 71102   0.022854
# 71103   0.577874
#
# [963 rows x 1 columns],        xs_return
# 71104  -0.041529
# 71105   0.110498
# 71106  -0.061461
# 71107  -0.003445
# 71109   0.314141
# ...          ...
# 72081  -0.033950
# 72082  -0.352882
# 72083   0.029646
# 72084   0.170572
# 72085  -0.015986
#
# [962 rows x 1 columns],        xs_return
# 72086   0.162785
# 72087  -0.051274
# 72088  -0.101629
# 72089  -0.159334
# 72090   0.163309
# ...          ...
# 73061  -0.166353
# 73062  -0.011344
# 73063  -0.011753
# 73064  -0.015035
# 73065   0.260727
#
# [966 rows x 1 columns],        xs_return
# 73066   0.021341
# 73067   0.073222
# 73068   0.019307
# 73069  -0.025759
# 73070   0.032895
# ...          ...
# 74037   0.026165
# 74039  -0.155241
# 74040   0.060768
# 74041   0.036147
# 74042  -0.095284
#
# [963 rows x 1 columns],        xs_return
# 74043   0.129595
# 74044   0.261006
# 74045  -0.099309
# 74046  -0.023357
# 74047  -0.269717
# ...          ...
# 75010  -0.021874
# 75011   0.169948
# 75012  -0.360529
# 75013  -0.021979
# 75014  -0.588807
#
# [959 rows x 1 columns],        xs_return
# 75015   0.025424
# 75017  -0.083025
# 75018  -0.011768
# 75019  -0.196537
# 75020   0.063747
# ...          ...
# 75981  -0.084923
# 75982  -0.089377
# 75983   0.104871
# 75984   0.244803
# 75985  -0.001764
#
# [957 rows x 1 columns],        xs_return
# 75987   0.360830
# 75988   0.082410
# 75989  -0.054494
# 75990   0.030699
# 75991   0.022025
# ...          ...
# 76952  -0.125573
# 76953  -0.160753
# 76954  -0.070916
# 76955  -0.204122
# 76956   0.165235
#
# [959 rows x 1 columns],        xs_return
# 76957   0.189799
# 76958  -0.103393
# 76959  -0.290343
# 76960   0.015350
# 76961  -0.234166
# ...          ...
# 77945  -0.189402
# 77946   0.119692
# 77947  -0.093520
# 77948  -0.068502
# 77949  -0.043422
#
# [970 rows x 1 columns],        xs_return
# 77950  -0.123583
# 77951  -0.061303
# 77952  -0.067696
# 77953  -0.018015
# 77954  -0.269322
# ...          ...
# 78933  -0.010876
# 78934  -0.121445
# 78935   0.172921
# 78936  -0.121659
# 78938  -0.073402
#
# [970 rows x 1 columns],        xs_return
# 78939  -0.138128
# 78940   0.173953
# 78941  -0.201363
# 78942  -0.140089
# 78943   0.031884
# ...          ...
# 79920   0.750585
# 79921   0.060377
# 79922   0.089912
# 79923  -0.069730
# 79924  -0.103736
#
# [971 rows x 1 columns],        xs_return
# 79925  -0.004576
# 79926  -0.011668
# 79927  -0.603752
# 79928  -0.098166
# 79929  -0.160798
# ...          ...
# 80902  -0.031266
# 80903   0.109382
# 80904   0.042381
# 80905  -0.075372
# 80906  -0.283183
#
# [964 rows x 1 columns],        xs_return
# 80907   0.017310
# 80908  -0.114495
# 80909   0.024771
# 80910  -0.041705
# 80911  -0.207378
# ...          ...
# 81885   0.121144
# 81886   0.053382
# 81887   0.083134
# 81888   0.045661
# 81889   0.152209
#
# [966 rows x 1 columns],        xs_return
# 81890  -0.160079
# 81891   0.113411
# 81892   0.008917
# 81893  -0.108077
# 81894  -0.230409
# ...          ...
# 82869   0.004300
# 82870  -0.252348
# 82872   0.117731
# 82873  -0.047444
# 82874  -0.026710
#
# [968 rows x 1 columns],        xs_return
# 82875  -0.113608
# 82876   0.042597
# 82877   0.109645
# 82878  -0.107230
# 82879  -0.121098
# ...          ...
# 83853  -0.110242
# 83854  -0.090609
# 83855   0.015872
# 83856   0.026095
# 83857  -0.016069
#
# [966 rows x 1 columns],        xs_return
# 83858   0.031824
# 83859   0.008964
# 83860  -0.320501
# 83861  -0.122721
# 83862   0.042023
# ...          ...
# 84837  -0.071582
# 84838  -0.071020
# 84839  -0.223938
# 84840   0.094702
# 84841   0.006339
#
# [970 rows x 1 columns],        xs_return
# 84842  -0.182317
# 84843   0.125684
# 84844  -0.233359
# 84845  -0.150673
# 84846   0.000900
# ...          ...
# 85819  -0.050409
# 85820   0.069024
# 85821   0.000278
# 85822   0.418921
# 85823   0.018787
#
# [968 rows x 1 columns],        xs_return
# 85824   0.084902
# 85825  -0.000587
# 85826  -0.101043
# 85827   0.059662
# 85828  -0.078495
# ...          ...
# 86798  -0.046455
# 86799   0.005368
# 86800   0.003050
# 86801  -0.057339
# 86802  -0.149373
#
# [958 rows x 1 columns],        xs_return
# 86803  -0.005215
# 86804  -0.213874
# 86805   0.071042
# 86806  -0.083422
# 86807  -0.148072
# ...          ...
# 87775  -0.020889
# 87776   0.257482
# 87777  -0.017184
# 87778   0.121480
# 87779  -0.023953
#
# [959 rows x 1 columns],        xs_return
# 87780  -0.263111
# 87781   0.025059
# 87782   0.053908
# 87783   0.012006
# 87784   0.069819
# ...          ...
# 88751   0.063730
# 88752   0.052395
# 88753  -0.046265
# 88754   0.147280
# 88755  -0.061883
#
# [960 rows x 1 columns],        xs_return
# 88756  -0.318014
# 88757   0.218517
# 88758   0.175805
# 88759   0.363804
# 88760   0.132797
# ...          ...
# 89744   0.071743
# 89745  -0.030287
# 89746  -0.458938
# 89747  -0.138025
# 89748  -0.075539
#
# [971 rows x 1 columns],        xs_return
# 89749   0.120975
# 89750  -0.137252
# 89751  -0.198988
# 89752   0.072318
# 89753   0.381700
# ...          ...
# 90730   0.073593
# 90731  -0.233980
# 90732  -0.095872
# 90733   0.069942
# 90735  -0.170955
#
# [969 rows x 1 columns],        xs_return
# 90736   0.157661
# 90737  -0.064242
# 90738  -0.073695
# 90740   0.233883
# 90741  -0.033095
# ...          ...
# 91709  -0.238639
# 91710  -0.061280
# 91711   0.059601
# 91712  -0.123579
# 91713   0.083287
#
# [967 rows x 1 columns],        xs_return
# 91714   0.024165
# 91715  -0.146335
# 91716  -0.030224
# 91717   0.062322
# 91718   0.103093
# ...          ...
# 92686  -0.259070
# 92687  -0.039539
# 92688   0.018641
# 92689  -0.001030
# 92690   0.117153
#
# [957 rows x 1 columns],        xs_return
# 92691  -0.153780
# 92692   0.073719
# 92693  -0.197356
# 92694   0.179655
# 92695   0.010360
# ...          ...
# 93661  -0.065242
# 93662  -0.026687
# 93663   0.024632
# 93664   0.532305
# 93665   0.053464
#
# [957 rows x 1 columns],        xs_return
# 93668  -0.051049
# 93669   0.011550
# 93670   0.208274
# 93672  -0.050738
# 93673   0.188981
# ...          ...
# 94637   0.715686
# 94638   0.051357
# 94639  -0.072047
# 94640   0.002819
# 94641  -0.103291
#
# [957 rows x 1 columns],        xs_return
# 94642  -0.176657
# 94643  -0.085275
# 94644  -0.127526
# 94645  -0.017129
# 94646  -0.140988
# ...          ...
# 95607   0.082667
# 95608   0.055362
# 95609  -0.133078
# 95610  -0.005990
# 95611   0.006577
#
# [954 rows x 1 columns],        xs_return
# 95612  -0.128841
# 95613  -0.246086
# 95614  -0.012592
# 95615   0.057885
# 95616  -0.284063
# ...          ...
# 96575  -0.069698
# 96576  -0.249163
# 96577   0.083302
# 96578  -0.051326
# 96579   0.229569
#
# [953 rows x 1 columns],        xs_return
# 96580  -0.198978
# 96581  -0.043170
# 96582   0.131327
# 96583  -0.095466
# 96584  -0.095901
# ...          ...
# 97541   0.199892
# 97542   0.027236
# 97543  -0.320940
# 97544  -0.023649
# 97545   0.082596
#
# [953 rows x 1 columns],        xs_return
# 97546   0.037461
# 97547  -0.082688
# 97548  -0.163343
# 97549   0.070515
# 97550  -0.095681
# ...          ...
# 98503  -0.200801
# 98504  -0.031422
# 98505  -0.225723
# 98506   0.136412
# 98507  -0.125233
#
# [941 rows x 1 columns],        xs_return
# 98508   0.289027
# 98509   0.206070
# 98510  -0.237945
# 98511   0.049854
# 98512   0.019943
# ...          ...
# 99463  -0.036743
# 99464  -0.230780
# 99465   0.260783
# 99466  -0.465905
# 99467   0.139175
#
# [940 rows x 1 columns],         xs_return
# 99468    0.050679
# 99469    0.002991
# 99470    0.042321
# 99471   -0.121590
# 99472   -0.227648
# ...           ...
# 100420   0.185809
# 100421  -0.420990
# 100422  -0.259977
# 100423  -0.001559
# 100424   0.241534
#
# [940 rows x 1 columns],         xs_return
# 100425   0.118924
# 100426  -0.003053
# 100427   0.029577
# 100428   0.077802
# 100429   0.205427
# ...           ...
# 101410   0.110297
# 101411   0.109482
# 101412   0.712004
# 101413  -0.051767
# 101415  -0.285936
#
# [971 rows x 1 columns],         xs_return
# 101416  -0.138886
# 101417  -0.210618
# 101418   0.076971
# 101419   0.268020
# 101420   0.441977
# ...           ...
# 102398   0.111091
# 102399  -0.231936
# 102400  -0.342014
# 102401   0.048713
# 102403  -0.557970
#
# [971 rows x 1 columns],         xs_return
# 102404  -0.160547
# 102405   0.319741
# 102406  -0.347668
# 102407  -0.010001
# 102408   0.555148
# ...           ...
# 103381   0.153630
# 103382  -0.155512
# 103383   0.189351
# 103384   0.004490
# 103385  -0.059170
#
# [968 rows x 1 columns],         xs_return
# 103386   0.561332
# 103387  -0.145923
# 103388   0.004876
# 103389  -0.082137
# 103390   0.277731
# ...           ...
# 104353  -0.248549
# 104355   0.065312
# 104356  -0.186719
# 104357  -0.323961
# 104358  -0.034576
#
# [949 rows x 1 columns],         xs_return
# 104359  -0.229520
# 104360   0.614070
# 104361   0.169750
# 104362  -0.511743
# 104363  -0.184889
# ...           ...
# 105318  -0.052362
# 105319  -0.252922
# 105320  -0.097873
# 105321   0.514562
# 105322   0.486499
#
# [946 rows x 1 columns],         xs_return
# 105324   0.238547
# 105325   0.036877
# 105326  -0.009992
# 105327  -0.008654
# 105329   0.290426
# ...           ...
# 106278   0.335878
# 106279   0.536821
# 106280   0.327901
# 106282   0.369431
# 106283  -0.031622
#
# [944 rows x 1 columns],         xs_return
# 106284  -0.043608
# 106285   0.091998
# 106286  -0.137625
# 106287  -0.135331
# 106288  -0.331343
# ...           ...
# 107235  -0.067726
# 107236   0.327797
# 107237  -0.021167
# 107238   0.135585
# 107239   0.292511
#
# [937 rows x 1 columns],         xs_return
# 107240  -0.045951
# 107242  -0.186948
# 107243   0.464763
# 107244   0.341380
# 107245   0.320092
# ...           ...
# 108191   0.019802
# 108192  -0.085858
# 108193   0.145900
# 108194  -0.067405
# 108195  -0.305606
#
# [939 rows x 1 columns],         xs_return
# 108196   0.456344
# 108197  -0.088853
# 108198  -0.088421
# 108199  -0.022088
# 108200   0.330267
# ...           ...
# 109145  -0.125032
# 109146  -0.044656
# 109147   0.283401
# 109148   0.032223
# 109149  -0.250815
#
# [938 rows x 1 columns],         xs_return
# 109150  -0.088113
# 109151   0.157793
# 109152  -0.063056
# 109153  -0.154005
# 109154  -0.256219
# ...           ...
# 110092  -0.082014
# 110093  -0.178590
# 110094  -0.136330
# 110095  -0.183387
# 110096   0.057965
#
# [932 rows x 1 columns],         xs_return
# 110097   0.056572
# 110098   0.093198
# 110099  -0.096232
# 110100   0.190059
# 110101   0.111598
# ...           ...
# 111035  -0.218058
# 111036   0.156166
# 111037  -0.212402
# 111038  -0.021543
# 111039  -0.075539
#
# [933 rows x 1 columns],         xs_return
# 111040  -0.129263
# 111041  -0.462859
# 111042  -0.015043
# 111043  -0.103678
# 111044   0.173185
# ...           ...
# 111979  -0.146386
# 111980  -0.215232
# 111981  -0.262418
# 111982   0.034292
# 111983  -0.266978
#
# [937 rows x 1 columns],         xs_return
# 111984   0.645303
# 111985   0.310237
# 111986   0.037218
# 111987  -0.446823
# 111988  -0.201528
# ...           ...
# 112975  -0.324001
# 112976  -0.346548
# 112977   0.104766
# 112978  -0.256670
# 112979  -0.114229
#
# [990 rows x 1 columns],         xs_return
# 112980  -0.195545
# 112981  -0.268652
# 112982   0.074611
# 112983  -0.354968
# 112984  -0.127594
# ...           ...
# 113962   0.053545
# 113963  -0.109236
# 113964  -0.183842
# 113965  -0.142411
# 113966  -0.146725
#
# [981 rows x 1 columns],         xs_return
# 113967  -0.056625
# 113968  -0.290093
# 113969  -0.104679
# 113970   0.779565
# 113971   0.036102
# ...           ...
# 114945  -0.140890
# 114946  -0.160227
# 114947  -0.284047
# 114948   0.006548
# 114949  -0.149647
#
# [975 rows x 1 columns],         xs_return
# 114950   0.972155
# 114951   0.516258
# 114952   0.055071
# 114953  -0.253636
# 114954  -0.070539
# ...           ...
# 115930  -0.145502
# 115931   0.548319
# 115932   0.670288
# 115933  -0.248906
# 115934  -0.158731
#
# [974 rows x 1 columns],         xs_return
# 115935  -0.142594
# 115936   0.550835
# 115937   0.222480
# 115938   0.123472
# 115939  -0.337749
# ...           ...
# 116906   0.050896
# 116907  -0.415217
# 116908  -0.043785
# 116909  -0.187349
# 116910   0.076826
#
# [965 rows x 1 columns],         xs_return
# 116911  -0.023221
# 116912   0.002204
# 116913  -0.129360
# 116914  -0.129970
# 116915  -0.490930
# ...           ...
# 117883   0.283816
# 117884   0.681188
# 117885   0.215691
# 117886   0.474522
# 117887   0.136682
#
# [967 rows x 1 columns],         xs_return
# 117888   0.176974
# 117889   0.269092
# 117890   0.147834
# 117891   0.197982
# 117892  -0.018812
# ...           ...
# 118853  -0.353513
# 118854  -0.121864
# 118855   0.261866
# 118856  -0.248714
# 118857  -0.183590
#
# [961 rows x 1 columns],         xs_return
# 118858   0.181012
# 118859   0.096192
# 118860  -0.034023
# 118861   0.152071
# 118862   0.154368
# ...           ...
# 119818  -0.357815
# 119819  -0.031798
# 119820  -0.027880
# 119821  -0.150524
# 119822   0.546138
#
# [957 rows x 1 columns],         xs_return
# 119823  -0.094498
# 119824  -0.044369
# 119825   0.078510
# 119826   0.019767
# 119827   0.082382
# ...           ...
# 120780  -0.093509
# 120781   0.012080
# 120782  -0.048137
# 120783   0.095228
# 120786   0.334379
#
# [956 rows x 1 columns],         xs_return
# 120787  -0.255300
# 120788  -0.171432
# 120789   0.240727
# 120790   0.012912
# 120791  -0.004999
# ...           ...
# 121741   0.065222
# 121742  -0.224672
# 121743   0.036077
# 121744   0.037511
# 121745   0.033435
#
# [951 rows x 1 columns],         xs_return
# 121746  -0.019930
# 121747   0.024164
# 121748  -0.445325
# 121749   0.179366
# 121750   0.210149
# ...           ...
# 122699   0.075847
# 122700   0.369126
# 122701  -0.161380
# 122702   0.144541
# 122703  -0.077463
#
# [950 rows x 1 columns],         xs_return
# 122704   0.004918
# 122705  -0.297574
# 122706   0.188437
# 122707   0.230402
# 122708   0.322548
# ...           ...
# 123653   0.179617
# 123654   0.083967
# 123655   0.241617
# 123656   0.101290
# 123657  -0.223731
#
# [946 rows x 1 columns],         xs_return
# 123658   0.182752
# 123659   0.225675
# 123660   0.185508
# 123661   0.034630
# 123662   0.142936
# ...           ...
# 124645   0.159878
# 124646   0.098687
# 124647   0.278480
# 124648  -0.711474
# 124649  -0.804028
#
# [986 rows x 1 columns],         xs_return
# 124650   0.496485
# 124651   0.031389
# 124652   0.296343
# 124653  -0.043548
# 124654  -0.721564
# ...           ...
# 125630   0.303277
# 125631   0.006789
# 125632  -0.337667
# 125633   0.131735
# 125634   0.247891
#
# [978 rows x 1 columns],         xs_return
# 125635   0.143328
# 125636  -0.411955
# 125637   0.004896
# 125638   0.308240
# 125639   0.080755
# ...           ...
# 126611   0.409006
# 126612   0.414543
# 126613   0.057127
# 126614   0.148497
# 126615   0.097321
#
# [975 rows x 1 columns],         xs_return
# 126616  -0.276604
# 126617  -0.107539
# 126618   0.296560
# 126619  -0.541730
# 126620   0.423207
# ...           ...
# 127587   0.139821
# 127588  -0.499613
# 127589   0.100879
# 127590  -0.367199
# 127591   0.208672
#
# [970 rows x 1 columns],         xs_return
# 127592   0.107954
# 127593   0.139569
# 127594   0.094127
# 127595   0.208772
# 127596  -0.024758
# ...           ...
# 128557   0.131265
# 128558   0.175787
# 128559   0.135096
# 128560  -0.026119
# 128561   0.293118
#
# [964 rows x 1 columns],         xs_return
# 128562  -0.456025
# 128563   0.051948
# 128564   0.177393
# 128565   0.036617
# 128566   0.336493
# ...           ...
# 129517  -0.305162
# 129518   0.000124
# 129519  -0.068252
# 129520   0.071023
# 129521  -0.187610
#
# [954 rows x 1 columns],         xs_return
# 129522   0.169149
# 129523  -0.118728
# 129524  -0.029889
# 129525  -0.055099
# 129526  -0.039188
# ...           ...
# 130472   0.152416
# 130473   0.151272
# 130474  -0.132282
# 130475  -0.221720
# 130477  -0.033047
#
# [950 rows x 1 columns],         xs_return
# 130478  -0.112631
# 130479   0.656593
# 130480   0.276695
# 130481  -0.119821
# 130482   0.039495
# ...           ...
# 131427   0.106855
# 131428   0.142496
# 131429   0.109206
# 131431  -0.437906
# 131432  -0.509174
#
# [949 rows x 1 columns],         xs_return
# 131433   0.273741
# 131434   0.068940
# 131435   2.456616
# 131436  -0.027479
# 131437  -0.009795
# ...           ...
# 132379  -0.294208
# 132380   0.083567
# 132381  -0.078989
# 132382  -0.012716
# 132383   0.062601
#
# [946 rows x 1 columns],         xs_return
# 132384   0.158044
# 132385  -0.306937
# 132386  -0.033829
# 132387   0.065878
# 132388  -0.239436
# ...           ...
# 133327   0.175332
# 133328   0.226749
# 133329   0.356845
# 133330  -0.064191
# 133331   0.209743
#
# [944 rows x 1 columns],         xs_return
# 133332  -0.603746
# 133333  -0.411049
# 133334  -0.314520
# 133335   0.050780
# 133336  -0.023590
# ...           ...
# 134268   0.141326
# 134269   0.035495
# 134270  -0.239638
# 134271   0.059622
# 134272   0.111707
#
# [938 rows x 1 columns],         xs_return
# 134273   0.063966
# 134274  -0.143361
# 134275  -0.136261
# 134276  -0.130519
# 134277  -0.568893
# ...           ...
# 135209   0.008014
# 135210   0.131134
# 135211   0.868373
# 135212   0.039117
# 135213   0.749583
#
# [938 rows x 1 columns],         xs_return
# 135214  -0.009233
# 135215  -0.038647
# 135216   0.098692
# 135217  -0.017587
# 135218  -0.084717
# ...           ...
# 136207   0.192388
# 136208  -0.033414
# 136209  -0.269727
# 136210  -0.127748
# 136211   0.060817
#
# [992 rows x 1 columns],         xs_return
# 136212  -0.059302
# 136213   0.452624
# 136214   1.047234
# 136215   0.400225
# 136216  -0.091101
# ...           ...
# 137200  -0.097450
# 137201  -0.046322
# 137202  -0.122780
# 137203   0.283131
# 137204   0.078165
#
# [987 rows x 1 columns],         xs_return
# 137205  -0.103872
# 137206   0.180372
# 137207   0.148369
# 137208  -0.186421
# 137209  -0.129720
# ...           ...
# 138187   0.094287
# 138188  -0.248183
# 138189  -0.074611
# 138190   0.173488
# 138191  -0.185734
#
# [982 rows x 1 columns],         xs_return
# 138192   0.039958
# 138193   0.005367
# 138194  -0.044354
# 138195   0.033678
# 138196  -0.124282
# ...           ...
# 139170  -0.439346
# 139171   0.229730
# 139172  -0.028752
# 139173  -0.437712
# 139174   0.121047
#
# [978 rows x 1 columns],         xs_return
# 139175   0.027421
# 139176   0.079347
# 139177  -0.373646
# 139179  -0.072255
# 139180   0.232475
# ...           ...
# 140146   0.088007
# 140147   0.083373
# 140148   0.028228
# 140149   0.255456
# 140150  -0.003206
#
# [971 rows x 1 columns],         xs_return
# 140151   0.779508
# 140152   0.146290
# 140153  -0.005926
# 140154  -0.371914
# 140155  -0.019619
# ...           ...
# 141124   0.113052
# 141125   0.047290
# 141126   0.045029
# 141127   0.026861
# 141128  -0.047626
#
# [973 rows x 1 columns],         xs_return
# 141129   0.089001
# 141130  -0.057649
# 141131  -0.026955
# 141132   0.376413
# 141133  -0.017379
# ...           ...
# 142093   0.177864
# 142094   0.321330
# 142095   0.053368
# 142096   0.180735
# 142097  -0.232573
#
# [964 rows x 1 columns],         xs_return
# 142098  -0.506651
# 142099  -0.037897
# 142100  -0.393519
# 142101  -0.038846
# 142102   0.108198
# ...           ...
# 143057   0.037373
# 143058   0.016900
# 143059  -0.407805
# 143060   0.022492
# 143061   0.149271
#
# [959 rows x 1 columns],         xs_return
# 143062   0.000490
# 143063  -0.059278
# 143064   0.084656
# 143065  -0.191833
# 143066  -0.460048
# ...           ...
# 144017  -0.048672
# 144018   0.042952
# 144019  -0.306653
# 144020  -0.178961
# 144022   0.108002
#
# [956 rows x 1 columns],         xs_return
# 144023   0.021978
# 144024  -0.106462
# 144025   0.083128
# 144026  -0.109792
# 144027   0.351211
# ...           ...
# 144976  -0.102135
# 144977  -0.002058
# 144978  -0.184137
# 144979  -0.013934
# 144980   0.066012
#
# [953 rows x 1 columns],         xs_return
# 144981  -0.292873
# 144982   0.165262
# 144983   0.108663
# 144984   0.183569
# 144985  -0.063666
# ...           ...
# 145933   0.222382
# 145934  -0.045512
# 145935  -0.127733
# 145936  -0.400523
# 145937  -0.026428
#
# [952 rows x 1 columns],         xs_return
# 145938  -0.043049
# 145939  -0.349328
# 145940   0.087688
# 145941   0.004432
# 145942   0.196105
# ...           ...
# 146884   0.029852
# 146885   0.023368
# 146886  -0.039897
# 146887  -0.195770
# 146888   0.163298
#
# [946 rows x 1 columns],         xs_return
# 146889  -0.039375
# 146890  -0.166270
# 146891  -0.372269
# 146892   0.339845
# 146893  -0.001574
# ...           ...
# 147881  -0.069493
# 147882   0.281683
# 147883   0.068185
# 147884   0.018445
# 147885   0.014723
#
# [991 rows x 1 columns],         xs_return
# 147886  -0.102203
# 147887  -0.106465
# 147888  -0.020594
# 147889  -0.025190
# 147890   0.205920
# ...           ...
# 148876   0.076304
# 148877   0.054099
# 148878  -0.221513
# 148879  -0.172724
# 148880  -0.068945
#
# [988 rows x 1 columns],         xs_return
# 148881   0.039320
# 148882   0.011560
# 148883   0.194058
# 148884   0.083479
# 148885   0.088326
# ...           ...
# 149868   0.120296
# 149869   0.095508
# 149870  -0.050009
# 149871   0.072964
# 149872  -0.215531
#
# [986 rows x 1 columns],         xs_return
# 149873   0.038085
# 149874   0.139732
# 149875   0.090472
# 149876   0.406544
# 149877   0.158127
# ...           ...
# 150858   0.061775
# 150860  -0.066155
# 150861  -0.115144
# 150863   0.134322
# 150864   0.030540
#
# [986 rows x 1 columns],         xs_return
# 150865  -0.093724
# 150866   0.079887
# 150867  -0.079552
# 150868   0.207990
# 150869  -0.108325
# ...           ...
# 151852  -0.161414
# 151853   0.037218
# 151854   0.136970
# 151855  -0.142091
# 151856  -0.006367
#
# [986 rows x 1 columns],         xs_return
# 151857  -0.164087
# 151858  -0.048544
# 151859  -0.020745
# 151860   0.130863
# 151861  -0.076825
# ...           ...
# 152843   0.039190
# 152844   0.222510
# 152845  -0.141474
# 152846   0.281503
# 152847   0.118398
#
# [985 rows x 1 columns],         xs_return
# 152848  -0.148101
# 152849  -0.029612
# 152850   0.118635
# 152851   0.034001
# 152852   0.342835
# ...           ...
# 153832   0.444948
# 153833  -0.145593
# 153834  -0.076072
# 153835   0.481341
# 153836   0.480878
#
# [983 rows x 1 columns],         xs_return
# 153837  -0.050308
# 153838  -0.072246
# 153839  -0.095051
# 153840  -0.097334
# 153841   0.231680
# ...           ...
# 154819  -0.123413
# 154820   0.578199
# 154821   0.124223
# 154823   0.860657
# 154824   0.062039
#
# [982 rows x 1 columns],         xs_return
# 154825   0.029392
# 154826  -0.196419
# 154827  -0.052763
# 154828  -0.048946
# 154829   0.208894
# ...           ...
# 155808  -0.032039
# 155809   0.122290
# 155810  -0.010308
# 155811  -0.069980
# 155812  -0.029146
#
# [982 rows x 1 columns],         xs_return
# 155813  -0.086882
# 155814  -0.345765
# 155815  -0.142265
# 155816   0.229705
# 155817  -0.153144
# ...           ...
# 156792   0.173762
# 156793  -0.009835
# 156794   0.118904
# 156795  -0.028802
# 156796   0.033123
#
# [978 rows x 1 columns],         xs_return
# 156797  -0.168460
# 156798   0.296356
# 156799  -0.034752
# 156800   0.294794
# 156801   0.011280
# ...           ...
# 157774  -0.169969
# 157775  -0.025643
# 157776  -0.207083
# 157777  -0.067361
# 157778   0.017365
#
# [976 rows x 1 columns],         xs_return
# 157779  -0.003450
# 157780  -0.137867
# 157781   0.151195
# 157782  -0.174527
# 157783  -0.091186
# ...           ...
# 158756   0.077934
# 158757   0.056223
# 158758  -0.005385
# 158759   0.116243
# 158760   0.173125
#
# [976 rows x 1 columns],         xs_return
# 158761   0.060424
# 158762  -0.117922
# 158763   0.079673
# 158764   0.072942
# 158765  -0.009437
# ...           ...
# 159752   0.083020
# 159754  -0.299363
# 159755   0.005718
# 159756  -0.052975
# 159758  -0.087821
#
# [992 rows x 1 columns],         xs_return
# 159759   0.174189
# 159760  -0.081186
# 159761   0.115265
# 159762   0.030463
# 159763   0.103352
# ...           ...
# 160750   0.069228
# 160751  -0.109386
# 160752   0.015743
# 160753  -0.095116
# 160754   0.032698
#
# [990 rows x 1 columns],         xs_return
# 160755   0.006234
# 160756  -0.014271
# 160757  -0.008142
# 160758  -0.038770
# 160759   0.005288
# ...           ...
# 161744   0.079444
# 161745   0.346374
# 161746   0.053026
# 161747  -0.012701
# 161748   0.112466
#
# [987 rows x 1 columns],         xs_return
# 161749   0.168745
# 161750   0.008211
# 161751  -0.309140
# 161752   0.135069
# 161753   0.064578
# ...           ...
# 162736  -0.024478
# 162737  -0.003363
# 162738  -0.110926
# 162739   0.080875
# 162740   0.012992
#
# [985 rows x 1 columns],         xs_return
# 162741   0.116364
# 162742   0.151338
# 162743   0.026186
# 162744  -0.268003
# 162745  -0.003942
# ...           ...
# 163726   0.176230
# 163727   0.143709
# 163728  -0.071705
# 163729  -0.172054
# 163730  -0.063106
#
# [983 rows x 1 columns],         xs_return
# 163731   0.042499
# 163732   0.003913
# 163733  -0.065279
# 163734   0.101470
# 163735  -0.047081
# ...           ...
# 164714   0.119600
# 164715  -0.171102
# 164716   0.009612
# 164717  -0.075294
# 164718   0.139939
#
# [981 rows x 1 columns],         xs_return
# 164719  -0.018585
# 164720   0.116512
# 164721   0.022716
# 164722   0.022795
# 164723  -0.067879
# ...           ...
# 165703  -0.049172
# 165704  -0.034559
# 165705  -0.040450
# 165706  -0.002198
# 165707   0.012281
#
# [981 rows x 1 columns],         xs_return
# 165708  -0.150518
# 165709  -0.099728
# 165710  -0.277032
# 165711  -0.121289
# 165712   0.064525
# ...           ...
# 166692   0.166302
# 166693  -0.028196
# 166694   0.184041
# 166695  -0.018939
# 166696  -0.076399
#
# [980 rows x 1 columns],         xs_return
# 166698  -0.219171
# 166699   0.087362
# 166700  -0.094883
# 166701  -0.115476
# 166702   0.120788
# ...           ...
# 167680   0.053990
# 167681  -0.037928
# 167682   0.054416
# 167683   0.002893
# 167685  -0.203272
#
# [978 rows x 1 columns],         xs_return
# 167686  -0.048026
# 167687   0.039206
# 167688  -0.046356
# 167689  -0.007296
# 167690   0.126821
# ...           ...
# 168666   0.026519
# 168667   0.056269
# 168668  -0.014556
# 168669  -0.099732
# 168670   0.209172
#
# [975 rows x 1 columns],         xs_return
# 168671   0.154041
# 168672  -0.318395
# 168673   0.100115
# 168674   0.023223
# 168675   0.121832
# ...           ...
# 169646   0.064962
# 169647   0.055657
# 169648   0.048773
# 169649  -0.028514
# 169650   0.045345
#
# [970 rows x 1 columns],         xs_return
# 169651   0.146261
# 169652  -0.091584
# 169653  -0.021230
# 169654   0.019970
# 169655   0.004627
# ...           ...
# 170628   0.125261
# 170629   0.141689
# 170630   0.138105
# 170631  -0.079073
# 170632   0.039331
#
# [971 rows x 1 columns],         xs_return
# 170633   0.082313
# 170634  -0.007088
# 170635  -0.054986
# 170636   0.058094
# 170637  -0.026174
# ...           ...
# 171617   0.220178
# 171618  -0.068734
# 171619   0.383602
# 171625   0.110801
# 171626  -0.030129
#
# [969 rows x 1 columns],         xs_return
# 171627   0.078775
# 171628   0.229627
# 171629   0.137617
# 171630  -0.052319
# 171631  -0.016135
# ...           ...
# 172613   0.127505
# 172614  -0.004370
# 172615   0.244034
# 172616   0.025856
# 172619   0.276534
#
# [967 rows x 1 columns],         xs_return
# 172620   0.000398
# 172621  -0.043223
# 172622  -0.115921
# 172623   0.075105
# 172624   0.058991
# ...           ...
# 173601  -0.058187
# 173602  -0.077170
# 173603  -0.041146
# 173604  -0.055165
# 173605  -0.122072
#
# [963 rows x 1 columns],         xs_return
# 173609  -0.023799
# 173610  -0.054515
# 173611   0.076856
# 173612   0.113863
# 173613   0.125093
# ...           ...
# 174593  -0.025838
# 174594   0.006060
# 174595   0.175428
# 174596  -0.073949
# 174600   0.343758
#
# [960 rows x 1 columns],         xs_return
# 174601   0.387572
# 174602  -0.012807
# 174603  -0.040076
# 174604  -0.328531
# 174605   0.264406
# ...           ...
# 175579  -0.010606
# 175580   0.030094
# 175581   0.559670
# 175588  -0.119315
# 175589  -0.073839
#
# [957 rows x 1 columns],         xs_return
# 175590   0.023975
# 175591   0.063798
# 175592   0.126634
# 175593  -0.048868
# 175594  -0.163022
# ...           ...
# 176567  -0.101671
# 176568   0.053342
# 176569   0.002419
# 176570   0.012241
# 176571   0.024355
#
# [954 rows x 1 columns],         xs_return
# 176576  -0.011739
# 176577  -0.041601
# 176578   0.100506
# 176579   0.078318
# 176580  -0.028970
# ...           ...
# 177559   0.176698
# 177560   0.364148
# 177561  -0.019117
# 177562  -0.028059
# 177563  -0.116229
#
# [951 rows x 1 columns],         xs_return
# 177564   0.143405
# 177565   0.150309
# 177566  -0.168667
# 177567   0.009422
# 177568   0.066537
# ...           ...
# 178543  -0.040831
# 178544  -0.139347
# 178545   0.009354
# 178546  -0.151620
# 178550  -0.206288
#
# [950 rows x 1 columns],         xs_return
# 178551  -0.072784
# 178552   0.020049
# 178553   0.028612
# 178554   0.012496
# 178555  -0.108552
# ...           ...
# 179528  -0.037728
# 179529   0.028275
# 179530  -0.108513
# 179536  -0.029915
# 179537  -0.035930
#
# [948 rows x 1 columns],         xs_return
# 179538  -0.022249
# 179539  -0.101673
# 179540  -0.066958
# 179541  -0.066410
# 179542   0.215431
# ...           ...
# 180514  -0.032368
# 180515   0.030741
# 180523  -0.000043
# 180524  -0.071846
# 180525   0.011490
#
# [945 rows x 1 columns],         xs_return
# 180526  -0.122533
# 180527   0.072348
# 180528  -0.024261
# 180529   0.131812
# 180530   0.037030
# ...           ...
# 181502  -0.053228
# 181503  -0.113177
# 181504   0.095602
# 181505   0.184090
# 181509  -0.107606
#
# [943 rows x 1 columns],         xs_return
# 181511  -0.006716
# 181512   0.106673
# 181513   0.023437
# 181514   0.285290
# 181515   0.051937
# ...           ...
# 182484  -0.353907
# 182485  -0.191451
# 182486  -0.085349
# 182487   0.018413
# 182493   0.044380
#
# [942 rows x 1 columns],         xs_return
# 182495   0.100495
# 182496   0.055837
# 182497  -0.257058
# 182498   0.062347
# 182499  -0.032651
# ...           ...
# 183488   0.053710
# 183489   0.169445
# 183490   0.029553
# 183491   0.149113
# 183492  -0.011523
#
# [955 rows x 1 columns],         xs_return
# 183493   0.280960
# 183494  -0.023747
# 183495  -0.057160
# 183496   0.026785
# 183497   0.069933
# ...           ...
# 184476   0.095385
# 184477   0.264374
# 184478   0.173121
# 184479  -0.015424
# 184480   0.156656
#
# [950 rows x 1 columns],         xs_return
# 184487  -0.066992
# 184488  -0.019032
# 184489   0.002961
# 184490   0.346858
# 184491   0.036344
# ...           ...
# 185464   0.093851
# 185465   0.068831
# 185466   0.097604
# 185468   0.197887
# 185472   0.535279
#
# [943 rows x 1 columns],         xs_return
# 185475   0.144163
# 185476   0.065006
# 185477   0.043139
# 185478   0.010898
# 185479   0.176680
# ...           ...
# 186452   0.058200
# 186459  -0.081198
# 186460   0.184768
# 186461  -0.126793
# 186462   0.012317
#
# [941 rows x 1 columns],         xs_return
# 186463  -0.190241
# 186464   0.050171
# 186465  -0.109974
# 186466   0.044131
# 186467  -0.081872
# ...           ...
# 187445  -0.107937
# 187446  -0.023582
# 187447   0.122640
# 187448   0.004667
# 187449  -0.067691
#
# [987 rows x 1 columns],         xs_return
# 187450  -0.005452
# 187451   0.107072
# 187452   0.097709
# 187453   0.200881
# 187454  -0.077192
# ...           ...
# 188429  -0.094796
# 188430  -0.042409
# 188431  -0.017800
# 188432  -0.054895
# 188433  -0.089485
#
# [984 rows x 1 columns],         xs_return
# 188434   0.094288
# 188435  -0.176864
# 188436  -0.018270
# 188437  -0.011760
# 188438   0.128953
# ...           ...
# 189408  -0.050052
# 189409   0.149535
# 189410  -0.131734
# 189411   0.085739
# 189412  -0.012598
#
# [979 rows x 1 columns],         xs_return
# 189413   0.151333
# 189414  -0.077647
# 189415  -0.114041
# 189416   0.021753
# 189417   0.185690
# ...           ...
# 190382   0.065235
# 190383   0.049817
# 190384  -0.067616
# 190385  -0.003794
# 190386  -0.125827
#
# [973 rows x 1 columns],         xs_return
# 190387  -0.087765
# 190388  -0.230067
# 190389  -0.048710
# 190390  -0.109865
# 190391   0.146136
# ...           ...
# 191353   0.055890
# 191354  -0.026301
# 191355   0.020727
# 191356   0.066374
# 191357  -0.117052
#
# [970 rows x 1 columns],         xs_return
# 191358   0.002407
# 191359  -0.069543
# 191360  -0.096413
# 191361  -0.298013
# 191362  -0.009402
# ...           ...
# 192315  -0.045373
# 192316  -0.120395
# 192317  -0.038890
# 192318  -0.057728
# 192319  -0.087804
#
# [961 rows x 1 columns],         xs_return
# 192320  -0.079216
# 192321   0.017753
# 192322  -0.113572
# 192323   0.222356
# 192324  -0.063670
# ...           ...
# 193276  -0.018578
# 193277   0.204434
# 193278   0.159561
# 193279   0.045484
# 193280  -0.010558
#
# [960 rows x 1 columns],         xs_return
# 193281  -0.079987
# 193282   0.230089
# 193283   0.010928
# 193284  -0.069288
# 193285  -0.263685
# ...           ...
# 194235  -0.125869
# 194236  -0.137406
# 194237   0.112807
# 194238   0.127561
# 194239   0.012879
#
# [958 rows x 1 columns],         xs_return
# 194240   0.028473
# 194241  -0.107557
# 194242  -0.054400
# 194243   0.043025
# 194244  -0.004923
# ...           ...
# 195227   0.087661
# 195228   0.117890
# 195229  -0.043090
# 195230  -0.026489
# 195231  -0.048505
#
# [991 rows x 1 columns],         xs_return
# 195232   0.092513
# 195233   0.032287
# 195234   0.079031
# 195235  -0.015691
# 195236   0.109128
# ...           ...
# 196218   0.020931
# 196219  -0.066175
# 196220   0.092919
# 196221   0.068668
# 196222  -0.029583
#
# [990 rows x 1 columns],         xs_return
# 196223   0.054260
# 196224   0.060851
# 196225   0.241878
# 196226   0.075797
# 196227   0.084632
# ...           ...
# 197207   0.027923
# 197208   0.166666
# 197209   0.025416
# 197210   0.114534
# 197211   0.068780
#
# [988 rows x 1 columns],         xs_return
# 197212  -0.027687
# 197213   0.012910
# 197214  -0.007775
# 197215  -0.263509
# 197216  -0.081683
# ...           ...
# 198197   0.174780
# 198198  -0.045508
# 198199  -0.043495
# 198200   0.059951
# 198201  -0.030697
#
# [989 rows x 1 columns],         xs_return
# 198202   0.059676
# 198203  -0.078384
# 198204  -0.030614
# 198205  -0.012158
# 198206  -0.042800
# ...           ...
# 199183   0.055561
# 199184  -0.096602
# 199185  -0.124442
# 199186  -0.085626
# 199187  -0.157842
#
# [985 rows x 1 columns],         xs_return
# 199188  -0.032311
# 199189  -0.067698
# 199190  -0.082001
# 199191  -0.010290
# 199192   0.104715
# ...           ...
# 200164  -0.058831
# 200165   0.038653
# 200166   0.095751
# 200167   0.055629
# 200168  -0.004518
#
# [980 rows x 1 columns],         xs_return
# 200169  -0.209165
# 200170  -0.074833
# 200171  -0.190480
# 200172   0.057502
# 200173   0.095250
# ...           ...
# 201148  -0.175731
# 201149  -0.229561
# 201150  -0.255088
# 201151  -0.132071
# 201152  -0.223219
#
# [984 rows x 1 columns],         xs_return
# 201153  -0.096671
# 201154  -0.038886
# 201155  -0.081515
# 201156   0.100474
# 201157   0.050586
# ...           ...
# ...
# 260346   0.195021
# 260347  -0.227554
#
# [951 rows x 1 columns],         xs_return
# 260348  -0.059815
# 260349  -0.166837
# 260350   0.058889
# 260351   0.034022
# 260352   0.029366
# ...           ...
# 261298  -0.082204
# 261299  -0.085406
# 261300   0.030266
# 261301   0.003330
# 261302   0.030510
#
# [947 rows x 1 columns],         xs_return
# 261303  -0.027817
# 261304   0.140716
# 261305   0.133977
# 261306   0.117356
# 261307   0.045641
# ...           ...
# 262254   0.094817
# 262255  -0.065615
# 262256   0.189378
# 262257   0.040473
# 262258  -0.042269
#
# [948 rows x 1 columns],         xs_return
# 262259   0.204503
# 262260   0.012881
# 262261   0.087955
# 262262  -0.270298
# 262263   0.075080
# ...           ...
# 263207  -0.038399
# 263208   0.084337
# 263209   0.740145
# 263210   0.039116
# 263211  -0.075235
#
# [944 rows x 1 columns],         xs_return
# 263212  -0.039069
# 263213  -0.088519
# 263214  -0.007397
# 263215   0.225288
# 263216   0.197769
# ...           ...
# 264157  -0.277693
# 264158  -0.211268
# 264159   0.113277
# 264160   0.809235
# 264161   0.362194
#
# [941 rows x 1 columns],         xs_return
# 264162   0.186755
# 264163   0.138312
# 264164   0.037433
# 264165   0.027459
# 264166  -0.092702
# ...           ...
# 265120  -0.088150
# 265121   0.024831
# 265122  -0.013149
# 265123  -0.003916
# 265124   0.092234
#
# [950 rows x 1 columns],         xs_return
# 265125   0.068618
# 265126  -0.011546
# 265127   0.019666
# 265128   0.025901
# 265129  -0.039656
# ...           ...
# 266082   0.118122
# 266083   0.448237
# 266084  -0.138615
# 266085   0.067941
# 266086  -0.083432
#
# [948 rows x 1 columns],         xs_return
# 266087   0.144941
# 266088   0.141368
# 266089   0.005420
# 266090  -0.063568
# 266091   0.078091
# ...           ...
# 267044  -0.000883
# 267045  -0.108643
# 267046  -0.107290
# 267047   0.029407
# 267048   0.005327
#
# [947 rows x 1 columns],         xs_return
# 267049  -0.058912
# 267050   0.117326
# 267051  -0.106926
# 267052   0.082187
# 267053   0.019625
# ...           ...
# 268007  -0.018995
# 268008  -0.091731
# 268009   0.132129
# 268010   0.011119
# 268011  -0.028055
#
# [944 rows x 1 columns],         xs_return
# 268012  -0.031923
# 268013  -0.017562
# 268014  -0.015520
# 268015  -0.043623
# 268016  -0.035496
# ...           ...
# 268973  -0.032826
# 268974  -0.005472
# 268975  -0.140568
# 268976   0.114435
# 268977  -0.105518
#
# [945 rows x 1 columns],         xs_return
# 268978   0.060214
# 268979   0.211548
# 268980   0.057017
# 268981   0.104373
# 268982  -0.170914
# ...           ...
# 269938   0.050276
# 269939  -0.120018
# 269940  -0.042222
# 269941   0.046856
# 269942   0.027319
#
# [944 rows x 1 columns],         xs_return
# 269943  -0.168648
# 269944  -0.059185
# 269945   0.028344
# 269946  -0.086092
# 269947   0.080615
# ...           ...
# 270903   0.015164
# 270904   0.235531
# 270905  -0.179216
# 270906   0.051731
# 270907   0.047656
#
# [940 rows x 1 columns],         xs_return
# 270908  -0.024967
# 270909   0.006171
# 270910   0.101163
# 270911   0.006947
# 270912  -0.131674
# ...           ...
# 271870  -0.040376
# 271871  -0.149636
# 271872   0.008233
# 271873   0.067488
# 271874  -0.107820
#
# [940 rows x 1 columns],         xs_return
# 271875   0.003388
# 271876  -0.080334
# 271877  -0.010647
# 271878   0.150231
# 271879  -0.052268
# ...           ...
# 272835  -0.078902
# 272836   0.016858
# 272837   0.094321
# 272838   0.101701
# 272839   0.008299
#
# [938 rows x 1 columns],         xs_return
# 272840  -0.103274
# 272841  -0.132965
# 272842   0.095205
# 272843   0.120055
# 272844   0.060301
# ...           ...
# 273802   0.014974
# 273803   0.055075
# 273804   0.139859
# 273805  -0.169669
# 273806  -0.100069
#
# [938 rows x 1 columns],         xs_return
# 273807   0.119604
# 273808   0.044013
# 273809   0.001974
# 273810   0.111066
# 273811   0.081750
# ...           ...
# 274768   0.026089
# 274769  -0.017030
# 274770   0.405304
# 274771  -0.036051
# 274772   0.091138
#
# [937 rows x 1 columns],         xs_return
# 274773   0.005552
# 274774   0.175126
# 274775  -0.062334
# 274776   0.017004
# 274777   0.044404
# ...           ...
# 275730  -0.054811
# 275731  -0.139812
# 275732  -0.095546
# 275733   0.008606
# 275734  -0.335626
#
# [960 rows x 1 columns],         xs_return
# 275735   0.038843
# 275736   0.397246
# 275737   0.024209
# 275738   0.024109
# 275739   0.002080
# ...           ...
# 276702  -0.037260
# 276703  -0.119637
# 276704  -0.000686
# 276705  -0.086999
# 276706   0.051511
#
# [971 rows x 1 columns],         xs_return
# 276707  -0.018291
# 276708   0.120083
# 276709   0.108409
# 276710   0.036802
# 276711   0.212613
# ...           ...
# 277674   0.020257
# 277675  -0.018199
# 277676   0.086891
# 277677   0.028043
# 277678  -0.042404
#
# [969 rows x 1 columns],         xs_return
# 277679   0.026962
# 277680   0.299387
# 277681   0.057507
# 277682  -0.098652
# 277683   0.047027
# ...           ...
# 278642   0.007478
# 278643   0.171488
# 278644   0.034698
# 278645  -0.580744
# 278646  -0.002950
#
# [964 rows x 1 columns],         xs_return
# 278647   0.077441
# 278648   0.072362
# 278649   0.018236
# 278650  -0.238311
# 278651  -0.046752
# ...           ...
# 279618   0.096008
# 279619  -0.279680
# 279620  -0.079256
# 279621  -0.038793
# 279622   0.029145
#
# [968 rows x 1 columns],         xs_return
# 279623  -0.114263
# 279624   0.033514
# 279625  -0.039368
# 279626  -0.148884
# 279627   0.055458
# ...           ...
# 280591   0.230076
# 280592   0.136636
# 280593  -0.117152
# 280594  -0.144597
# 280595   0.091370
#
# [973 rows x 1 columns],         xs_return
# 280596  -0.017539
# 280597  -0.010161
# 280598  -0.219029
# 280599  -0.135704
# 280600  -0.066690
# ...           ...
# 281566   0.009764
# 281567   0.085945
# 281568   0.008986
# 281569   0.202957
# 281570  -0.020363
#
# [973 rows x 1 columns],         xs_return
# 281571   0.044247
# 281572   0.049640
# 281573   0.002867
# 281574   0.041096
# 281575   0.012874
# ...           ...
# 282550  -0.056364
# 282551  -0.391565
# 282552  -0.025982
# 282553  -0.109518
# 282554   0.164874
#
# [982 rows x 1 columns],         xs_return
# 282555   0.006388
# 282556  -0.137321
# 282557  -0.050806
# 282558  -0.072834
# 282559   0.046332
# ...           ...
# 283535   0.068121
# 283536  -0.032106
# 283537  -0.214707
# 283538   0.225010
# 283539   0.076402
#
# [983 rows x 1 columns],         xs_return
# 283540  -0.073777
# 283541   0.099309
# 283542   0.001849
# 283543   0.015289
# 283544  -0.074773
# ...           ...
# 284519  -0.035718
# 284520   0.228127
# 284521  -0.495372
# 284522   0.013596
# 284523  -0.182346
#
# [983 rows x 1 columns],         xs_return
# 284524  -0.114361
# 284525  -0.657979
# 284526   0.006197
# 284527  -0.294845
# 284528   0.147463
# ...           ...
# 285506   0.019610
# 285507   0.176818
# 285508   0.036282
# 285509  -0.031846
# 285510   0.093483
#
# [986 rows x 1 columns],         xs_return
# 285511   0.046908
# 285512  -0.548185
# 285513  -0.289965
# 285514   0.146989
# 285515   0.114366
# ...           ...
# 286495   0.032921
# 286496  -0.163826
# 286497   0.018174
# 286498  -0.037516
# 286499   0.014788
#
# [986 rows x 1 columns],         xs_return
# 286500  -0.259326
# 286501   0.116181
# 286502  -0.030223
# 286503  -0.158580
# 286504   0.129645
# ...           ...
# 287516   0.095453
# 287517  -0.241429
# 287518  -0.077863
# 287519  -0.002672
# 287520  -0.037021
#
# [1015 rows x 1 columns],         xs_return
# 287521   0.087324
# 287522   0.075166
# 287523   0.101049
# 287524   0.002181
# 287525  -0.074706
# ...           ...
# 288545   0.031551
# 288546   0.392546
# 288547   0.019058
# 288548   0.105423
# 288549   0.016883
#
# [1021 rows x 1 columns],         xs_return
# 288550  -0.224626
# 288551  -0.012198
# 288552  -0.062405
# 288553   0.057174
# 288554   0.066343
# ...           ...
# 289575   0.032203
# 289576   0.085838
# 289577   0.048889
# 289578  -0.047676
# 289579   0.001055
#
# [1023 rows x 1 columns],         xs_return
# 289580   0.001454
# 289581   0.066783
# 289582  -0.043834
# 289583  -0.010328
# 289584  -0.032444
# ...           ...
# 290606   0.043093
# 290607   0.216480
# 290608   0.042148
# 290609  -0.041927
# 290610  -0.180417
#
# [1031 rows x 1 columns],         xs_return
# 290611   0.067105
# 290612  -0.134095
# 290613  -0.069630
# 290614  -0.000623
# 290615   0.050319
# ...           ...
# 291643   0.207052
# 291644   0.040755
# 291645  -0.015986
# 291646  -0.031745
# 291647   0.011308
#
# [1036 rows x 1 columns],         xs_return
# 291648  -0.043797
# 291649  -0.037938
# 291650  -0.014141
# 291651   0.003201
# 291652   0.085344
# ...           ...
# 292676  -0.058798
# 292677   0.195315
# 292678  -0.040810
# 292679  -0.023420
# 292680   0.016217
#
# [1030 rows x 1 columns],         xs_return
# 292681   0.052253
# 292682   0.205297
# 292683  -0.037511
# 292684   0.068509
# 292685  -0.108982
# ...           ...
# 293708  -0.007584
# 293709   0.109139
# 293710  -0.183058
# 293711  -0.283988
# 293712  -0.032725
#
# [1031 rows x 1 columns],         xs_return
# 293713   0.169933
# 293714   0.026297
# 293715  -0.032130
# 293716  -0.065890
# 293717  -0.561010
# ...           ...
# 294742   0.132411
# 294743   0.061604
# 294744   0.147335
# 294745   0.040423
# 294746  -0.110670
#
# [1034 rows x 1 columns],         xs_return
# 294747   0.037779
# 294748   0.029874
# 294749  -0.049465
# 294750   0.173760
# 294751   0.099310
# ...           ...
# 295777  -0.202847
# 295778  -0.177397
# 295779  -0.032332
# 295780   0.027436
# 295781  -0.104676
#
# [1034 rows x 1 columns],         xs_return
# 295782  -0.129994
# 295783  -0.069087
# 295784   0.078849
# 295785   0.052983
# 295786  -0.144526
# ...           ...
# 296812   0.099771
# 296813  -0.076806
# 296814   0.068796
# 296815  -0.011855
# 296816  -0.076385
#
# [1035 rows x 1 columns],         xs_return
# 296817   0.027366
# 296818  -0.061400
# 296819  -0.097275
# 296820   0.121389
# 296821  -0.076092
# ...           ...
# 297846  -0.040048
# 297847  -0.159352
# 297848  -0.037641
# 297849   0.036916
# 297850   0.154676
#
# [1034 rows x 1 columns],         xs_return
# 297851   0.046915
# 297852   0.007885
# 297853   0.128513
# 297854  -0.071506
# 297855  -0.016737
# ...           ...
# 298880   0.099258
# 298881  -0.253565
# 298882  -0.217471
# 298883  -0.196596
# 298884   0.177211
#
# [1034 rows x 1 columns],         xs_return
# 298885  -0.229796
# 298886   0.188530
# 298887   0.018418
# 298888  -0.091647
# 298889  -0.028629
# ...           ...
# 299904  -0.024426
# 299905   0.000197
# 299906  -0.166545
# 299907   0.031735
# 299908   0.017008
#
# [1024 rows x 1 columns],         xs_return
# 299909   0.057871
# 299910   0.035770
# 299911  -0.023375
# 299912   0.003880
# 299913   0.001613
# ...           ...
# 300931  -0.044724
# 300932  -0.004703
# 300933   0.019559
# 300934  -0.018747
# 300935  -0.112233
#
# [1019 rows x 1 columns],         xs_return
# 300936   0.192298
# 300937   0.082188
# 300938  -0.039453
# 300939   0.212800
# 300940   0.001126
# ...           ...
# 301957   0.164324
# 301958   0.063660
# 301959   0.154841
# 301960   0.045357
# 301961  -0.001001
#
# [1026 rows x 1 columns],         xs_return
# 301962  -0.013494
# 301963   0.176241
# 301964  -0.091785
# 301965   0.108688
# 301966   0.102561
# ...           ...
# 302985   0.192654
# 302986   0.160444
# 302987  -0.004399
# 302988   0.057691
# 302989  -0.091529
#
# [1028 rows x 1 columns],         xs_return
# 302990   0.045665
# 302991   0.022775
# 302992   0.162997
# 302993   0.402544
# 302994   0.140578
# ...           ...
# 304014  -0.047270
# 304015  -0.006484
# 304016   0.026125
# 304017  -0.089231
# 304018  -0.020439
#
# [1026 rows x 1 columns],         xs_return
# 304019   0.096481
# 304020  -0.120024
# 304021  -0.057229
# 304022   0.111413
# 304023  -0.085783
# ...           ...
# 305045   0.119804
# 305046   0.217277
# 305047   0.009691
# 305048  -0.031206
# 305049   0.190374
#
# [1026 rows x 1 columns],         xs_return
# 305050   0.295906
# 305051   0.032818
# 305052  -0.158847
# 305053  -0.043399
# 305054   0.186618
# ...           ...
# 306072   0.088658
# 306073  -0.057231
# 306074  -0.044745
# 306075  -0.034737
# 306076  -0.073507
#
# [1022 rows x 1 columns],         xs_return
# 306077  -0.098683
# 306078   0.032563
# 306079  -0.060568
# 306080   0.093745
# 306081   0.036333
# ...           ...
# 307097  -0.038398
# 307098  -0.046601
# 307099   0.455831
# 307100  -0.030606
# 307101   0.062684
#
# [1023 rows x 1 columns],         xs_return
# 307102   0.086345
# 307103   0.357218
# 307104   0.083714
# 307105   0.055760
# 307106  -0.195963
# ...           ...
# 308120  -0.100323
# 308121  -0.030181
# 308122  -0.041739
# 308123  -0.169007
# 308124   0.049940
#
# [1022 rows x 1 columns],         xs_return
# 308125   0.036160
# 308126  -0.015495
# 308127   0.008593
# 308128  -0.001804
# 308129  -0.038531
# ...           ...
# 309139   0.175758
# 309140  -0.055387
# 309141  -0.142324
# 309142   0.039675
# 309143  -0.096069
#
# [1018 rows x 1 columns],         xs_return
# 309144  -0.091830
# 309145   0.031907
# 309146  -0.100640
# 309147   0.013282
# 309148   0.141944
# ...           ...
# 310152   0.020082
# 310153   0.067723
# 310154  -0.060181
# 310155  -0.124128
# 310156  -0.058443
#
# [1012 rows x 1 columns],         xs_return
# 310157   0.187494
# 310158   0.268502
# 310159   0.143492
# 310160   0.128608
# 310161  -0.218743
# ...           ...
# 311167  -0.152772
# 311168  -0.068497
# 311169   0.040015
# 311170  -0.235635
# 311171  -0.053031
#
# [1008 rows x 1 columns],         xs_return
# 311172   0.085195
# 311173  -0.119123
# 311174   0.056668
# 311175   0.040562
# 311176  -0.084896
# ...           ...
# 312180  -0.040176
# 312181   0.092279
# 312182  -0.033644
# 312183  -0.136231
# 312184  -0.010033
#
# [1011 rows x 1 columns],         xs_return
# 312185  -0.016589
# 312186  -0.024084
# 312187  -0.015608
# 312188  -0.007163
# 312189  -0.078238
# ...           ...
# 313176  -0.323345
# 313177  -0.025910
# 313178  -0.010684
# 313179   0.014123
# 313180  -0.119447
#
# [994 rows x 1 columns],         xs_return
# 313181   0.083498
# 313182   0.057803
# 313183   0.055574
# 313184  -0.000885
# 313185  -0.124583
# ...           ...
# 314175  -0.001267
# 314176   0.093657
# 314177  -0.315753
# 314178  -0.085791
# 314179   0.014127
#
# [999 rows x 1 columns],         xs_return
# 314180   0.119776
# 314181  -0.145160
# 314182   0.047725
# 314183   0.000887
# 314184   0.052365
# ...           ...
# 315165   0.025200
# 315166   0.146407
# 315167  -0.049831
# 315168   0.067583
# 315169   0.202940
#
# [990 rows x 1 columns],         xs_return
# 315170   0.061531
# 315171  -0.092834
# 315172  -0.083373
# 315173   0.301704
# 315174   0.025101
# ...           ...
# 316162   0.315647
# 316163  -0.086705
# 316164   0.038225
# 316165   0.109467
# 316166   0.080796
#
# [992 rows x 1 columns],         xs_return
# 316167  -0.148632
# 316168   0.087535
# 316169  -0.220128
# 316170  -0.022503
# 316171   0.011920
# ...           ...
# 317157  -0.093728
# 317158  -0.153653
# 317159   0.106289
# 317160  -0.138299
# 317161  -0.115739
#
# [991 rows x 1 columns],         xs_return
# 317162  -0.096815
# 317163   0.077750
# 317164  -0.013827
# 317165   0.002461
# 317166  -0.091037
# ...           ...
# 318150   0.085526
# 318151   0.082965
# 318152   0.036148
# 318153  -0.178833
# 318154   0.063136
#
# [991 rows x 1 columns],         xs_return
# 318155  -0.038145
# 318156  -0.319774
# 318157   0.066304
# 318158  -0.075949
# 318159  -0.130112
# ...           ...
# 319142   0.005682
# 319143   0.054968
# 319144   0.048501
# 319145   0.106549
# 319146  -0.040562
#
# [988 rows x 1 columns],         xs_return
# 319147  -0.158906
# 319148   0.030853
# 319150   0.043185
# 319151   0.061386
# 319152   0.110300
# ...           ...
# 320141  -0.053221
# 320142  -0.070708
# 320143   0.152069
# 320144   0.081127
# 320145  -0.105531
#
# [993 rows x 1 columns],         xs_return
# 320146   0.053637
# 320147  -0.073954
# 320148   0.051057
# 320149  -0.057044
# 320150   0.020703
# ...           ...
# 321137   0.025668
# 321138  -0.017893
# 321139   0.062097
# 321140  -0.206763
# 321141  -0.243906
#
# [996 rows x 1 columns],         xs_return
# 321142   0.302740
# 321143   0.000712
# 321144  -0.246326
# 321145   0.061548
# 321146  -0.258392
# ...           ...
# 322134  -0.054230
# 322135   0.104355
# 322136   0.028792
# 322137   0.007074
# 322138  -0.029700
#
# [997 rows x 1 columns],         xs_return
# 322139  -0.030105
# 322140   0.184023
# 322141  -0.020312
# 322142   0.178501
# 322143  -0.082132
# ...           ...
# 323130  -0.124877
# 323131  -0.150426
# 323132   0.102472
# 323133  -0.017021
# 323134   0.076186
#
# [996 rows x 1 columns],         xs_return
# 323135   0.179187
# 323136   0.138008
# 323137  -0.031551
# 323138   0.035266
# 323139  -0.054951
# ...           ...
# 324122  -0.161097
# 324123   0.007234
# 324124  -0.114722
# 324125  -0.021013
# 324126  -0.274870
#
# [992 rows x 1 columns],         xs_return
# 324127   0.109979
# 324128   0.074553
# 324129  -0.252338
# 324130   0.178925
# 324131   0.090516
# ...           ...
# 325106  -0.178692
# 325107   0.058276
# 325108  -0.084064
# 325109  -0.006748
# 325110   0.096230
#
# [984 rows x 1 columns],         xs_return
# 325111   0.042818
# 325112   0.056687
# 325113  -0.087541
# 325114  -0.094343
# 325115  -0.224205
# ...           ...
# 325873   0.001853
# 325874  -0.116442
# 325875  -0.020435
# 325876  -0.022288
# 325877  -0.125507
#
# [767 rows x 1 columns]]

# %%
print(ys['test_PLS'])
# Out:
# [            x
# 0   -0.157558
# 1    0.050256
# 2   -0.014424
# 3   -0.043486
# 4    0.019946
# ..        ...
# 940  0.033861
# 941  0.181684
# 942  0.192743
# 943 -0.041043
# 944 -0.156577
#
# [945 rows x 1 columns],             x
# 0   -0.074912
# 1    0.345704
# 2    0.144951
# 3   -0.240155
# 4   -0.131292
# ..        ...
# 942 -0.015293
# 943 -0.051648
# 944 -0.199777
# 945  0.080769
# 946 -0.059249
#
# [947 rows x 1 columns],             x
# 0    0.096076
# 1    0.205841
# 2    0.067402
# 3   -0.019490
# 4   -0.089756
# ..        ...
# 941  0.049919
# 942 -0.130796
# 943 -0.128335
# 944 -0.051583
# 945 -0.318678
#
# [946 rows x 1 columns],             x
# 0    0.001278
# 1   -0.064058
# 2    0.123117
# 3   -0.188325
# 4    0.092776
# ..        ...
# 942  0.070254
# 943 -0.032192
# 944  0.023870
# 945 -0.151788
# 946  0.104951
#
# [947 rows x 1 columns],             x
# 0   -0.201126
# 1    0.022738
# 2   -0.280591
# 3    0.437094
# 4    0.214574
# ..        ...
# 941 -0.070136
# 942  0.086033
# 943  0.091646
# 944 -0.018534
# 945 -0.271926
#
# [946 rows x 1 columns],             x
# 0   -0.135725
# 1    0.095100
# 2   -0.191923
# 3    0.003601
# 4   -0.278328
# ..        ...
# 969  0.202389
# 970  0.044396
# 971  0.100054
# 972  0.073682
# 973  0.170733
#
# [974 rows x 1 columns],             x
# 0   -0.282890
# 1   -0.173572
# 2    0.222201
# 3   -0.322937
# 4    0.068541
# ..        ...
# 967 -0.324862
# 968 -0.151809
# 969  0.037685
# 970  0.075929
# 971 -0.079144
#
# [972 rows x 1 columns],             x
# 0    0.028795
# 1    0.205711
# 2    0.108170
# 3   -0.090219
# 4    0.006756
# ..        ...
# 962 -0.099453
# 963 -0.306129
# 964 -0.035931
# 965 -0.070239
# 966 -0.135039
#
# [967 rows x 1 columns],             x
# 0    0.210095
# 1   -0.135233
# 2    0.232562
# 3    0.299054
# 4   -0.094564
# ..        ...
# 959  0.395956
# 960 -0.005228
# 961  0.260068
# 962  0.189519
# 963  0.208302
#
# [964 rows x 1 columns],             x
# 0   -0.076555
# 1    0.199486
# 2    0.072728
# 3    0.053883
# 4    0.019756
# ..        ...
# 961  0.270604
# 962 -0.081502
# 963  0.092909
# 964 -0.054484
# 965  0.009461
#
# [966 rows x 1 columns],             x
# 0   -0.067716
# 1    0.140800
# 2    0.196810
# 3    0.160478
# 4   -0.132698
# ..        ...
# 964  0.405696
# 965  0.109084
# 966 -0.008413
# 967  0.010672
# 968 -0.099930
#
# [969 rows x 1 columns],             x
# 0    0.652782
# 1   -0.083362
# 2   -0.188998
# 3    0.051269
# 4   -0.117788
# ..        ...
# 961 -0.040353
# 962 -0.194089
# 963  0.004069
# 964 -0.052457
# 965  0.116892
#
# [966 rows x 1 columns],             x
# 0    0.081521
# 1    0.023642
# 2   -0.080511
# 3   -0.010116
# 4    0.155753
# ..        ...
# 960 -0.098461
# 961  0.589288
# 962  0.142036
# 963 -0.057817
# 964 -0.082285
#
# [965 rows x 1 columns],             x
# 0    0.022875
# 1   -0.053694
# 2   -0.062595
# 3   -0.035485
# 4    0.027202
# ..        ...
# 960 -0.208717
# 961 -0.086872
# 962  0.073119
# 963  0.081325
# 964  0.043283
#
# [965 rows x 1 columns],             x
# 0   -0.195762
# 1   -0.104409
# 2   -0.025126
# 3   -0.062401
# 4   -0.000939
# ..        ...
# 956  0.044420
# 957  0.014626
# 958  0.059827
# 959  0.005419
# 960 -0.118759
#
# [961 rows x 1 columns],             x
# 0   -0.059473
# 1    0.004255
# 2    0.085201
# 3    0.223437
# 4    0.074246
# ..        ...
# 958  0.034644
# 959 -0.061396
# 960  0.280531
# 961  0.063256
# 962 -0.009605
#
# [963 rows x 1 columns],             x
# 0   -0.022144
# 1   -0.021019
# 2    0.018456
# 3    0.239060
# 4    0.040747
# ..        ...
# 959  0.315819
# 960  0.047164
# 961  0.027622
# 962  0.027609
# 963  0.054567
#
# [964 rows x 1 columns],             x
# 0    0.075653
# 1    0.073041
# 2    0.107381
# 3    0.058398
# 4    0.046506
# ..        ...
# 968 -0.031218
# 969 -0.030804
# 970  0.059485
# 971 -0.071382
# 972  0.007706
#
# [973 rows x 1 columns],             x
# 0    0.018564
# 1   -0.218013
# 2   -0.155012
# 3    0.018625
# 4    0.289980
# ..        ...
# 968 -0.154840
# 969  0.169300
# 970  0.130311
# 971 -0.141611
# 972  0.053422
#
# [973 rows x 1 columns],             x
# 0   -0.146697
# 1   -0.091126
# 2   -0.210121
# 3   -0.204656
# 4   -0.035013
# ..        ...
# 970 -0.054862
# 971  0.274493
# 972  0.015320
# 973 -0.007468
# 974 -0.175478
#
# [975 rows x 1 columns],             x
# 0   -0.090372
# 1   -0.068197
# 2   -0.145743
# 3    0.193479
# 4   -0.139047
# ..        ...
# 966 -0.072826
# 967 -0.142074
# 968  0.178754
# 969  0.219965
# 970 -0.106126
#
# [971 rows x 1 columns],             x
# 0    0.089692
# 1    0.025275
# 2    0.442711
# 3    0.039898
# 4   -0.015801
# ..        ...
# 967  0.094132
# 968 -0.102720
# 969  0.047808
# 970 -0.051646
# 971  0.044571
#
# [972 rows x 1 columns],             x
# 0    0.143027
# 1    0.288356
# 2    0.013150
# 3    0.070415
# 4    0.019808
# ..        ...
# 965  0.036502
# 966 -0.045316
# 967  0.304110
# 968  0.008530
# 969 -0.118258
#
# [970 rows x 1 columns],             x
# 0   -0.319274
# 1    0.209614
# 2    0.434117
# 3    0.167035
# 4    0.110699
# ..        ...
# 961 -0.143868
# 962  0.015031
# 963  0.056570
# 964 -0.183375
# 965 -0.108906
#
# [966 rows x 1 columns],             x
# 0   -0.012235
# 1   -0.089748
# 2   -0.295494
# 3   -0.027469
# 4   -0.096435
# ..        ...
# 960  0.047543
# 961  0.045233
# 962 -0.008922
# 963  0.028717
# 964  0.086008
#
# [965 rows x 1 columns],             x
# 0    0.057668
# 1   -0.171413
# 2   -0.068627
# 3   -0.332555
# 4    0.116229
# ..        ...
# 960  0.204432
# 961  0.018938
# 962  0.146964
# 963  0.100157
# 964  0.052334
#
# [965 rows x 1 columns],             x
# 0   -0.162988
# 1   -0.072554
# 2   -0.484293
# 3   -0.219597
# 4    0.146631
# ..        ...
# 956 -0.192362
# 957  0.292746
# 958  0.077644
# 959 -0.094256
# 960  0.125915
#
# [961 rows x 1 columns],             x
# 0    0.070405
# 1    0.005999
# 2    0.051553
# 3   -0.161038
# 4    0.071455
# ..        ...
# 955  0.003668
# 956 -0.190122
# 957  0.053569
# 958  0.016456
# 959 -0.116039
#
# [960 rows x 1 columns],             x
# 0   -0.076283
# 1   -0.179400
# 2    0.037125
# 3    0.097378
# 4   -0.142754
# ..        ...
# 955 -0.043800
# 956  0.264350
# 957  0.012738
# 958 -0.583286
# 959 -0.066933
#
# [960 rows x 1 columns],             x
# 0   -0.177482
# 1    0.053508
# 2    0.035019
# 3    0.015115
# 4   -0.168298
# ..        ...
# 966  0.075305
# 967 -0.007693
# 968  0.085161
# 969  0.213443
# 970 -0.001097
#
# [971 rows x 1 columns],             x
# 0    0.088774
# 1   -0.048644
# 2    0.092057
# 3    0.856382
# 4    0.167330
# ..        ...
# 971  0.009418
# 972  0.003319
# 973  0.119986
# 974 -0.224265
# 975 -0.116782
#
# [976 rows x 1 columns],             x
# 0    0.001908
# 1    0.161733
# 2   -0.060377
# 3    0.110580
# 4    0.103138
# ..        ...
# 972 -0.126274
# 973 -0.130514
# 974  0.216498
# 975 -0.430212
# 976 -0.143843
#
# [977 rows x 1 columns],             x
# 0    0.015241
# 1    0.085051
# 2    0.118348
# 3   -0.108861
# 4   -0.085793
# ..        ...
# 972  0.194352
# 973 -0.062940
# 974 -0.239394
# 975 -0.010167
# 976 -0.079916
#
# [977 rows x 1 columns],             x
# 0    0.069615
# 1    2.651346
# 2   -0.066766
# 3    0.048765
# 4   -0.039720
# ..        ...
# 971  0.033250
# 972 -0.049659
# 973  0.040056
# 974  0.159589
# 975  0.084257
#
# [976 rows x 1 columns],             x
# 0   -0.104884
# 1    0.072170
# 2   -0.227567
# 3    0.027585
# 4   -0.061395
# ..        ...
# 971 -0.166923
# 972  0.007717
# 973  0.047313
# 974  0.065156
# 975 -0.051520
#
# [976 rows x 1 columns],             x
# 0    0.014624
# 1   -0.016138
# 2    0.005064
# 3    0.010862
# 4   -0.065064
# ..        ...
# 970  0.112166
# 971  0.094211
# 972 -0.055271
# 973 -0.047346
# 974 -0.036247
#
# [975 rows x 1 columns],             x
# 0    0.199561
# 1    0.115508
# 2    0.186669
# 3    0.095169
# 4    0.167083
# ..        ...
# 969  0.021345
# 970 -0.077436
# 971  0.007942
# 972  0.142564
# 973  0.070436
#
# [974 rows x 1 columns],             x
# 0    0.029258
# 1    0.022660
# 2    0.066619
# 3   -0.026596
# 4   -0.000524
# ..        ...
# 969  0.109551
# 970 -0.158223
# 971 -0.143632
# 972 -0.204413
# 973  0.006579
#
# [974 rows x 1 columns],             x
# 0   -0.090443
# 1    0.013478
# 2    0.001816
# 3   -0.030318
# 4   -0.126279
# ..        ...
# 969 -0.320591
# 970  0.080668
# 971 -0.045755
# 972  0.118361
# 973 -0.062880
#
# [974 rows x 1 columns],             x
# 0   -0.104513
# 1    0.002161
# 2    0.030317
# 3   -0.013324
# 4   -0.292207
# ..        ...
# 970 -0.073054
# 971 -0.109380
# 972  0.220588
# 973  0.147156
# 974  0.041463
#
# [975 rows x 1 columns],             x
# 0    0.096660
# 1    0.756020
# 2   -0.005880
# 3   -0.092075
# 4   -0.021356
# ..        ...
# 970 -0.134733
# 971 -0.038605
# 972  0.104155
# 973 -0.034052
# 974 -0.290243
#
# [975 rows x 1 columns],             x
# 0   -0.010613
# 1   -0.157015
# 2    0.161500
# 3    0.091937
# 4    0.072752
# ..        ...
# 963 -0.031988
# 964 -0.046941
# 965  0.006023
# 966  0.041318
# 967 -0.157779
#
# [968 rows x 1 columns],             x
# 0   -0.147241
# 1   -0.061174
# 2   -0.216818
# 3    0.064671
# 4    0.227364
# ..        ...
# 966  0.113091
# 967 -0.011470
# 968 -0.148105
# 969  0.070986
# 970  0.109592
#
# [971 rows x 1 columns],             x
# 0    0.165590
# 1    0.219599
# 2   -0.098528
# 3   -0.118146
# 4   -0.132866
# ..        ...
# 964  0.125547
# 965 -0.333442
# 966  0.095645
# 967  0.278227
# 968 -0.041026
#
# [969 rows x 1 columns],             x
# 0    0.093940
# 1   -0.014511
# 2   -0.071365
# 3   -0.141999
# 4   -0.069869
# ..        ...
# 961 -0.083260
# 962 -0.170975
# 963  0.133576
# 964  0.050685
# 965 -0.155943
#
# [966 rows x 1 columns],             x
# 0    0.125393
# 1   -0.058502
# 2   -0.020587
# 3    0.055836
# 4    0.182680
# ..        ...
# 961  0.115259
# 962  0.117766
# 963  0.235208
# 964 -0.035416
# 965  0.083178
#
# [966 rows x 1 columns],             x
# 0   -0.040868
# 1   -0.018755
# 2    0.087090
# 3   -0.034213
# 4   -0.084249
# ..        ...
# 960 -0.078571
# 961  0.148512
# 962 -0.072941
# 963  0.054609
# 964 -0.107369
#
# [965 rows x 1 columns],             x
# 0   -0.084318
# 1   -0.075740
# 2   -0.060310
# 3   -0.024106
# 4   -0.034801
# ..        ...
# 963 -0.011650
# 964  0.104594
# 965  0.047891
# 966  0.107209
# 967 -0.155786
#
# [968 rows x 1 columns],             x
# 0    0.190151
# 1    0.017796
# 2    0.087584
# 3   -0.077941
# 4   -0.132610
# ..        ...
# 965 -0.090050
# 966 -0.015751
# 967 -0.103787
# 968  0.033613
# 969 -0.150208
#
# [970 rows x 1 columns],             x
# 0   -0.093807
# 1    0.068609
# 2   -0.007852
# 3    0.057129
# 4   -0.020008
# ..        ...
# 963 -0.106833
# 964  0.045199
# 965  0.121305
# 966  0.139253
# 967  0.270560
#
# [968 rows x 1 columns],             x
# 0   -0.075566
# 1   -0.013071
# 2   -0.017429
# 3    0.030628
# 4   -0.057992
# ..        ...
# 967  0.091861
# 968  0.034600
# 969 -0.101764
# 970  0.135500
# 971 -0.118404
#
# [972 rows x 1 columns],             x
# 0    0.038919
# 1   -0.121248
# 2    0.101769
# 3   -0.028759
# 4    0.349431
# ..        ...
# 967  0.130034
# 968  0.063940
# 969 -0.061890
# 970  0.073069
# 971 -0.067271
#
# [972 rows x 1 columns],             x
# 0    0.013702
# 1   -0.027858
# 2   -0.113764
# 3   -0.084315
# 4    0.111701
# ..        ...
# 970  0.129938
# 971  0.060340
# 972 -0.013762
# 973  0.037469
# 974 -0.095705
#
# [975 rows x 1 columns],             x
# 0    0.415525
# 1    0.095716
# 2   -0.095617
# 3   -0.024386
# 4    0.014114
# ..        ...
# 966 -0.049778
# 967 -0.044390
# 968  0.005399
# 969  0.035024
# 970  0.022603
#
# [971 rows x 1 columns],             x
# 0    0.072276
# 1   -0.072807
# 2   -0.129208
# 3    0.034159
# 4   -0.022982
# ..        ...
# 966  0.024934
# 967  0.033831
# 968 -0.041747
# 969 -0.127299
# 970  0.017689
#
# [971 rows x 1 columns],             x
# 0    0.096703
# 1    0.039033
# 2    0.011878
# 3   -0.077346
# 4    0.142743
# ..        ...
# 963 -0.034909
# 964 -0.007572
# 965  0.107266
# 966 -0.052116
# 967 -0.046117
#
# [968 rows x 1 columns],             x
# 0   -0.011555
# 1    0.055330
# 2   -0.028349
# 3   -0.190478
# 4   -0.084488
# ..        ...
# 959  0.018456
# 960 -0.203920
# 961  0.076937
# 962  0.001935
# 963 -0.060038
#
# [964 rows x 1 columns],             x
# 0    0.017468
# 1    0.044507
# 2   -0.077252
# 3    0.002350
# 4    0.060222
# ..        ...
# 957  0.017872
# 958  0.042627
# 959 -0.219547
# 960 -0.130953
# 961 -0.046991
#
# [962 rows x 1 columns],             x
# 0   -0.200637
# 1   -0.089927
# 2    0.113259
# 3   -0.117482
# 4   -0.029675
# ..        ...
# 954  0.017464
# 955 -0.020199
# 956 -0.074580
# 957 -0.080992
# 958  0.220458
#
# [959 rows x 1 columns],             x
# 0   -0.107949
# 1    0.042064
# 2   -0.289868
# 3   -0.024932
# 4   -0.086849
# ..        ...
# 956  0.314087
# 957 -0.064039
# 958  0.009314
# 959 -0.085210
# 960 -0.088163
#
# [961 rows x 1 columns],             x
# 0   -0.004172
# 1   -0.049039
# 2    0.009484
# 3   -0.021054
# 4    0.019302
# ..        ...
# 954 -0.021015
# 955 -0.040589
# 956 -0.105463
# 957 -0.134352
# 958  0.006465
#
# [959 rows x 1 columns],             x
# 0   -0.396612
# 1   -0.074454
# 2    0.050820
# 3   -0.013669
# 4   -0.010281
# ..        ...
# 953 -0.072167
# 954  0.143808
# 955 -0.069890
# 956  0.068691
# 957  0.238770
#
# [958 rows x 1 columns],             x
# 0    0.007575
# 1   -0.049368
# 2   -0.095416
# 3   -0.050878
# 4    0.146972
# ..        ...
# 949 -0.042820
# 950 -0.091982
# 951 -0.091625
# 952  0.037916
# 953  0.111079
#
# [954 rows x 1 columns],             x
# 0   -0.026533
# 1    0.311070
# 2   -0.028337
# 3   -0.090572
# 4    0.008704
# ..        ...
# 946 -0.127155
# 947 -0.347856
# 948 -0.101656
# 949 -0.082128
# 950 -0.143533
#
# [951 rows x 1 columns],             x
# 0   -0.133331
# 1    0.050270
# 2    0.007619
# 3   -0.051181
# 4    0.022187
# ..        ...
# 946  0.009324
# 947 -0.068281
# 948 -0.053344
# 949 -0.099847
# 950  0.117155
#
# [951 rows x 1 columns],             x
# 0   -0.101467
# 1   -0.069733
# 2    0.073384
# 3    0.095104
# 4   -0.146734
# ..        ...
# 972 -0.091975
# 973  0.155330
# 974 -0.191492
# 975 -0.001677
# 976 -0.327693
#
# [977 rows x 1 columns],             x
# 0    0.036252
# 1    0.078373
# 2   -0.044275
# 3    0.054774
# 4   -0.033169
# ..        ...
# 972  0.038558
# 973 -0.012550
# 974 -0.112722
# 975 -0.080795
# 976  0.032840
#
# [977 rows x 1 columns],             x
# 0   -0.067292
# 1    0.016605
# 2    0.070513
# 3   -0.164311
# 4    0.097919
# ..        ...
# 970  0.018837
# 971 -0.110954
# 972 -0.106240
# 973  0.051655
# 974  0.252069
#
# [975 rows x 1 columns],             x
# 0   -0.053844
# 1    0.033238
# 2    0.004362
# 3    0.034359
# 4   -0.158986
# ..        ...
# 960  0.140268
# 961  0.021289
# 962 -0.151514
# 963 -0.331050
# 964 -0.048347
#
# [965 rows x 1 columns],             x
# 0   -0.047218
# 1   -0.308472
# 2   -0.002778
# 3    0.020053
# 4    0.030698
# ..        ...
# 961 -0.031419
# 962 -0.067537
# 963  0.100978
# 964  0.104002
# 965 -0.078194
#
# [966 rows x 1 columns],             x
# 0   -0.159490
# 1    0.253894
# 2    0.077695
# 3    0.045305
# 4    0.083959
# ..        ...
# 958  0.185786
# 959 -0.130673
# 960 -0.000228
# 961  0.022854
# 962  0.577874
#
# [963 rows x 1 columns],             x
# 0   -0.041529
# 1    0.110498
# 2   -0.061461
# 3   -0.003445
# 4    0.314141
# ..        ...
# 957 -0.033950
# 958 -0.352882
# 959  0.029646
# 960  0.170572
# 961 -0.015986
#
# [962 rows x 1 columns],             x
# 0    0.162785
# 1   -0.051274
# 2   -0.101629
# 3   -0.159334
# 4    0.163309
# ..        ...
# 961 -0.166353
# 962 -0.011344
# 963 -0.011753
# 964 -0.015035
# 965  0.260727
#
# [966 rows x 1 columns],             x
# 0    0.021341
# 1    0.073222
# 2    0.019307
# 3   -0.025759
# 4    0.032895
# ..        ...
# 958  0.026165
# 959 -0.155241
# 960  0.060768
# 961  0.036147
# 962 -0.095284
#
# [963 rows x 1 columns],             x
# 0    0.129595
# 1    0.261006
# 2   -0.099309
# 3   -0.023357
# 4   -0.269717
# ..        ...
# 954 -0.021874
# 955  0.169948
# 956 -0.360529
# 957 -0.021979
# 958 -0.588807
#
# [959 rows x 1 columns],             x
# 0    0.025424
# 1   -0.083025
# 2   -0.011768
# 3   -0.196537
# 4    0.063747
# ..        ...
# 952 -0.084923
# 953 -0.089377
# 954  0.104871
# 955  0.244803
# 956 -0.001764
#
# [957 rows x 1 columns],             x
# 0    0.360830
# 1    0.082410
# 2   -0.054494
# 3    0.030699
# 4    0.022025
# ..        ...
# 954 -0.125573
# 955 -0.160753
# 956 -0.070916
# 957 -0.204122
# 958  0.165235
#
# [959 rows x 1 columns],             x
# 0    0.189799
# 1   -0.103393
# 2   -0.290343
# 3    0.015350
# 4   -0.234166
# ..        ...
# 965 -0.189402
# 966  0.119692
# 967 -0.093520
# 968 -0.068502
# 969 -0.043422
#
# [970 rows x 1 columns],             x
# 0   -0.123583
# 1   -0.061303
# 2   -0.067696
# 3   -0.018015
# 4   -0.269322
# ..        ...
# 965 -0.010876
# 966 -0.121445
# 967  0.172921
# 968 -0.121659
# 969 -0.073402
#
# [970 rows x 1 columns],             x
# 0   -0.138128
# 1    0.173953
# 2   -0.201363
# 3   -0.140089
# 4    0.031884
# ..        ...
# 966  0.750585
# 967  0.060377
# 968  0.089912
# 969 -0.069730
# 970 -0.103736
#
# [971 rows x 1 columns],             x
# 0   -0.004576
# 1   -0.011668
# 2   -0.603752
# 3   -0.098166
# 4   -0.160798
# ..        ...
# 959 -0.031266
# 960  0.109382
# 961  0.042381
# 962 -0.075372
# 963 -0.283183
#
# [964 rows x 1 columns],             x
# 0    0.017310
# 1   -0.114495
# 2    0.024771
# 3   -0.041705
# 4   -0.207378
# ..        ...
# 961  0.121144
# 962  0.053382
# 963  0.083134
# 964  0.045661
# 965  0.152209
#
# [966 rows x 1 columns],             x
# 0   -0.160079
# 1    0.113411
# 2    0.008917
# 3   -0.108077
# 4   -0.230409
# ..        ...
# 963  0.004300
# 964 -0.252348
# 965  0.117731
# 966 -0.047444
# 967 -0.026710
#
# [968 rows x 1 columns],             x
# 0   -0.113608
# 1    0.042597
# 2    0.109645
# 3   -0.107230
# 4   -0.121098
# ..        ...
# 961 -0.110242
# 962 -0.090609
# 963  0.015872
# 964  0.026095
# 965 -0.016069
#
# [966 rows x 1 columns],             x
# 0    0.031824
# 1    0.008964
# 2   -0.320501
# 3   -0.122721
# 4    0.042023
# ..        ...
# 965 -0.071582
# 966 -0.071020
# 967 -0.223938
# 968  0.094702
# 969  0.006339
#
# [970 rows x 1 columns],             x
# 0   -0.182317
# 1    0.125684
# 2   -0.233359
# 3   -0.150673
# 4    0.000900
# ..        ...
# 963 -0.050409
# 964  0.069024
# 965  0.000278
# 966  0.418921
# 967  0.018787
#
# [968 rows x 1 columns],             x
# 0    0.084902
# 1   -0.000587
# 2   -0.101043
# 3    0.059662
# 4   -0.078495
# ..        ...
# 953 -0.046455
# 954  0.005368
# 955  0.003050
# 956 -0.057339
# 957 -0.149373
#
# [958 rows x 1 columns],             x
# 0   -0.005215
# 1   -0.213874
# 2    0.071042
# 3   -0.083422
# 4   -0.148072
# ..        ...
# 954 -0.020889
# 955  0.257482
# 956 -0.017184
# 957  0.121480
# 958 -0.023953
#
# [959 rows x 1 columns],             x
# 0   -0.263111
# 1    0.025059
# 2    0.053908
# 3    0.012006
# 4    0.069819
# ..        ...
# 955  0.063730
# 956  0.052395
# 957 -0.046265
# 958  0.147280
# 959 -0.061883
#
# [960 rows x 1 columns],             x
# 0   -0.318014
# 1    0.218517
# 2    0.175805
# 3    0.363804
# 4    0.132797
# ..        ...
# 966  0.071743
# 967 -0.030287
# 968 -0.458938
# 969 -0.138025
# 970 -0.075539
#
# [971 rows x 1 columns],             x
# 0    0.120975
# 1   -0.137252
# 2   -0.198988
# 3    0.072318
# 4    0.381700
# ..        ...
# 964  0.073593
# 965 -0.233980
# 966 -0.095872
# 967  0.069942
# 968 -0.170955
#
# [969 rows x 1 columns],             x
# 0    0.157661
# 1   -0.064242
# 2   -0.073695
# 3    0.233883
# 4   -0.033095
# ..        ...
# 962 -0.238639
# 963 -0.061280
# 964  0.059601
# 965 -0.123579
# 966  0.083287
#
# [967 rows x 1 columns],             x
# 0    0.024165
# 1   -0.146335
# 2   -0.030224
# 3    0.062322
# 4    0.103093
# ..        ...
# 952 -0.259070
# 953 -0.039539
# 954  0.018641
# 955 -0.001030
# 956  0.117153
#
# [957 rows x 1 columns],             x
# 0   -0.153780
# 1    0.073719
# 2   -0.197356
# 3    0.179655
# 4    0.010360
# ..        ...
# 952 -0.065242
# 953 -0.026687
# 954  0.024632
# 955  0.532305
# 956  0.053464
#
# [957 rows x 1 columns],             x
# 0   -0.051049
# 1    0.011550
# 2    0.208274
# 3   -0.050738
# 4    0.188981
# ..        ...
# 952  0.715686
# 953  0.051357
# 954 -0.072047
# 955  0.002819
# 956 -0.103291
#
# [957 rows x 1 columns],             x
# 0   -0.176657
# 1   -0.085275
# 2   -0.127526
# 3   -0.017129
# 4   -0.140988
# ..        ...
# 949  0.082667
# 950  0.055362
# 951 -0.133078
# 952 -0.005990
# 953  0.006577
#
# [954 rows x 1 columns],             x
# 0   -0.128841
# 1   -0.246086
# 2   -0.012592
# 3    0.057885
# 4   -0.284063
# ..        ...
# 948 -0.069698
# 949 -0.249163
# 950  0.083302
# 951 -0.051326
# 952  0.229569
#
# [953 rows x 1 columns],             x
# 0   -0.198978
# 1   -0.043170
# 2    0.131327
# 3   -0.095466
# 4   -0.095901
# ..        ...
# 948  0.199892
# 949  0.027236
# 950 -0.320940
# 951 -0.023649
# 952  0.082596
#
# [953 rows x 1 columns],             x
# 0    0.037461
# 1   -0.082688
# 2   -0.163343
# 3    0.070515
# 4   -0.095681
# ..        ...
# 936 -0.200801
# 937 -0.031422
# 938 -0.225723
# 939  0.136412
# 940 -0.125233
#
# [941 rows x 1 columns],             x
# 0    0.289027
# 1    0.206070
# 2   -0.237945
# 3    0.049854
# 4    0.019943
# ..        ...
# 935 -0.036743
# 936 -0.230780
# 937  0.260783
# 938 -0.465905
# 939  0.139175
#
# [940 rows x 1 columns],             x
# 0    0.050679
# 1    0.002991
# 2    0.042321
# 3   -0.121590
# 4   -0.227648
# ..        ...
# 935  0.185809
# 936 -0.420990
# 937 -0.259977
# 938 -0.001559
# 939  0.241534
#
# [940 rows x 1 columns],             x
# 0    0.118924
# 1   -0.003053
# 2    0.029577
# 3    0.077802
# 4    0.205427
# ..        ...
# 966  0.110297
# 967  0.109482
# 968  0.712004
# 969 -0.051767
# 970 -0.285936
#
# [971 rows x 1 columns],             x
# 0   -0.138886
# 1   -0.210618
# 2    0.076971
# 3    0.268020
# 4    0.441977
# ..        ...
# 966  0.111091
# 967 -0.231936
# 968 -0.342014
# 969  0.048713
# 970 -0.557970
#
# [971 rows x 1 columns],             x
# 0   -0.160547
# 1    0.319741
# 2   -0.347668
# 3   -0.010001
# 4    0.555148
# ..        ...
# 963  0.153630
# 964 -0.155512
# 965  0.189351
# 966  0.004490
# 967 -0.059170
#
# [968 rows x 1 columns],             x
# 0    0.561332
# 1   -0.145923
# 2    0.004876
# 3   -0.082137
# 4    0.277731
# ..        ...
# 944 -0.248549
# 945  0.065312
# 946 -0.186719
# 947 -0.323961
# 948 -0.034576
#
# [949 rows x 1 columns],             x
# 0   -0.229520
# 1    0.614070
# 2    0.169750
# 3   -0.511743
# 4   -0.184889
# ..        ...
# 941 -0.052362
# 942 -0.252922
# 943 -0.097873
# 944  0.514562
# 945  0.486499
#
# [946 rows x 1 columns],             x
# 0    0.238547
# 1    0.036877
# 2   -0.009992
# 3   -0.008654
# 4    0.290426
# ..        ...
# 939  0.335878
# 940  0.536821
# 941  0.327901
# 942  0.369431
# 943 -0.031622
#
# [944 rows x 1 columns],             x
# 0   -0.043608
# 1    0.091998
# 2   -0.137625
# 3   -0.135331
# 4   -0.331343
# ..        ...
# 932 -0.067726
# 933  0.327797
# 934 -0.021167
# 935  0.135585
# 936  0.292511
#
# [937 rows x 1 columns],             x
# 0   -0.045951
# 1   -0.186948
# 2    0.464763
# 3    0.341380
# 4    0.320092
# ..        ...
# 934  0.019802
# 935 -0.085858
# 936  0.145900
# 937 -0.067405
# 938 -0.305606
#
# [939 rows x 1 columns],             x
# 0    0.456344
# 1   -0.088853
# 2   -0.088421
# 3   -0.022088
# 4    0.330267
# ..        ...
# 933 -0.125032
# 934 -0.044656
# 935  0.283401
# 936  0.032223
# 937 -0.250815
#
# [938 rows x 1 columns],             x
# 0   -0.088113
# 1    0.157793
# 2   -0.063056
# 3   -0.154005
# 4   -0.256219
# ..        ...
# 927 -0.082014
# 928 -0.178590
# 929 -0.136330
# 930 -0.183387
# 931  0.057965
#
# [932 rows x 1 columns],             x
# 0    0.056572
# 1    0.093198
# 2   -0.096232
# 3    0.190059
# 4    0.111598
# ..        ...
# 928 -0.218058
# 929  0.156166
# 930 -0.212402
# 931 -0.021543
# 932 -0.075539
#
# [933 rows x 1 columns],             x
# 0   -0.129263
# 1   -0.462859
# 2   -0.015043
# 3   -0.103678
# 4    0.173185
# ..        ...
# 932 -0.146386
# 933 -0.215232
# 934 -0.262418
# 935  0.034292
# 936 -0.266978
#
# [937 rows x 1 columns],             x
# 0    0.645303
# 1    0.310237
# 2    0.037218
# 3   -0.446823
# 4   -0.201528
# ..        ...
# 985 -0.324001
# 986 -0.346548
# 987  0.104766
# 988 -0.256670
# 989 -0.114229
#
# [990 rows x 1 columns],             x
# 0   -0.195545
# 1   -0.268652
# 2    0.074611
# 3   -0.354968
# 4   -0.127594
# ..        ...
# 976  0.053545
# 977 -0.109236
# 978 -0.183842
# 979 -0.142411
# 980 -0.146725
#
# [981 rows x 1 columns],             x
# 0   -0.056625
# 1   -0.290093
# 2   -0.104679
# 3    0.779565
# 4    0.036102
# ..        ...
# 970 -0.140890
# 971 -0.160227
# 972 -0.284047
# 973  0.006548
# 974 -0.149647
#
# [975 rows x 1 columns],             x
# 0    0.972155
# 1    0.516258
# 2    0.055071
# 3   -0.253636
# 4   -0.070539
# ..        ...
# 969 -0.145502
# 970  0.548319
# 971  0.670288
# 972 -0.248906
# 973 -0.158731
#
# [974 rows x 1 columns],             x
# 0   -0.142594
# 1    0.550835
# 2    0.222480
# 3    0.123472
# 4   -0.337749
# ..        ...
# 960  0.050896
# 961 -0.415217
# 962 -0.043785
# 963 -0.187349
# 964  0.076826
#
# [965 rows x 1 columns],             x
# 0   -0.023221
# 1    0.002204
# 2   -0.129360
# 3   -0.129970
# 4   -0.490930
# ..        ...
# 962  0.283816
# 963  0.681188
# 964  0.215691
# 965  0.474522
# 966  0.136682
#
# [967 rows x 1 columns],             x
# 0    0.176974
# 1    0.269092
# 2    0.147834
# 3    0.197982
# 4   -0.018812
# ..        ...
# 956 -0.353513
# 957 -0.121864
# 958  0.261866
# 959 -0.248714
# 960 -0.183590
#
# [961 rows x 1 columns],             x
# 0    0.181012
# 1    0.096192
# 2   -0.034023
# 3    0.152071
# 4    0.154368
# ..        ...
# 952 -0.357815
# 953 -0.031798
# 954 -0.027880
# 955 -0.150524
# 956  0.546138
#
# [957 rows x 1 columns],             x
# 0   -0.094498
# 1   -0.044369
# 2    0.078510
# 3    0.019767
# 4    0.082382
# ..        ...
# 951 -0.093509
# 952  0.012080
# 953 -0.048137
# 954  0.095228
# 955  0.334379
#
# [956 rows x 1 columns],             x
# 0   -0.255300
# 1   -0.171432
# 2    0.240727
# 3    0.012912
# 4   -0.004999
# ..        ...
# 946  0.065222
# 947 -0.224672
# 948  0.036077
# 949  0.037511
# 950  0.033435
#
# [951 rows x 1 columns],             x
# 0   -0.019930
# 1    0.024164
# 2   -0.445325
# 3    0.179366
# 4    0.210149
# ..        ...
# 945  0.075847
# 946  0.369126
# 947 -0.161380
# 948  0.144541
# 949 -0.077463
#
# [950 rows x 1 columns],             x
# 0    0.004918
# 1   -0.297574
# 2    0.188437
# 3    0.230402
# 4    0.322548
# ..        ...
# 941  0.179617
# 942  0.083967
# 943  0.241617
# 944  0.101290
# 945 -0.223731
#
# [946 rows x 1 columns],             x
# 0    0.182752
# 1    0.225675
# 2    0.185508
# 3    0.034630
# 4    0.142936
# ..        ...
# 981  0.159878
# 982  0.098687
# 983  0.278480
# 984 -0.711474
# 985 -0.804028
#
# [986 rows x 1 columns],             x
# 0    0.496485
# 1    0.031389
# 2    0.296343
# 3   -0.043548
# 4   -0.721564
# ..        ...
# 973  0.303277
# 974  0.006789
# 975 -0.337667
# 976  0.131735
# 977  0.247891
#
# [978 rows x 1 columns],             x
# 0    0.143328
# 1   -0.411955
# 2    0.004896
# 3    0.308240
# 4    0.080755
# ..        ...
# 970  0.409006
# 971  0.414543
# 972  0.057127
# 973  0.148497
# 974  0.097321
#
# [975 rows x 1 columns],             x
# 0   -0.276604
# 1   -0.107539
# 2    0.296560
# 3   -0.541730
# 4    0.423207
# ..        ...
# 965  0.139821
# 966 -0.499613
# 967  0.100879
# 968 -0.367199
# 969  0.208672
#
# [970 rows x 1 columns],             x
# 0    0.107954
# 1    0.139569
# 2    0.094127
# 3    0.208772
# 4   -0.024758
# ..        ...
# 959  0.131265
# 960  0.175787
# 961  0.135096
# 962 -0.026119
# 963  0.293118
#
# [964 rows x 1 columns],             x
# 0   -0.456025
# 1    0.051948
# 2    0.177393
# 3    0.036617
# 4    0.336493
# ..        ...
# 949 -0.305162
# 950  0.000124
# 951 -0.068252
# 952  0.071023
# 953 -0.187610
#
# [954 rows x 1 columns],             x
# 0    0.169149
# 1   -0.118728
# 2   -0.029889
# 3   -0.055099
# 4   -0.039188
# ..        ...
# 945  0.152416
# 946  0.151272
# 947 -0.132282
# 948 -0.221720
# 949 -0.033047
#
# [950 rows x 1 columns],             x
# 0   -0.112631
# 1    0.656593
# 2    0.276695
# 3   -0.119821
# 4    0.039495
# ..        ...
# 944  0.106855
# 945  0.142496
# 946  0.109206
# 947 -0.437906
# 948 -0.509174
#
# [949 rows x 1 columns],             x
# 0    0.273741
# 1    0.068940
# 2    2.456616
# 3   -0.027479
# 4   -0.009795
# ..        ...
# 941 -0.294208
# 942  0.083567
# 943 -0.078989
# 944 -0.012716
# 945  0.062601
#
# [946 rows x 1 columns],             x
# 0    0.158044
# 1   -0.306937
# 2   -0.033829
# 3    0.065878
# 4   -0.239436
# ..        ...
# 939  0.175332
# 940  0.226749
# 941  0.356845
# 942 -0.064191
# 943  0.209743
#
# [944 rows x 1 columns],             x
# 0   -0.603746
# 1   -0.411049
# 2   -0.314520
# 3    0.050780
# 4   -0.023590
# ..        ...
# 933  0.141326
# 934  0.035495
# 935 -0.239638
# 936  0.059622
# 937  0.111707
#
# [938 rows x 1 columns],             x
# 0    0.063966
# 1   -0.143361
# 2   -0.136261
# 3   -0.130519
# 4   -0.568893
# ..        ...
# 933  0.008014
# 934  0.131134
# 935  0.868373
# 936  0.039117
# 937  0.749583
#
# [938 rows x 1 columns],             x
# 0   -0.009233
# 1   -0.038647
# 2    0.098692
# 3   -0.017587
# 4   -0.084717
# ..        ...
# 987  0.192388
# 988 -0.033414
# 989 -0.269727
# 990 -0.127748
# 991  0.060817
#
# [992 rows x 1 columns],             x
# 0   -0.059302
# 1    0.452624
# 2    1.047234
# 3    0.400225
# 4   -0.091101
# ..        ...
# 982 -0.097450
# 983 -0.046322
# 984 -0.122780
# 985  0.283131
# 986  0.078165
#
# [987 rows x 1 columns],             x
# 0   -0.103872
# 1    0.180372
# 2    0.148369
# 3   -0.186421
# 4   -0.129720
# ..        ...
# 977  0.094287
# 978 -0.248183
# 979 -0.074611
# 980  0.173488
# 981 -0.185734
#
# [982 rows x 1 columns],             x
# 0    0.039958
# 1    0.005367
# 2   -0.044354
# 3    0.033678
# 4   -0.124282
# ..        ...
# 973 -0.439346
# 974  0.229730
# 975 -0.028752
# 976 -0.437712
# 977  0.121047
#
# [978 rows x 1 columns],             x
# 0    0.027421
# 1    0.079347
# 2   -0.373646
# 3   -0.072255
# 4    0.232475
# ..        ...
# 966  0.088007
# 967  0.083373
# 968  0.028228
# 969  0.255456
# 970 -0.003206
#
# [971 rows x 1 columns],             x
# 0    0.779508
# 1    0.146290
# 2   -0.005926
# 3   -0.371914
# 4   -0.019619
# ..        ...
# 968  0.113052
# 969  0.047290
# 970  0.045029
# 971  0.026861
# 972 -0.047626
#
# [973 rows x 1 columns],             x
# 0    0.089001
# 1   -0.057649
# 2   -0.026955
# 3    0.376413
# 4   -0.017379
# ..        ...
# 959  0.177864
# 960  0.321330
# 961  0.053368
# 962  0.180735
# 963 -0.232573
#
# [964 rows x 1 columns],             x
# 0   -0.506651
# 1   -0.037897
# 2   -0.393519
# 3   -0.038846
# 4    0.108198
# ..        ...
# 954  0.037373
# 955  0.016900
# 956 -0.407805
# 957  0.022492
# 958  0.149271
#
# [959 rows x 1 columns],             x
# 0    0.000490
# 1   -0.059278
# 2    0.084656
# 3   -0.191833
# 4   -0.460048
# ..        ...
# 951 -0.048672
# 952  0.042952
# 953 -0.306653
# 954 -0.178961
# 955  0.108002
#
# [956 rows x 1 columns],             x
# 0    0.021978
# 1   -0.106462
# 2    0.083128
# 3   -0.109792
# 4    0.351211
# ..        ...
# 948 -0.102135
# 949 -0.002058
# 950 -0.184137
# 951 -0.013934
# 952  0.066012
#
# [953 rows x 1 columns],             x
# 0   -0.292873
# 1    0.165262
# 2    0.108663
# 3    0.183569
# 4   -0.063666
# ..        ...
# 947  0.222382
# 948 -0.045512
# 949 -0.127733
# 950 -0.400523
# 951 -0.026428
#
# [952 rows x 1 columns],             x
# 0   -0.043049
# 1   -0.349328
# 2    0.087688
# 3    0.004432
# 4    0.196105
# ..        ...
# 941  0.029852
# 942  0.023368
# 943 -0.039897
# 944 -0.195770
# 945  0.163298
#
# [946 rows x 1 columns],             x
# 0   -0.039375
# 1   -0.166270
# 2   -0.372269
# 3    0.339845
# 4   -0.001574
# ..        ...
# 986 -0.069493
# 987  0.281683
# 988  0.068185
# 989  0.018445
# 990  0.014723
#
# [991 rows x 1 columns],             x
# 0   -0.102203
# 1   -0.106465
# 2   -0.020594
# 3   -0.025190
# 4    0.205920
# ..        ...
# 983  0.076304
# 984  0.054099
# 985 -0.221513
# 986 -0.172724
# 987 -0.068945
#
# [988 rows x 1 columns],             x
# 0    0.039320
# 1    0.011560
# 2    0.194058
# 3    0.083479
# 4    0.088326
# ..        ...
# 981  0.120296
# 982  0.095508
# 983 -0.050009
# 984  0.072964
# 985 -0.215531
#
# [986 rows x 1 columns],             x
# 0    0.038085
# 1    0.139732
# 2    0.090472
# 3    0.406544
# 4    0.158127
# ..        ...
# 981  0.061775
# 982 -0.066155
# 983 -0.115144
# 984  0.134322
# 985  0.030540
#
# [986 rows x 1 columns],             x
# 0   -0.093724
# 1    0.079887
# 2   -0.079552
# 3    0.207990
# 4   -0.108325
# ..        ...
# 981 -0.161414
# 982  0.037218
# 983  0.136970
# 984 -0.142091
# 985 -0.006367
#
# [986 rows x 1 columns],             x
# 0   -0.164087
# 1   -0.048544
# 2   -0.020745
# 3    0.130863
# 4   -0.076825
# ..        ...
# 980  0.039190
# 981  0.222510
# 982 -0.141474
# 983  0.281503
# 984  0.118398
#
# [985 rows x 1 columns],             x
# 0   -0.148101
# 1   -0.029612
# 2    0.118635
# 3    0.034001
# 4    0.342835
# ..        ...
# 978  0.444948
# 979 -0.145593
# 980 -0.076072
# 981  0.481341
# 982  0.480878
#
# [983 rows x 1 columns],             x
# 0   -0.050308
# 1   -0.072246
# 2   -0.095051
# 3   -0.097334
# 4    0.231680
# ..        ...
# 977 -0.123413
# 978  0.578199
# 979  0.124223
# 980  0.860657
# 981  0.062039
#
# [982 rows x 1 columns],             x
# 0    0.029392
# 1   -0.196419
# 2   -0.052763
# 3   -0.048946
# 4    0.208894
# ..        ...
# 977 -0.032039
# 978  0.122290
# 979 -0.010308
# 980 -0.069980
# 981 -0.029146
#
# [982 rows x 1 columns],             x
# 0   -0.086882
# 1   -0.345765
# 2   -0.142265
# 3    0.229705
# 4   -0.153144
# ..        ...
# 973  0.173762
# 974 -0.009835
# 975  0.118904
# 976 -0.028802
# 977  0.033123
#
# [978 rows x 1 columns],             x
# 0   -0.168460
# 1    0.296356
# 2   -0.034752
# 3    0.294794
# 4    0.011280
# ..        ...
# 971 -0.169969
# 972 -0.025643
# 973 -0.207083
# 974 -0.067361
# 975  0.017365
#
# [976 rows x 1 columns],             x
# 0   -0.003450
# 1   -0.137867
# 2    0.151195
# 3   -0.174527
# 4   -0.091186
# ..        ...
# 971  0.077934
# 972  0.056223
# 973 -0.005385
# 974  0.116243
# 975  0.173125
#
# [976 rows x 1 columns],             x
# 0    0.060424
# 1   -0.117922
# 2    0.079673
# 3    0.072942
# 4   -0.009437
# ..        ...
# 987  0.083020
# 988 -0.299363
# 989  0.005718
# 990 -0.052975
# 991 -0.087821
#
# [992 rows x 1 columns],             x
# 0    0.174189
# 1   -0.081186
# 2    0.115265
# 3    0.030463
# 4    0.103352
# ..        ...
# 985  0.069228
# 986 -0.109386
# 987  0.015743
# 988 -0.095116
# 989  0.032698
#
# [990 rows x 1 columns],             x
# 0    0.006234
# 1   -0.014271
# 2   -0.008142
# 3   -0.038770
# 4    0.005288
# ..        ...
# 982  0.079444
# 983  0.346374
# 984  0.053026
# 985 -0.012701
# 986  0.112466
#
# [987 rows x 1 columns],             x
# 0    0.168745
# 1    0.008211
# 2   -0.309140
# 3    0.135069
# 4    0.064578
# ..        ...
# 980 -0.024478
# 981 -0.003363
# 982 -0.110926
# 983  0.080875
# 984  0.012992
#
# [985 rows x 1 columns],             x
# 0    0.116364
# 1    0.151338
# 2    0.026186
# 3   -0.268003
# 4   -0.003942
# ..        ...
# 978  0.176230
# 979  0.143709
# 980 -0.071705
# 981 -0.172054
# 982 -0.063106
#
# [983 rows x 1 columns],             x
# 0    0.042499
# 1    0.003913
# 2   -0.065279
# 3    0.101470
# 4   -0.047081
# ..        ...
# 976  0.119600
# 977 -0.171102
# 978  0.009612
# 979 -0.075294
# 980  0.139939
#
# [981 rows x 1 columns],             x
# 0   -0.018585
# 1    0.116512
# 2    0.022716
# 3    0.022795
# 4   -0.067879
# ..        ...
# 976 -0.049172
# 977 -0.034559
# 978 -0.040450
# 979 -0.002198
# 980  0.012281
#
# [981 rows x 1 columns],             x
# 0   -0.150518
# 1   -0.099728
# 2   -0.277032
# 3   -0.121289
# 4    0.064525
# ..        ...
# 975  0.166302
# 976 -0.028196
# 977  0.184041
# 978 -0.018939
# 979 -0.076399
#
# [980 rows x 1 columns],             x
# 0   -0.219171
# 1    0.087362
# 2   -0.094883
# 3   -0.115476
# 4    0.120788
# ..        ...
# 973  0.053990
# 974 -0.037928
# 975  0.054416
# 976  0.002893
# 977 -0.203272
#
# [978 rows x 1 columns],             x
# 0   -0.048026
# 1    0.039206
# 2   -0.046356
# 3   -0.007296
# 4    0.126821
# ..        ...
# 970  0.026519
# 971  0.056269
# 972 -0.014556
# 973 -0.099732
# 974  0.209172
#
# [975 rows x 1 columns],             x
# 0    0.154041
# 1   -0.318395
# 2    0.100115
# 3    0.023223
# 4    0.121832
# ..        ...
# 965  0.064962
# 966  0.055657
# 967  0.048773
# 968 -0.028514
# 969  0.045345
#
# [970 rows x 1 columns],             x
# 0    0.146261
# 1   -0.091584
# 2   -0.021230
# 3    0.019970
# 4    0.004627
# ..        ...
# 966  0.125261
# 967  0.141689
# 968  0.138105
# 969 -0.079073
# 970  0.039331
#
# [971 rows x 1 columns],             x
# 0    0.082313
# 1   -0.007088
# 2   -0.054986
# 3    0.058094
# 4   -0.026174
# ..        ...
# 964  0.220178
# 965 -0.068734
# 966  0.383602
# 967  0.110801
# 968 -0.030129
#
# [969 rows x 1 columns],             x
# 0    0.078775
# 1    0.229627
# 2    0.137617
# 3   -0.052319
# 4   -0.016135
# ..        ...
# 962  0.127505
# 963 -0.004370
# 964  0.244034
# 965  0.025856
# 966  0.276534
#
# [967 rows x 1 columns],             x
# 0    0.000398
# 1   -0.043223
# 2   -0.115921
# 3    0.075105
# 4    0.058991
# ..        ...
# 958 -0.058187
# 959 -0.077170
# 960 -0.041146
# 961 -0.055165
# 962 -0.122072
#
# [963 rows x 1 columns],             x
# 0   -0.023799
# 1   -0.054515
# 2    0.076856
# 3    0.113863
# 4    0.125093
# ..        ...
# 955 -0.025838
# 956  0.006060
# 957  0.175428
# 958 -0.073949
# 959  0.343758
#
# [960 rows x 1 columns],             x
# 0    0.387572
# 1   -0.012807
# 2   -0.040076
# 3   -0.328531
# 4    0.264406
# ..        ...
# 952 -0.010606
# 953  0.030094
# 954  0.559670
# 955 -0.119315
# 956 -0.073839
#
# [957 rows x 1 columns],             x
# 0    0.023975
# 1    0.063798
# 2    0.126634
# 3   -0.048868
# 4   -0.163022
# ..        ...
# 949 -0.101671
# 950  0.053342
# 951  0.002419
# 952  0.012241
# 953  0.024355
#
# [954 rows x 1 columns],             x
# 0   -0.011739
# 1   -0.041601
# 2    0.100506
# 3    0.078318
# 4   -0.028970
# ..        ...
# 946  0.176698
# 947  0.364148
# 948 -0.019117
# 949 -0.028059
# 950 -0.116229
#
# [951 rows x 1 columns],             x
# 0    0.143405
# 1    0.150309
# 2   -0.168667
# 3    0.009422
# 4    0.066537
# ..        ...
# 945 -0.040831
# 946 -0.139347
# 947  0.009354
# 948 -0.151620
# 949 -0.206288
#
# [950 rows x 1 columns],             x
# 0   -0.072784
# 1    0.020049
# 2    0.028612
# 3    0.012496
# 4   -0.108552
# ..        ...
# 943 -0.037728
# 944  0.028275
# 945 -0.108513
# 946 -0.029915
# 947 -0.035930
#
# [948 rows x 1 columns],             x
# 0   -0.022249
# 1   -0.101673
# 2   -0.066958
# 3   -0.066410
# 4    0.215431
# ..        ...
# 940 -0.032368
# 941  0.030741
# 942 -0.000043
# 943 -0.071846
# 944  0.011490
#
# [945 rows x 1 columns],             x
# 0   -0.122533
# 1    0.072348
# 2   -0.024261
# 3    0.131812
# 4    0.037030
# ..        ...
# 938 -0.053228
# 939 -0.113177
# 940  0.095602
# 941  0.184090
# 942 -0.107606
#
# [943 rows x 1 columns],             x
# 0   -0.006716
# 1    0.106673
# 2    0.023437
# 3    0.285290
# 4    0.051937
# ..        ...
# 937 -0.353907
# 938 -0.191451
# 939 -0.085349
# 940  0.018413
# 941  0.044380
#
# [942 rows x 1 columns],             x
# 0    0.100495
# 1    0.055837
# 2   -0.257058
# 3    0.062347
# 4   -0.032651
# ..        ...
# 950  0.053710
# 951  0.169445
# 952  0.029553
# 953  0.149113
# 954 -0.011523
#
# [955 rows x 1 columns],             x
# 0    0.280960
# 1   -0.023747
# 2   -0.057160
# 3    0.026785
# 4    0.069933
# ..        ...
# 945  0.095385
# 946  0.264374
# 947  0.173121
# 948 -0.015424
# 949  0.156656
#
# [950 rows x 1 columns],             x
# 0   -0.066992
# 1   -0.019032
# 2    0.002961
# 3    0.346858
# 4    0.036344
# ..        ...
# 938  0.093851
# 939  0.068831
# 940  0.097604
# 941  0.197887
# 942  0.535279
#
# [943 rows x 1 columns],             x
# 0    0.144163
# 1    0.065006
# 2    0.043139
# 3    0.010898
# 4    0.176680
# ..        ...
# 936  0.058200
# 937 -0.081198
# 938  0.184768
# 939 -0.126793
# 940  0.012317
#
# [941 rows x 1 columns],             x
# 0   -0.190241
# 1    0.050171
# 2   -0.109974
# 3    0.044131
# 4   -0.081872
# ..        ...
# 982 -0.107937
# 983 -0.023582
# 984  0.122640
# 985  0.004667
# 986 -0.067691
#
# [987 rows x 1 columns],             x
# 0   -0.005452
# 1    0.107072
# 2    0.097709
# 3    0.200881
# 4   -0.077192
# ..        ...
# 979 -0.094796
# 980 -0.042409
# 981 -0.017800
# 982 -0.054895
# 983 -0.089485
#
# [984 rows x 1 columns],             x
# 0    0.094288
# 1   -0.176864
# 2   -0.018270
# 3   -0.011760
# 4    0.128953
# ..        ...
# 974 -0.050052
# 975  0.149535
# 976 -0.131734
# 977  0.085739
# 978 -0.012598
#
# [979 rows x 1 columns],             x
# 0    0.151333
# 1   -0.077647
# 2   -0.114041
# 3    0.021753
# 4    0.185690
# ..        ...
# 968  0.065235
# 969  0.049817
# 970 -0.067616
# 971 -0.003794
# 972 -0.125827
#
# [973 rows x 1 columns],             x
# 0   -0.087765
# 1   -0.230067
# 2   -0.048710
# 3   -0.109865
# 4    0.146136
# ..        ...
# 965  0.055890
# 966 -0.026301
# 967  0.020727
# 968  0.066374
# 969 -0.117052
#
# [970 rows x 1 columns],             x
# 0    0.002407
# 1   -0.069543
# 2   -0.096413
# 3   -0.298013
# 4   -0.009402
# ..        ...
# 956 -0.045373
# 957 -0.120395
# 958 -0.038890
# 959 -0.057728
# 960 -0.087804
#
# [961 rows x 1 columns],             x
# 0   -0.079216
# 1    0.017753
# 2   -0.113572
# 3    0.222356
# 4   -0.063670
# ..        ...
# 955 -0.018578
# 956  0.204434
# 957  0.159561
# 958  0.045484
# 959 -0.010558
#
# [960 rows x 1 columns],             x
# 0   -0.079987
# 1    0.230089
# 2    0.010928
# 3   -0.069288
# 4   -0.263685
# ..        ...
# 953 -0.125869
# 954 -0.137406
# 955  0.112807
# 956  0.127561
# 957  0.012879
#
# [958 rows x 1 columns],             x
# 0    0.028473
# 1   -0.107557
# 2   -0.054400
# 3    0.043025
# 4   -0.004923
# ..        ...
# 986  0.087661
# 987  0.117890
# 988 -0.043090
# 989 -0.026489
# 990 -0.048505
#
# [991 rows x 1 columns],             x
# 0    0.092513
# 1    0.032287
# 2    0.079031
# 3   -0.015691
# 4    0.109128
# ..        ...
# 985  0.020931
# 986 -0.066175
# 987  0.092919
# 988  0.068668
# 989 -0.029583
#
# [990 rows x 1 columns],             x
# 0    0.054260
# 1    0.060851
# 2    0.241878
# 3    0.075797
# 4    0.084632
# ..        ...
# 983  0.027923
# 984  0.166666
# 985  0.025416
# 986  0.114534
# 987  0.068780
#
# [988 rows x 1 columns],             x
# 0   -0.027687
# 1    0.012910
# 2   -0.007775
# 3   -0.263509
# 4   -0.081683
# ..        ...
# 984  0.174780
# 985 -0.045508
# 986 -0.043495
# 987  0.059951
# 988 -0.030697
#
# [989 rows x 1 columns],             x
# 0    0.059676
# 1   -0.078384
# 2   -0.030614
# 3   -0.012158
# 4   -0.042800
# ..        ...
# 980  0.055561
# 981 -0.096602
# 982 -0.124442
# 983 -0.085626
# 984 -0.157842
#
# [985 rows x 1 columns],             x
# 0   -0.032311
# 1   -0.067698
# 2   -0.082001
# 3   -0.010290
# 4    0.104715
# ..        ...
# 975 -0.058831
# 976  0.038653
# 977  0.095751
# 978  0.055629
# 979 -0.004518
#
# [980 rows x 1 columns],             x
# 0   -0.209165
# 1   -0.074833
# 2   -0.190480
# 3    0.057502
# 4    0.095250
# ..        ...
# 979 -0.175731
# 980 -0.229561
# 981 -0.255088
# 982 -0.132071
# 983 -0.223219
#
# [984 rows x 1 columns],             x
# 0   -0.096671
# 1   -0.038886
# 2   -0.081515
# 3    0.100474
# 4    0.050586
# ..        ...
# 975 -0.128705
# 976  0.244670
# 977 -0.162709
# 978  0.077444
# 979 -0.085813
#
# [980 rows x 1 columns],             x
# 0   -0.031242
# 1   -0.313927
# 2   -0.036634
# 3   -0.005141
# 4   -0.009195
# ..        ...
# 973 -0.037693
# 974 -0.013491
# 975  0.066863
# 976 -0.052696
# 977 -0.091563
#
# [978 rows x 1 columns],             x
# 0    0.012905
# 1    0.031652
# 2   -0.019002
# 3   -0.015880
# 4    0.021092
# ..        ...
# 967  0.191025
# 968 -0.068914
# 969  0.032393
# 970 -0.024232
# 971 -0.050510
#
# [972 rows x 1 columns],             x
# 0   -0.087878
# 1    0.304952
# 2   -0.201233
# 3   -0.017309
# 4   -0.077692
# ..        ...
# 964  0.240693
# 965 -0.051355
# 966  0.068980
# 967  0.030659
# 968 -0.027293
#
# [969 rows x 1 columns],             x
# 0   -0.110513
# 1   -0.129469
# 2   -0.098726
# 3   -0.059637
# 4    0.201865
# ..        ...
# 961  0.078715
# 962  0.300273
# 963  0.549143
# 964 -0.113254
# 965 -0.005923
#
# [966 rows x 1 columns],             x
# 0   -0.078215
# 1   -0.364989
# 2   -0.370290
# 3   -0.177992
# 4   -0.096655
# ..        ...
# 989  0.125953
# 990 -0.114408
# 991 -0.228233
# 992 -0.086495
# 993 -0.269840
#
# [994 rows x 1 columns],             x
# 0   -0.161982
# 1   -0.008220
# 2   -0.102694
# 3   -0.085314
# 4   -0.021749
# ..        ...
# 985  0.050012
# 986  0.025596
# 987  0.050450
# 988 -0.209624
# 989  0.030528
#
# [990 rows x 1 columns],             x
# 0   -0.097659
# 1    0.138311
# 2   -0.106698
# 3   -0.100666
# 4    0.244992
# ..        ...
# 984  0.212851
# 985  0.021564
# 986  0.275006
# 987  0.218483
# 988  0.317742
#
# [989 rows x 1 columns],             x
# 0    0.132014
# 1   -0.159661
# 2   -0.104154
# 3    0.011751
# 4   -0.315921
# ..        ...
# 977 -0.001352
# 978  0.073869
# 979  0.121196
# 980  0.047951
# 981 -0.073759
#
# [982 rows x 1 columns],             x
# 0    0.093405
# 1    0.053163
# 2    0.162323
# 3   -0.041226
# 4   -0.080587
# ..        ...
# 971  0.120075
# 972 -0.329591
# 973 -0.043066
# 974  0.088010
# 975  0.327320
#
# [976 rows x 1 columns],             x
# 0   -0.000182
# 1    0.217601
# 2    0.025265
# 3   -0.050873
# 4    0.055920
# ..        ...
# 960  0.097058
# 961 -0.096735
# 962 -0.103177
# 963  0.005002
# 964 -0.117547
#
# [965 rows x 1 columns],             x
# 0    0.217142
# 1   -0.130882
# 2   -0.092170
# 3   -0.011484
# 4   -0.031801
# ..        ...
# 964  0.160176
# 965 -0.096765
# 966  0.242950
# 967 -0.004041
# 968 -0.261466
#
# [969 rows x 1 columns],             x
# 0    0.223518
# 1    0.008799
# 2   -0.087598
# 3   -0.108716
# 4    0.168067
# ..        ...
# 965  0.125109
# 966  0.125419
# 967  0.081621
# 968  0.074102
# 969  0.062300
#
# [970 rows x 1 columns],             x
# 0    0.005511
# 1    0.090473
# 2   -0.077119
# 3    0.093827
# 4   -0.199716
# ..        ...
# 965 -0.324949
# 966 -0.172470
# 967  0.221356
# 968  0.253988
# 969  0.061394
#
# [970 rows x 1 columns],             x
# 0   -0.025445
# 1    0.068001
# 2    1.499120
# 3   -0.205161
# 4   -0.315294
# ..        ...
# 961  0.004932
# 962  0.156228
# 963 -0.265808
# 964 -0.273973
# 965 -0.039556
#
# [966 rows x 1 columns],             x
# 0    0.219709
# 1   -0.169189
# 2    0.187377
# 3   -0.249932
# 4    0.452081
# ..        ...
# 964  0.000577
# 965 -0.253988
# 966 -0.111924
# 967 -0.524031
# 968 -0.187532
#
# [969 rows x 1 columns],             x
# 0    0.429470
# 1    0.187035
# 2   -0.210843
# 3   -0.126442
# 4   -0.279295
# ..        ...
# 961  0.127786
# 962  0.035102
# 963  0.054788
# 964 -0.318832
# 965 -0.006391
#
# [966 rows x 1 columns],             x
# 0   -0.258947
# 1   -0.149450
# 2    0.198883
# 3    0.007535
# 4   -0.085474
# ..        ...
# 958  0.358843
# 959 -0.065015
# 960  0.023930
# 961  0.147341
# 962  0.024232
#
# [963 rows x 1 columns],             x
# 0    0.457609
# 1    0.089854
# 2   -0.288665
# 3   -0.271300
# 4   -0.076933
# ..        ...
# 962  0.023835
# 963 -0.166085
# 964 -0.097584
# 965 -0.267702
# 966  0.245381
#
# [967 rows x 1 columns],             x
# 0   -0.452117
# 1   -0.064690
# 2   -0.013500
# 3   -0.019815
# 4    0.092867
# ..        ...
# 964 -0.323453
# 965 -0.323940
# 966 -0.078656
# 967 -0.075531
# 968 -0.211857
#
# [969 rows x 1 columns],             x
# 0   -0.428063
# 1    0.006553
# 2    0.031113
# 3   -0.079494
# 4   -0.034046
# ..        ...
# 959 -0.026859
# 960 -0.096721
# 961 -0.162453
# 962 -0.392925
# 963 -0.022178
#
# [964 rows x 1 columns],             x
# 0   -0.071388
# 1   -0.184181
# 2   -0.086702
# 3    0.023707
# 4    0.274162
# ..        ...
# 955 -0.103232
# 956  0.338990
# 957  0.134650
# 958  0.128544
# 959  0.192879
#
# [960 rows x 1 columns],             x
# 0   -0.155905
# 1   -0.179622
# 2    1.414292
# 3    0.174453
# 4   -0.931565
# ..        ...
# 949  0.521788
# 950  0.378145
# 951 -0.218417
# 952 -0.188767
# 953 -0.084549
#
# [954 rows x 1 columns],             x
# 0    0.344459
# 1   -0.133779
# 2    0.584609
# 3    0.026845
# 4    0.106860
# ..        ...
# 944 -0.096532
# 945  0.059679
# 946 -0.145704
# 947 -0.039130
# 948 -0.273732
#
# [949 rows x 1 columns],             x
# 0    0.081384
# 1    0.266678
# 2    0.157306
# 3   -0.219709
# 4   -0.105316
# ..        ...
# 942  0.049712
# 943 -0.101267
# 944 -0.248809
# 945 -0.083487
# 946  0.332381
#
# [947 rows x 1 columns],             x
# 0   -0.008622
# 1   -0.104950
# 2    0.177404
# 3    0.316405
# 4   -0.037230
# ..        ...
# 937  0.204124
# 938 -0.005953
# 939 -0.033714
# 940  0.097682
# 941  0.266108
#
# [942 rows x 1 columns],             x
# 0    0.013844
# 1   -0.047163
# 2   -0.116325
# 3   -0.564914
# 4    0.071875
# ..        ...
# 932 -0.041255
# 933  0.159454
# 934 -0.012407
# 935 -0.015972
# 936  0.099117
#
# [937 rows x 1 columns],             x
# 0    0.033868
# 1   -0.039871
# 2   -0.054311
# 3    0.069475
# 4    0.127682
# ..        ...
# 931 -0.068314
# 932  0.036145
# 933  0.178057
# 934  0.022745
# 935  0.001328
#
# [936 rows x 1 columns],             x
# 0   -0.331817
# 1   -0.128539
# 2    0.055078
# 3   -0.009812
# 4    0.141116
# ..        ...
# 930  0.082783
# 931  0.029087
# 932  0.033523
# 933 -0.071568
# 934  0.032881
#
# [935 rows x 1 columns],             x
# 0   -0.075149
# 1    0.039513
# 2    0.148076
# 3    0.126617
# 4   -0.090506
# ..        ...
# 923 -0.051396
# 924 -0.001931
# 925 -0.132884
# 926 -0.017247
# 927 -0.064278
#
# [928 rows x 1 columns],             x
# 0    0.024634
# 1   -0.190836
# 2    0.075161
# 3   -0.077799
# 4   -0.151929
# ..        ...
# 929  0.558993
# 930  0.087994
# 931  0.164730
# 932 -0.012875
# 933 -0.096955
#
# [934 rows x 1 columns],             x
# 0    0.128494
# 1    0.108859
# 2    0.081637
# 3    0.096032
# 4    0.156032
# ..        ...
# 928  0.125139
# 929 -0.063499
# 930  0.087715
# 931  0.074958
# 932  0.028700
#
# [933 rows x 1 columns],             x
# 0    0.212979
# 1    0.066437
# 2    0.024155
# 3    0.037124
# 4    0.226662
# ..        ...
# 926  0.098545
# 927 -0.050133
# 928  0.149783
# 929  0.148930
# 930 -0.294504
#
# [931 rows x 1 columns],             x
# 0   -0.027675
# 1    0.053417
# 2    0.089223
# 3   -0.015799
# 4    0.048684
# ..        ...
# 921 -0.071335
# 922  0.226983
# 923  0.086295
# 924  0.064713
# 925 -0.053252
#
# [926 rows x 1 columns],             x
# 0   -0.000380
# 1   -0.072995
# 2   -0.049104
# 3   -0.007956
# 4    0.243586
# ..        ...
# 915  0.085888
# 916 -0.018743
# 917 -0.031898
# 918  0.000170
# 919 -0.063859
#
# [920 rows x 1 columns],             x
# 0    0.055664
# 1   -0.033981
# 2   -0.015798
# 3    0.025025
# 4    0.082125
# ..        ...
# 918 -0.021415
# 919  0.256712
# 920 -0.262464
# 921 -0.262907
# 922  0.013722
#
# [923 rows x 1 columns],             x
# 0   -0.196226
# 1    0.005010
# 2    0.082874
# 3    0.082019
# 4   -0.108441
# ..        ...
# 920 -0.102179
# 921  0.017587
# 922  0.208634
# 923 -0.197112
# 924 -0.012730
#
# [925 rows x 1 columns],             x
# 0    0.160956
# 1   -0.233861
# 2    0.026370
# 3   -0.244248
# 4   -0.038354
# ..        ...
# 915 -0.025834
# 916 -0.034394
# 917 -0.120112
# 918  0.030234
# 919  0.141038
#
# [920 rows x 1 columns],             x
# 0   -0.027138
# 1    0.067752
# 2    0.310447
# 3    0.149899
# 4    0.062564
# ..        ...
# 912  0.262622
# 913 -0.134971
# 914  0.223119
# 915 -0.202500
# 916  0.103791
#
# [917 rows x 1 columns],             x
# 0   -0.314389
# 1    0.226596
# 2   -0.113771
# 3   -0.057692
# 4    0.107454
# ..        ...
# 912  0.346043
# 913 -0.135449
# 914 -0.084347
# 915 -0.013154
# 916  0.153507
#
# [917 rows x 1 columns],             x
# 0    0.222686
# 1   -0.094643
# 2    0.073869
# 3    0.082473
# 4   -0.023477
# ..        ...
# 910  0.093693
# 911  0.272409
# 912  0.618060
# 913  0.258328
# 914  0.210374
#
# [915 rows x 1 columns],             x
# 0   -0.060412
# 1    0.223971
# 2    0.016268
# 3    0.081213
# 4   -0.020959
# ..        ...
# 904 -0.122103
# 905  0.159101
# 906 -0.181174
# 907  0.044895
# 908 -0.100669
#
# [909 rows x 1 columns],             x
# 0    0.049778
# 1    0.217167
# 2   -0.051753
# 3    0.255087
# 4   -0.002351
# ..        ...
# 924 -0.012684
# 925  0.039791
# 926  0.170100
# 927  0.158294
# 928 -0.091844
#
# [929 rows x 1 columns],             x
# 0    0.004452
# 1   -0.055289
# 2    0.212600
# 3    0.051562
# 4    0.250967
# ..        ...
# 924  0.098889
# 925 -0.074017
# 926 -0.287643
# 927 -0.072725
# 928  0.148361
#
# [929 rows x 1 columns],             x
# 0    0.039414
# 1    0.058719
# 2   -0.006248
# 3    0.455233
# 4   -0.003149
# ..        ...
# 919 -0.028167
# 920  0.048949
# ...
# 927 -0.097084
#
# [928 rows x 1 columns],             x
# 0    0.069640
# 1    0.022231
# 2    0.112128
# 3   -0.030262
# 4   -0.158926
# ..        ...
# 920  0.030938
# 921 -0.101634
# 922  0.003769
# 923  0.026054
# 924  0.007819
#
# [925 rows x 1 columns],             x
# 0    0.160047
# 1   -0.047097
# 2    0.145930
# 3   -0.110906
# 4   -0.082722
# ..        ...
# 922 -0.080376
# 923  0.000626
# 924 -0.004402
# 925 -0.175511
# 926  0.007159
#
# [927 rows x 1 columns],             x
# 0   -0.065041
# 1   -0.116332
# 2   -0.187533
# 3   -0.235973
# 4    0.084227
# ..        ...
# 919  0.122702
# 920  0.010120
# 921 -0.108766
# 922 -0.217769
# 923 -0.032792
#
# [924 rows x 1 columns],             x
# 0    0.180799
# 1    0.028370
# 2   -0.126058
# 3   -0.050409
# 4   -0.140430
# ..        ...
# 915 -0.110978
# 916 -0.153352
# 917 -0.102165
# 918 -0.293081
# 919  0.054767
#
# [920 rows x 1 columns],             x
# 0    0.049087
# 1    0.072140
# 2   -0.049694
# 3   -0.265292
# 4   -0.059716
# ..        ...
# 915  0.013199
# 916  0.137003
# 917 -0.458269
# 918 -0.062243
# 919 -0.030467
#
# [920 rows x 1 columns],             x
# 0   -0.078657
# 1   -0.119181
# 2    0.057951
# 3   -0.158325
# 4   -0.195392
# ..        ...
# 908  0.231163
# 909  0.262048
# 910  0.027966
# 911 -0.545218
# 912  0.094697
#
# [913 rows x 1 columns],             x
# 0    0.036396
# 1    0.088186
# 2   -0.142389
# 3    0.096184
# 4   -0.022526
# ..        ...
# 927 -0.041370
# 928 -0.072324
# 929  0.107393
# 930 -0.125820
# 931 -0.185553
#
# [932 rows x 1 columns],             x
# 0    0.017458
# 1   -0.052608
# 2   -0.094284
# 3   -0.040132
# 4   -0.024173
# ..        ...
# 951 -0.080593
# 952 -0.048751
# 953 -0.015580
# 954 -0.050554
# 955  0.154389
#
# [956 rows x 1 columns],             x
# 0    0.187453
# 1   -0.080804
# 2    0.036058
# 3    0.100491
# 4    0.097021
# ..        ...
# 950 -0.258192
# 951 -0.140032
# 952 -0.104669
# 953 -0.122820
# 954  0.330634
#
# [955 rows x 1 columns],             x
# 0   -0.070091
# 1    0.162402
# 2    0.010257
# 3    0.595691
# 4    0.168184
# ..        ...
# 946  0.020587
# 947 -0.016654
# 948 -0.066587
# 949 -0.374920
# 950 -0.012445
#
# [951 rows x 1 columns],             x
# 0   -0.056560
# 1    0.079020
# 2    0.069624
# 3    0.170298
# 4   -0.227140
# ..        ...
# 948  0.200759
# 949 -0.133284
# 950  0.017108
# 951 -0.080805
# 952 -0.093244
#
# [953 rows x 1 columns],             x
# 0    0.011144
# 1    0.237415
# 2   -0.164021
# 3   -0.131571
# 4    0.172932
# ..        ...
# 950 -0.039230
# 951  0.039263
# 952 -0.121143
# 953  0.193879
# 954 -0.061939
#
# [955 rows x 1 columns],             x
# 0   -0.032564
# 1    0.061981
# 2    0.178162
# 3    0.141322
# 4   -0.162506
# ..        ...
# 946 -0.037646
# 947  0.061437
# 948 -0.078810
# 949  0.087117
# 950 -0.072283
#
# [951 rows x 1 columns],             x
# 0   -0.034486
# 1    0.076726
# 2    0.062501
# 3   -0.047372
# 4   -0.031109
# ..        ...
# 946 -0.552041
# 947 -0.064971
# 948  0.031695
# 949  0.022304
# 950  0.004695
#
# [951 rows x 1 columns],             x
# 0   -0.044466
# 1   -0.081145
# 2   -0.288878
# 3   -0.028424
# 4   -0.141495
# ..        ...
# 946  0.005266
# 947  0.025330
# 948 -0.059539
# 949  0.195021
# 950 -0.227554
#
# [951 rows x 1 columns],             x
# 0   -0.059815
# 1   -0.166837
# 2    0.058889
# 3    0.034022
# 4    0.029366
# ..        ...
# 942 -0.082204
# 943 -0.085406
# 944  0.030266
# 945  0.003330
# 946  0.030510
#
# [947 rows x 1 columns],             x
# 0   -0.027817
# 1    0.140716
# 2    0.133977
# 3    0.117356
# 4    0.045641
# ..        ...
# 943  0.094817
# 944 -0.065615
# 945  0.189378
# 946  0.040473
# 947 -0.042269
#
# [948 rows x 1 columns],             x
# 0    0.204503
# 1    0.012881
# 2    0.087955
# 3   -0.270298
# 4    0.075080
# ..        ...
# 939 -0.038399
# 940  0.084337
# 941  0.740145
# 942  0.039116
# 943 -0.075235
#
# [944 rows x 1 columns],             x
# 0   -0.039069
# 1   -0.088519
# 2   -0.007397
# 3    0.225288
# 4    0.197769
# ..        ...
# 936 -0.277693
# 937 -0.211268
# 938  0.113277
# 939  0.809235
# 940  0.362194
#
# [941 rows x 1 columns],             x
# 0    0.186755
# 1    0.138312
# 2    0.037433
# 3    0.027459
# 4   -0.092702
# ..        ...
# 945 -0.088150
# 946  0.024831
# 947 -0.013149
# 948 -0.003916
# 949  0.092234
#
# [950 rows x 1 columns],             x
# 0    0.068618
# 1   -0.011546
# 2    0.019666
# 3    0.025901
# 4   -0.039656
# ..        ...
# 943  0.118122
# 944  0.448237
# 945 -0.138615
# 946  0.067941
# 947 -0.083432
#
# [948 rows x 1 columns],             x
# 0    0.144941
# 1    0.141368
# 2    0.005420
# 3   -0.063568
# 4    0.078091
# ..        ...
# 942 -0.000883
# 943 -0.108643
# 944 -0.107290
# 945  0.029407
# 946  0.005327
#
# [947 rows x 1 columns],             x
# 0   -0.058912
# 1    0.117326
# 2   -0.106926
# 3    0.082187
# 4    0.019625
# ..        ...
# 939 -0.018995
# 940 -0.091731
# 941  0.132129
# 942  0.011119
# 943 -0.028055
#
# [944 rows x 1 columns],             x
# 0   -0.031923
# 1   -0.017562
# 2   -0.015520
# 3   -0.043623
# 4   -0.035496
# ..        ...
# 940 -0.032826
# 941 -0.005472
# 942 -0.140568
# 943  0.114435
# 944 -0.105518
#
# [945 rows x 1 columns],             x
# 0    0.060214
# 1    0.211548
# 2    0.057017
# 3    0.104373
# 4   -0.170914
# ..        ...
# 939  0.050276
# 940 -0.120018
# 941 -0.042222
# 942  0.046856
# 943  0.027319
#
# [944 rows x 1 columns],             x
# 0   -0.168648
# 1   -0.059185
# 2    0.028344
# 3   -0.086092
# 4    0.080615
# ..        ...
# 935  0.015164
# 936  0.235531
# 937 -0.179216
# 938  0.051731
# 939  0.047656
#
# [940 rows x 1 columns],             x
# 0   -0.024967
# 1    0.006171
# 2    0.101163
# 3    0.006947
# 4   -0.131674
# ..        ...
# 935 -0.040376
# 936 -0.149636
# 937  0.008233
# 938  0.067488
# 939 -0.107820
#
# [940 rows x 1 columns],             x
# 0    0.003388
# 1   -0.080334
# 2   -0.010647
# 3    0.150231
# 4   -0.052268
# ..        ...
# 933 -0.078902
# 934  0.016858
# 935  0.094321
# 936  0.101701
# 937  0.008299
#
# [938 rows x 1 columns],             x
# 0   -0.103274
# 1   -0.132965
# 2    0.095205
# 3    0.120055
# 4    0.060301
# ..        ...
# 933  0.014974
# 934  0.055075
# 935  0.139859
# 936 -0.169669
# 937 -0.100069
#
# [938 rows x 1 columns],             x
# 0    0.119604
# 1    0.044013
# 2    0.001974
# 3    0.111066
# 4    0.081750
# ..        ...
# 932  0.026089
# 933 -0.017030
# 934  0.405304
# 935 -0.036051
# 936  0.091138
#
# [937 rows x 1 columns],             x
# 0    0.005552
# 1    0.175126
# 2   -0.062334
# 3    0.017004
# 4    0.044404
# ..        ...
# 955 -0.054811
# 956 -0.139812
# 957 -0.095546
# 958  0.008606
# 959 -0.335626
#
# [960 rows x 1 columns],             x
# 0    0.038843
# 1    0.397246
# 2    0.024209
# 3    0.024109
# 4    0.002080
# ..        ...
# 966 -0.037260
# 967 -0.119637
# 968 -0.000686
# 969 -0.086999
# 970  0.051511
#
# [971 rows x 1 columns],             x
# 0   -0.018291
# 1    0.120083
# 2    0.108409
# 3    0.036802
# 4    0.212613
# ..        ...
# 964  0.020257
# 965 -0.018199
# 966  0.086891
# 967  0.028043
# 968 -0.042404
#
# [969 rows x 1 columns],             x
# 0    0.026962
# 1    0.299387
# 2    0.057507
# 3   -0.098652
# 4    0.047027
# ..        ...
# 959  0.007478
# 960  0.171488
# 961  0.034698
# 962 -0.580744
# 963 -0.002950
#
# [964 rows x 1 columns],             x
# 0    0.077441
# 1    0.072362
# 2    0.018236
# 3   -0.238311
# 4   -0.046752
# ..        ...
# 963  0.096008
# 964 -0.279680
# 965 -0.079256
# 966 -0.038793
# 967  0.029145
#
# [968 rows x 1 columns],             x
# 0   -0.114263
# 1    0.033514
# 2   -0.039368
# 3   -0.148884
# 4    0.055458
# ..        ...
# 968  0.230076
# 969  0.136636
# 970 -0.117152
# 971 -0.144597
# 972  0.091370
#
# [973 rows x 1 columns],             x
# 0   -0.017539
# 1   -0.010161
# 2   -0.219029
# 3   -0.135704
# 4   -0.066690
# ..        ...
# 968  0.009764
# 969  0.085945
# 970  0.008986
# 971  0.202957
# 972 -0.020363
#
# [973 rows x 1 columns],             x
# 0    0.044247
# 1    0.049640
# 2    0.002867
# 3    0.041096
# 4    0.012874
# ..        ...
# 977 -0.056364
# 978 -0.391565
# 979 -0.025982
# 980 -0.109518
# 981  0.164874
#
# [982 rows x 1 columns],             x
# 0    0.006388
# 1   -0.137321
# 2   -0.050806
# 3   -0.072834
# 4    0.046332
# ..        ...
# 978  0.068121
# 979 -0.032106
# 980 -0.214707
# 981  0.225010
# 982  0.076402
#
# [983 rows x 1 columns],             x
# 0   -0.073777
# 1    0.099309
# 2    0.001849
# 3    0.015289
# 4   -0.074773
# ..        ...
# 978 -0.035718
# 979  0.228127
# 980 -0.495372
# 981  0.013596
# 982 -0.182346
#
# [983 rows x 1 columns],             x
# 0   -0.114361
# 1   -0.657979
# 2    0.006197
# 3   -0.294845
# 4    0.147463
# ..        ...
# 981  0.019610
# 982  0.176818
# 983  0.036282
# 984 -0.031846
# 985  0.093483
#
# [986 rows x 1 columns],             x
# 0    0.046908
# 1   -0.548185
# 2   -0.289965
# 3    0.146989
# 4    0.114366
# ..        ...
# 981  0.032921
# 982 -0.163826
# 983  0.018174
# 984 -0.037516
# 985  0.014788
#
# [986 rows x 1 columns],              x
# 0    -0.259326
# 1     0.116181
# 2    -0.030223
# 3    -0.158580
# 4     0.129645
# ...        ...
# 1010  0.095453
# 1011 -0.241429
# 1012 -0.077863
# 1013 -0.002672
# 1014 -0.037021
#
# [1015 rows x 1 columns],              x
# 0     0.087324
# 1     0.075166
# 2     0.101049
# 3     0.002181
# 4    -0.074706
# ...        ...
# 1016  0.031551
# 1017  0.392546
# 1018  0.019058
# 1019  0.105423
# 1020  0.016883
#
# [1021 rows x 1 columns],              x
# 0    -0.224626
# 1    -0.012198
# 2    -0.062405
# 3     0.057174
# 4     0.066343
# ...        ...
# 1018  0.032203
# 1019  0.085838
# 1020  0.048889
# 1021 -0.047676
# 1022  0.001055
#
# [1023 rows x 1 columns],              x
# 0     0.001454
# 1     0.066783
# 2    -0.043834
# 3    -0.010328
# 4    -0.032444
# ...        ...
# 1026  0.043093
# 1027  0.216480
# 1028  0.042148
# 1029 -0.041927
# 1030 -0.180417
#
# [1031 rows x 1 columns],              x
# 0     0.067105
# 1    -0.134095
# 2    -0.069630
# 3    -0.000623
# 4     0.050319
# ...        ...
# 1031  0.207052
# 1032  0.040755
# 1033 -0.015986
# 1034 -0.031745
# 1035  0.011308
#
# [1036 rows x 1 columns],              x
# 0    -0.043797
# 1    -0.037938
# 2    -0.014141
# 3     0.003201
# 4     0.085344
# ...        ...
# 1025 -0.058798
# 1026  0.195315
# 1027 -0.040810
# 1028 -0.023420
# 1029  0.016217
#
# [1030 rows x 1 columns],              x
# 0     0.052253
# 1     0.205297
# 2    -0.037511
# 3     0.068509
# 4    -0.108982
# ...        ...
# 1026 -0.007584
# 1027  0.109139
# 1028 -0.183058
# 1029 -0.283988
# 1030 -0.032725
#
# [1031 rows x 1 columns],              x
# 0     0.169933
# 1     0.026297
# 2    -0.032130
# 3    -0.065890
# 4    -0.561010
# ...        ...
# 1029  0.132411
# 1030  0.061604
# 1031  0.147335
# 1032  0.040423
# 1033 -0.110670
#
# [1034 rows x 1 columns],              x
# 0     0.037779
# 1     0.029874
# 2    -0.049465
# 3     0.173760
# 4     0.099310
# ...        ...
# 1029 -0.202847
# 1030 -0.177397
# 1031 -0.032332
# 1032  0.027436
# 1033 -0.104676
#
# [1034 rows x 1 columns],              x
# 0    -0.129994
# 1    -0.069087
# 2     0.078849
# 3     0.052983
# 4    -0.144526
# ...        ...
# 1030  0.099771
# 1031 -0.076806
# 1032  0.068796
# 1033 -0.011855
# 1034 -0.076385
#
# [1035 rows x 1 columns],              x
# 0     0.027366
# 1    -0.061400
# 2    -0.097275
# 3     0.121389
# 4    -0.076092
# ...        ...
# 1029 -0.040048
# 1030 -0.159352
# 1031 -0.037641
# 1032  0.036916
# 1033  0.154676
#
# [1034 rows x 1 columns],              x
# 0     0.046915
# 1     0.007885
# 2     0.128513
# 3    -0.071506
# 4    -0.016737
# ...        ...
# 1029  0.099258
# 1030 -0.253565
# 1031 -0.217471
# 1032 -0.196596
# 1033  0.177211
#
# [1034 rows x 1 columns],              x
# 0    -0.229796
# 1     0.188530
# 2     0.018418
# 3    -0.091647
# 4    -0.028629
# ...        ...
# 1019 -0.024426
# 1020  0.000197
# 1021 -0.166545
# 1022  0.031735
# 1023  0.017008
#
# [1024 rows x 1 columns],              x
# 0     0.057871
# 1     0.035770
# 2    -0.023375
# 3     0.003880
# 4     0.001613
# ...        ...
# 1014 -0.044724
# 1015 -0.004703
# 1016  0.019559
# 1017 -0.018747
# 1018 -0.112233
#
# [1019 rows x 1 columns],              x
# 0     0.192298
# 1     0.082188
# 2    -0.039453
# 3     0.212800
# 4     0.001126
# ...        ...
# 1021  0.164324
# 1022  0.063660
# 1023  0.154841
# 1024  0.045357
# 1025 -0.001001
#
# [1026 rows x 1 columns],              x
# 0    -0.013494
# 1     0.176241
# 2    -0.091785
# 3     0.108688
# 4     0.102561
# ...        ...
# 1023  0.192654
# 1024  0.160444
# 1025 -0.004399
# 1026  0.057691
# 1027 -0.091529
#
# [1028 rows x 1 columns],              x
# 0     0.045665
# 1     0.022775
# 2     0.162997
# 3     0.402544
# 4     0.140578
# ...        ...
# 1021 -0.047270
# 1022 -0.006484
# 1023  0.026125
# 1024 -0.089231
# 1025 -0.020439
#
# [1026 rows x 1 columns],              x
# 0     0.096481
# 1    -0.120024
# 2    -0.057229
# 3     0.111413
# 4    -0.085783
# ...        ...
# 1021  0.119804
# 1022  0.217277
# 1023  0.009691
# 1024 -0.031206
# 1025  0.190374
#
# [1026 rows x 1 columns],              x
# 0     0.295906
# 1     0.032818
# 2    -0.158847
# 3    -0.043399
# 4     0.186618
# ...        ...
# 1017  0.088658
# 1018 -0.057231
# 1019 -0.044745
# 1020 -0.034737
# 1021 -0.073507
#
# [1022 rows x 1 columns],              x
# 0    -0.098683
# 1     0.032563
# 2    -0.060568
# 3     0.093745
# 4     0.036333
# ...        ...
# 1018 -0.038398
# 1019 -0.046601
# 1020  0.455831
# 1021 -0.030606
# 1022  0.062684
#
# [1023 rows x 1 columns],              x
# 0     0.086345
# 1     0.357218
# 2     0.083714
# 3     0.055760
# 4    -0.195963
# ...        ...
# 1017 -0.100323
# 1018 -0.030181
# 1019 -0.041739
# 1020 -0.169007
# 1021  0.049940
#
# [1022 rows x 1 columns],              x
# 0     0.036160
# 1    -0.015495
# 2     0.008593
# 3    -0.001804
# 4    -0.038531
# ...        ...
# 1013  0.175758
# 1014 -0.055387
# 1015 -0.142324
# 1016  0.039675
# 1017 -0.096069
#
# [1018 rows x 1 columns],              x
# 0    -0.091830
# 1     0.031907
# 2    -0.100640
# 3     0.013282
# 4     0.141944
# ...        ...
# 1007  0.020082
# 1008  0.067723
# 1009 -0.060181
# 1010 -0.124128
# 1011 -0.058443
#
# [1012 rows x 1 columns],              x
# 0     0.187494
# 1     0.268502
# 2     0.143492
# 3     0.128608
# 4    -0.218743
# ...        ...
# 1003 -0.152772
# 1004 -0.068497
# 1005  0.040015
# 1006 -0.235635
# 1007 -0.053031
#
# [1008 rows x 1 columns],              x
# 0     0.085195
# 1    -0.119123
# 2     0.056668
# 3     0.040562
# 4    -0.084896
# ...        ...
# 1006 -0.040176
# 1007  0.092279
# 1008 -0.033644
# 1009 -0.136231
# 1010 -0.010033
#
# [1011 rows x 1 columns],             x
# 0   -0.016589
# 1   -0.024084
# 2   -0.015608
# 3   -0.007163
# 4   -0.078238
# ..        ...
# 989 -0.323345
# 990 -0.025910
# 991 -0.010684
# 992  0.014123
# 993 -0.119447
#
# [994 rows x 1 columns],             x
# 0    0.083498
# 1    0.057803
# 2    0.055574
# 3   -0.000885
# 4   -0.124583
# ..        ...
# 994 -0.001267
# 995  0.093657
# 996 -0.315753
# 997 -0.085791
# 998  0.014127
#
# [999 rows x 1 columns],             x
# 0    0.119776
# 1   -0.145160
# 2    0.047725
# 3    0.000887
# 4    0.052365
# ..        ...
# 985  0.025200
# 986  0.146407
# 987 -0.049831
# 988  0.067583
# 989  0.202940
#
# [990 rows x 1 columns],             x
# 0    0.061531
# 1   -0.092834
# 2   -0.083373
# 3    0.301704
# 4    0.025101
# ..        ...
# 987  0.315647
# 988 -0.086705
# 989  0.038225
# 990  0.109467
# 991  0.080796
#
# [992 rows x 1 columns],             x
# 0   -0.148632
# 1    0.087535
# 2   -0.220128
# 3   -0.022503
# 4    0.011920
# ..        ...
# 986 -0.093728
# 987 -0.153653
# 988  0.106289
# 989 -0.138299
# 990 -0.115739
#
# [991 rows x 1 columns],             x
# 0   -0.096815
# 1    0.077750
# 2   -0.013827
# 3    0.002461
# 4   -0.091037
# ..        ...
# 986  0.085526
# 987  0.082965
# 988  0.036148
# 989 -0.178833
# 990  0.063136
#
# [991 rows x 1 columns],             x
# 0   -0.038145
# 1   -0.319774
# 2    0.066304
# 3   -0.075949
# 4   -0.130112
# ..        ...
# 983  0.005682
# 984  0.054968
# 985  0.048501
# 986  0.106549
# 987 -0.040562
#
# [988 rows x 1 columns],             x
# 0   -0.158906
# 1    0.030853
# 2    0.043185
# 3    0.061386
# 4    0.110300
# ..        ...
# 988 -0.053221
# 989 -0.070708
# 990  0.152069
# 991  0.081127
# 992 -0.105531
#
# [993 rows x 1 columns],             x
# 0    0.053637
# 1   -0.073954
# 2    0.051057
# 3   -0.057044
# 4    0.020703
# ..        ...
# 991  0.025668
# 992 -0.017893
# 993  0.062097
# 994 -0.206763
# 995 -0.243906
#
# [996 rows x 1 columns],             x
# 0    0.302740
# 1    0.000712
# 2   -0.246326
# 3    0.061548
# 4   -0.258392
# ..        ...
# 992 -0.054230
# 993  0.104355
# 994  0.028792
# 995  0.007074
# 996 -0.029700
#
# [997 rows x 1 columns],             x
# 0   -0.030105
# 1    0.184023
# 2   -0.020312
# 3    0.178501
# 4   -0.082132
# ..        ...
# 991 -0.124877
# 992 -0.150426
# 993  0.102472
# 994 -0.017021
# 995  0.076186
#
# [996 rows x 1 columns],             x
# 0    0.179187
# 1    0.138008
# 2   -0.031551
# 3    0.035266
# 4   -0.054951
# ..        ...
# 987 -0.161097
# 988  0.007234
# 989 -0.114722
# 990 -0.021013
# 991 -0.274870
#
# [992 rows x 1 columns],             x
# 0    0.109979
# 1    0.074553
# 2   -0.252338
# 3    0.178925
# 4    0.090516
# ..        ...
# 979 -0.178692
# 980  0.058276
# 981 -0.084064
# 982 -0.006748
# 983  0.096230
#
# [984 rows x 1 columns],             x
# 0    0.042818
# 1    0.056687
# 2   -0.087541
# 3   -0.094343
# 4   -0.224205
# ..        ...
# 762  0.001853
# 763 -0.116442
# 764 -0.020435
# 765 -0.022288
# 766 -0.125507
#
# [767 rows x 1 columns]]

# %%
PLS_data_folder = '../data/PLS_data'

# %%
# Load the data
X=pd.read_csv('../../data/X.csv') #Here '../..' because the files are stored on my computer in another folder
Y=pd.read_csv('../../data/Y_untouched.csv')

# %%
load_datasets_PLS(training_periods, vars_explained)
# Out:
# 50
# 80
# 95

# %%
Y.dropna(inplace=True)
dates = Y.drop_duplicates('date')
dates = list(dates['date'][0:training_periods])

load_dataset_NN(X, Y, dates)

# %% [markdown]
# # Training Functions

# %%
# define neural network model in Keras
def NN(n_inputs, n_units = 30, dropout =0.1, l1_reg =0.001, activation='relu', L=2):
    # L>0 is the number of hidden layers
    
    model = Sequential()
    model.add(Dense(units=n_units, input_dim=n_inputs, kernel_regularizer=l1(l1_reg), kernel_initializer='normal', activation=activation))
    model.add(Dropout(dropout))
    for i in range (0,L-1):
        model.add(Dense(units=n_units, kernel_regularizer=l1(l1_reg), kernel_initializer='normal', activation=activation))
        model.add(Dropout(dropout))
    model.add(Dense(1, kernel_initializer='normal')) 
    model.compile(loss='mean_squared_error', optimizer='adam',metrics=['mae'])
    return(model)

# %%
es = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=3)

# %%
"""
 NN parameter tuning:
"""
def parameter_tuning(X, y, cv=3, seed = 7):


   param_grid = dict(n_inputs=[X.shape[1]],n_units=[50,100,200], l1_reg = [0, 0.0001, 0.001,0.01], activation=['relu','tanh']) # dropout=[0, 0.1, 0.2, 0.3],  #n_hidden_neurons=[10,50,100], 
   estimator = KerasRegressor(build_fn=NN, epochs=100, batch_size=50, verbose=0)   
   grid = GridSearchCV(estimator=estimator, param_grid=param_grid, cv=cv)
   grid_result = grid.fit(X, y)
 
   print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
   means = grid_result.cv_results_['mean_test_score']
   stds = grid_result.cv_results_['std_test_score']
   params = grid_result.cv_results_['params']
   for mean, stdev, param in zip(means, stds, params):
         print("%f (%f) with: %r" % (mean, stdev, param))

# %%
def training_LASSO(X, Y, training_dates):
    i=0
    for date in training_dates:
        print(i, date)
        train_index = Y[Y['date']==date].index

        if len(train_index)==0:
            next
        date_next=pd.Timestamp(np.datetime64(date)).to_pydatetime() + relativedelta(months=+1)
        date_next = date_next.strftime('%Y-%m-%d')
        test_index  = Y[Y['date']==date_next].index   
        if len(test_index)==0:
            next
            
        x_train = X.loc[train_index]
        x_train=x_train.drop("date", axis=1)
        y_train = Y.loc[train_index]
        y_train= y_train.drop("date", axis=1)
        x_test  = X.loc[test_index]
        x_test=x_test.drop("date", axis=1)
        y_test =  Y.loc[test_index]
        y_test=y_test.drop("date", axis=1)


        n_inputs = x_train.shape[1]
        if n_inputs ==0:
            next
            
        interaction = PolynomialFeatures(degree=2, interaction_only=False, include_bias=False)
        x = interaction.fit_transform(x_train)
        model=linear_model.LassoCV(n_alphas=50, fit_intercept=True, normalize=False).fit(x,y_train)
        betas['LASSO'].append(model.coef_[:49])   # with elements from index first to last – 1
        beta_interacts['LASSO'].append(model.coef_[49:])
        models['LASSO'].append(model)

# %%
"""X_try = pd.read_csv('../../data/X_untouched.csv')
Y_try = pd.read_csv('../../data/Y_untouched.csv')

X_try.drop("date", axis=1)

Y_try.dropna(inplace=True)
dates_try = Y_try.drop_duplicates('date')

dates_try = list(dates_try['date'][0:332])

date_try = dates_try[0]

train_index_try = Y_try[Y_try['date']==date_try].index

data_try = X_try.loc[train_index_try]

print(data_try.shape == sm.add_constant(data_try).shape)
print(data_try.shape == sm.add_constant(data_try, has_constant='add').shape)"""
# Out:
# True
# False

# %%
def training_OLS(X, Y, training_dates):
    i=0
    for date in training_dates:
        #start_time = timeit.default_timer()  
        print(i, date)
        train_index = Y[Y['date']==date].index

        if len(train_index)==0:
            next

        date_next=pd.Timestamp(np.datetime64(date)).to_pydatetime() + relativedelta(months=+1)
        date_next = date_next.strftime('%Y-%m-%d')
        test_index  = Y[Y['date']==date_next].index
        
        if len(test_index)==0:
            next


        x_train = X.loc[train_index]
        x_train=x_train.drop("date", axis=1)
        y_train = Y.loc[train_index]
        y_train= y_train.drop("date", axis=1)
        x_test  = X.loc[test_index]
        x_test=x_test.drop("date", axis=1)
        y_test =  Y.loc[test_index]
        y_test=y_test.drop("date", axis=1)


        n_inputs = x_train.shape[1]
        if n_inputs ==0:
            next
            
        x=sm.add_constant(x_train, has_constant='add')
        model =sm.OLS(y_train, x).fit()   
        betas['linear'].append(model.params)
        models['linear'].append(model)
        xs['train_linear'].append(x_train)
        xs['test_linear'].append(x_test)
        ys['train_linear'].append(y_train)
        ys['test_linear'].append(y_test)
        
        i+=1
        
    return

# %%
def training_NN_OLS(X, Y, training_dates, L):
    
    #{'activation': 'tanh', 'l1_reg': 0, 'n_inputs': 49, 'n_units': 200}
    n_epoches = 100  # maximum number of epoches (to be used with early stopping)
    n_batch = 50     # mini-batch size
    drop_out = 0.0   # level of dropout (set between 0 and 1)
    n_units = 200
    l1_reg = 0.00  # L_1 regularization parameter
    tune = False     # set to true to perform cross-validation for parameter tuning
    activation='tanh'

    i=0
    for date in training_dates:
        #start_time = timeit.default_timer()  
        print(i, date)
        train_index = Y[Y['date']==date].index

        if len(train_index)==0:
            next
        date_next=pd.Timestamp(np.datetime64(date)).to_pydatetime() + relativedelta(months=+1)
        date_next = date_next.strftime('%Y-%m-%d')
        test_index  = Y[Y['date']==date_next].index
        if len(test_index)==0:
            next


        x_train = X.loc[train_index]
        x_train=x_train.drop("date", axis=1)
        y_train = Y.loc[train_index]
        y_train= y_train.drop("date", axis=1)
        x_test  = X.loc[test_index]
        x_test=x_test.drop("date", axis=1)
        y_test =  Y.loc[test_index]
        y_test=y_test.drop("date", axis=1)


        n_inputs = x_train.shape[1]
        if n_inputs ==0:
            next

        if tune:
            print("cross-validation...")
            parameter_tuning(x_train, y_train, 3)
            tune=False

        model = NN(n_units=n_units, n_inputs=n_inputs, dropout=drop_out, l1_reg=l1_reg, activation=activation, L=L)
        model.fit(x_train.values, y_train.values, epochs=n_epoches, batch_size=n_batch, verbose=0, callbacks=[es])   
        beta=sensitivities(model, x_train.values, L, activation)   
        models['NN'].append(model)
        betas['NN'].append(beta)
        
        x=sm.add_constant(x_train)
        model =sm.OLS(y_train, x).fit()   
        betas['linear'].append(model.params)
        models['linear'].append(model)
        xs['train'].append(x_train)
        xs['test'].append(x_test)
        ys['train'].append(y_train)
        ys['test'].append(y_test)

        #elapsed = timeit.default_timer() - start_time
        #print("Elapsed time:" + str(elapsed) + " (s)")
        i+=1
        
    return

# %%
def training_PLS(L, variance, training_periods):
    
    n_epoches = 100  # maximum number of epoches (to be used with early stopping)
    n_batch = 50     # mini-batch size
    drop_out = 0.0   # level of dropout (set between 0 and 1)
    tune = False     # set to true to perform cross-validation for parameter tuning

    if variance == 50: #{'activation': 'tanh', 'l1_reg': 0, 'n_inputs': 14, 'n_units': 100}
        n_units = 100
        l1_reg = 0.00  # L_1 regularization parameter
        activation='tanh'
    elif variance == 80: #{'activation': 'tanh', 'l1_reg': 0.0001, 'n_inputs': 28, 'n_units': 50}
        n_units = 50
        l1_reg = 0.0001  # L_1 regularization parameter
        activation='tanh'
    elif variance == 95: #{'activation': 'tanh', 'l1_reg': 0, 'n_inputs': 37, 'n_units': 100}
        n_units = 100
        l1_reg = 0.00  # L_1 regularization parameter
        activation='tanh'
        
    x_trains_folder = "../data/PLS_data/%i/x_train" % var
    y_trains_folder = "../data/PLS_data/%i/y_train" % var
    x_tests_folder = "../data/PLS_data/%i/x_test" % var
    y_tests_folder = "../data/PLS_data/%i/y_test" % var
    
    XTRAIN = os.listdir(x_trains_folder)
    YTRAIN = os.listdir(y_trains_folder)
    XTEST = os.listdir(x_tests_folder)
    YTEST = os.listdir(y_tests_folder)  
    
    #start_time = timeit.default_timer()    

    #training_periods = np.min(len(XTRAIN), training_periods)
    
    for i in range( training_periods ):
        x_train_file = "%s/%s" % (x_trains_folder, XTRAIN[i])
        y_train_file = "%s/%s" % (y_trains_folder, YTRAIN[i])
        x_test_file = "%s/%s" % (x_tests_folder, XTEST[i])
        y_test_file = "%s/%s" % (y_tests_folder, YTEST[i])
        
        x_train = pd.read_csv(x_train_file)
        y_train = pd.read_csv(y_train_file)
        x_test = pd.read_csv(x_test_file)
        y_test = pd.read_csv(y_test_file)
        
        x_train.drop(columns='Unnamed: 0', inplace=True)
        y_train.drop(columns='Unnamed: 0', inplace=True)
        x_test.drop(columns='Unnamed: 0', inplace=True)
        y_test.drop(columns='Unnamed: 0', inplace=True)
        
        n_inputs = x_train.shape[1]
        if n_inputs ==0:
            next

        if tune:
            print("cross-validation...")
            parameter_tuning(x_train, y_train, 3)
            tune=False
        
        model = NN(n_units=n_units, n_inputs=n_inputs, dropout=drop_out, l1_reg=l1_reg, activation=activation, L=L)        
        model.fit(x_train.values, y_train.values, epochs=n_epoches, batch_size=n_batch, verbose=0, callbacks=[es])   
        beta=sensitivities(model, x_train.values, L, activation)   
        models['PLS_NN'].append(model)
        betas['PLS_NN'].append(beta)

        xs['train_PLS'].append(x_train)
        xs['test_PLS'].append(x_test)
        ys['train_PLS'].append(y_train)
        ys['test_PLS'].append(y_test)

        #elapsed = timeit.default_timer() - start_time
        #print("Elapsed time:" + str(elapsed) + " (s)")
    
    return

# %%
# Compute the sensitivites of the network for either tanh or ReLU
def sensitivities(lm, X, L, activation='tanh'):
    
    W=lm.get_weights()
    M = np.shape(X)[0]
    p = np.shape(X)[1]
    beta=np.array([0]*M*(p+1), dtype='float32').reshape(M,p+1)
    B_0 =W[1]
    for i in range (0,L):
      if activation=='tanh':  
        B_0 = (np.dot(np.transpose(W[2*(i+1)]),np.tanh(B_0))+W[2*(i+1)+1])
      elif activation=='relu':
        B_0 = (np.dot(np.transpose(W[2*(i+1)]),np.maximum(B_0,0))+W[2*(i+1)+1])
    
          
    beta[:,0]= B_0 # intercept \beta_0= F_{W,b}(0)
    for i in range(M):
      I1 = np.dot(np.transpose(W[0]),np.transpose(X[i,])) + W[1]
      if activation=='tanh':
          Z= np.tanh(I1)  
          D = np.diag(1-Z**2)
      elif activation=='relu':
          Z=np.maximum(I1,0)
          D = np.diag(np.sign(Z)) 
               
      for j in range(p):
        J = np.dot(D,W[0][j])       
        for a in range (1,L):
          I= np.dot(np.transpose(W[2*a]),Z) + W[2*a+1] 
          if activation=='tanh':  
              Z = np.tanh(I)
              D = np.diag(1-Z**2)
          elif activation=='relu':    
              Z=np.maximum(I,0)
              D = np.diag(np.sign(Z)) 
          J = np.dot(np.dot(D,np.transpose(W[a*2])),J)
        beta[i,j+1]=np.dot(np.transpose(W[2*L]),J)
            
    return(beta)

# %% [markdown]
# ## Training of models

# %% [markdown]
# ## Run all trainings

# %%
# Run all trainings

models = {}
models['linear']=[]
models['NN']=[]
models['PLS_NN']=[]

betas = {}
betas['NN'] =[]
betas['linear'] =[]
betas['PLS_NN'] =[]

xs = {}
ys = {}

xs['train']=[]
xs['test']=[]
ys['train']=[]
ys['test']=[]

xs['train_PLS']=[]
xs['test_PLS']=[]
ys['train_PLS']=[]
ys['test_PLS']=[]

vars_explained = [50, 80, 95]

for var in vars_explained:
    training_periods = 332
    L = 2
    start = time.time()
    training_PLS(L, var, training_periods)
    print(var, "% Variance explained took", time.time()-start, "s for", training_periods, "training periods")
    

L=2 # Number of hidden layers
training_periods = 332 # number of model training and evaluation periods
Y.dropna(inplace=True)
dates = Y.drop_duplicates('date')
dates = list(dates['date'][0:training_periods])

training_NN_OLS(X,Y,dates,L)

save_all_models()

# %% [markdown]
# ## Run PLS

# %%
# 50%:
#2250 seconds = 38min for 5 dates + tuning for 50% var explained
# Best: -0.014796 using {'activation': 'tanh', 'l1_reg': 0, 'n_inputs': 14, 'n_units': 100}

# 80%:
#1083 seconds
# Best: -0.015962 using {'activation': 'tanh', 'l1_reg': 0.0001, 'n_inputs': 28, 'n_units': 50}

# 95%:
# Best: -0.015735 using {'activation': 'tanh', 'l1_reg': 0, 'n_inputs': 37, 'n_units': 100}

#vars_explained = [50,70,80,90,95,99]
vars_explained = [95]

for var in vars_explained:
    training_periods = 20
    L = 2
    start = time.time()
    training_PLS(L, var, training_periods)
    print(var, "% Variance explained took", time.time()-start, "s for", training_periods, "training periods")

# %% [markdown]
# ## Run NN and OLS

# %%
#n = len(np.unique(Y['date']))
#dates = np.unique(Y['date'])[(n-training_periods):n] 

#Best: -0.016099 using {'activation': 'tanh', 'l1_reg': 0, 'n_inputs': 49, 'n_units': 200}

L=2 # Number of hidden layers
training_periods = 20 # number of model training and evaluation periods
Y.dropna(inplace=True)
dates = Y.drop_duplicates('date')
dates = list(dates['date'][0:training_periods])

training_NN_OLS(X,Y,dates,L)

# %% [markdown]
# ## Run OLS

# %%
training_periods = 332 # number of model training and evaluation periods
Y.dropna(inplace=True)
dates = Y.drop_duplicates('date')
dates = list(dates['date'][0:training_periods])

training_OLS(X, Y, dates)
# Out:
# 0 1989-12-01
# 1 1990-01-01
# 2 1990-02-01
# 3 1990-03-01
# 4 1990-04-01
# 5 1990-05-01
# 6 1990-06-01
# 7 1990-07-01
# 8 1990-08-01
# 9 1990-09-01
# 10 1990-10-01
# 11 1990-11-01
# 12 1990-12-01
# 13 1991-01-01
# 14 1991-02-01
# 15 1991-03-01
# 16 1991-04-01
# 17 1991-05-01
# 18 1991-06-01
# 19 1991-07-01
# 20 1991-08-01
# 21 1991-09-01
# 22 1991-10-01
# 23 1991-11-01
# 24 1991-12-01
# 25 1992-01-01
# 26 1992-02-01
# 27 1992-03-01
# 28 1992-04-01
# 29 1992-05-01
# 30 1992-06-01
# 31 1992-07-01
# 32 1992-08-01
# 33 1992-09-01
# 34 1992-10-01
# 35 1992-11-01
# 36 1992-12-01
# 37 1993-01-01
# 38 1993-02-01
# 39 1993-03-01
# 40 1993-04-01
# 41 1993-05-01
# 42 1993-06-01
# 43 1993-07-01
# 44 1993-08-01
# 45 1993-09-01
# 46 1993-10-01
# 47 1993-11-01
# 48 1993-12-01
# 49 1994-01-01
# 50 1994-02-01
# 51 1994-03-01
# 52 1994-04-01
# 53 1994-05-01
# 54 1994-06-01
# 55 1994-07-01
# 56 1994-08-01
# 57 1994-09-01
# 58 1994-10-01
# 59 1994-11-01
# 60 1994-12-01
# 61 1995-01-01
# 62 1995-02-01
# 63 1995-03-01
# 64 1995-04-01
# 65 1995-05-01
# 66 1995-06-01
# 67 1995-07-01
# 68 1995-08-01
# 69 1995-09-01
# 70 1995-10-01
# 71 1995-11-01
# 72 1995-12-01
# 73 1996-01-01
# 74 1996-02-01
# 75 1996-03-01
# 76 1996-04-01
# 77 1996-05-01
# 78 1996-06-01
# 79 1996-07-01
# 80 1996-08-01
# 81 1996-09-01
# 82 1996-10-01
# 83 1996-11-01
# 84 1996-12-01
# 85 1997-01-01
# 86 1997-02-01
# 87 1997-03-01
# 88 1997-04-01
# 89 1997-05-01
# 90 1997-06-01
# 91 1997-07-01
# 92 1997-08-01
# 93 1997-09-01
# 94 1997-10-01
# 95 1997-11-01
# 96 1997-12-01
# 97 1998-01-01
# 98 1998-02-01
# 99 1998-03-01
# 100 1998-04-01
# 101 1998-05-01
# 102 1998-06-01
# 103 1998-07-01
# 104 1998-08-01
# 105 1998-09-01
# 106 1998-10-01
# 107 1998-11-01
# 108 1998-12-01
# 109 1999-01-01
# 110 1999-02-01
# 111 1999-03-01
# 112 1999-04-01
# 113 1999-05-01
# 114 1999-06-01
# 115 1999-07-01
# 116 1999-08-01
# 117 1999-09-01
# 118 1999-10-01
# 119 1999-11-01
# 120 1999-12-01
# 121 2000-01-01
# 122 2000-02-01
# 123 2000-03-01
# 124 2000-04-01
# 125 2000-05-01
# 126 2000-06-01
# 127 2000-07-01
# 128 2000-08-01
# 129 2000-09-01
# 130 2000-10-01
# 131 2000-11-01
# 132 2000-12-01
# 133 2001-01-01
# 134 2001-02-01
# 135 2001-03-01
# 136 2001-04-01
# 137 2001-05-01
# 138 2001-06-01
# 139 2001-07-01
# 140 2001-08-01
# 141 2001-09-01
# 142 2001-10-01
# 143 2001-11-01
# 144 2001-12-01
# 145 2002-01-01
# 146 2002-02-01
# 147 2002-03-01
# 148 2002-04-01
# 149 2002-05-01
# 150 2002-06-01
# 151 2002-07-01
# 152 2002-08-01
# 153 2002-09-01
# 154 2002-10-01
# 155 2002-11-01
# 156 2002-12-01
# 157 2003-01-01
# 158 2003-02-01
# 159 2003-03-01
# 160 2003-04-01
# 161 2003-05-01
# 162 2003-06-01
# 163 2003-07-01
# 164 2003-08-01
# 165 2003-09-01
# 166 2003-10-01
# 167 2003-11-01
# 168 2003-12-01
# 169 2004-01-01
# 170 2004-02-01
# 171 2004-03-01
# 172 2004-04-01
# 173 2004-05-01
# 174 2004-06-01
# 175 2004-07-01
# 176 2004-08-01
# 177 2004-09-01
# 178 2004-10-01
# 179 2004-11-01
# 180 2004-12-01
# 181 2005-01-01
# 182 2005-02-01
# 183 2005-03-01
# 184 2005-04-01
# 185 2005-05-01
# 186 2005-06-01
# 187 2005-07-01
# 188 2005-08-01
# 189 2005-09-01
# 190 2005-10-01
# 191 2005-11-01
# 192 2005-12-01
# 193 2006-01-01
# 194 2006-02-01
# 195 2006-03-01
# 196 2006-04-01
# 197 2006-05-01
# 198 2006-06-01
# 199 2006-07-01
# 200 2006-08-01
# 201 2006-09-01
# 202 2006-10-01
# 203 2006-11-01
# 204 2006-12-01
# 205 2007-01-01
# 206 2007-02-01
# 207 2007-03-01
# 208 2007-04-01
# 209 2007-05-01
# 210 2007-06-01
# 211 2007-07-01
# 212 2007-08-01
# 213 2007-09-01
# 214 2007-10-01
# 215 2007-11-01
# 216 2007-12-01
# 217 2008-01-01
# 218 2008-02-01
# 219 2008-03-01
# 220 2008-04-01
# 221 2008-05-01
# 222 2008-06-01
# 223 2008-07-01
# 224 2008-08-01
# 225 2008-09-01
# 226 2008-10-01
# 227 2008-11-01
# 228 2008-12-01
# 229 2009-01-01
# 230 2009-02-01
# 231 2009-03-01
# 232 2009-04-01
# 233 2009-05-01
# 234 2009-06-01
# 235 2009-07-01
# 236 2009-08-01
# 237 2009-09-01
# 238 2009-10-01
# 239 2009-11-01
# 240 2009-12-01
# 241 2010-01-01
# 242 2010-02-01
# 243 2010-03-01
# 244 2010-04-01
# 245 2010-05-01
# 246 2010-06-01
# 247 2010-07-01
# 248 2010-08-01
# 249 2010-09-01
# 250 2010-10-01
# 251 2010-11-01
# 252 2010-12-01
# 253 2011-01-01
# 254 2011-02-01
# 255 2011-03-01
# 256 2011-04-01
# 257 2011-05-01
# 258 2011-06-01
# 259 2011-07-01
# 260 2011-08-01
# 261 2011-09-01
# 262 2011-10-01
# 263 2011-11-01
# 264 2011-12-01
# 265 2012-01-01
# 266 2012-02-01
# 267 2012-03-01
# 268 2012-04-01
# 269 2012-05-01
# 270 2012-06-01
# 271 2012-07-01
# 272 2012-08-01
# 273 2012-09-01
# 274 2012-10-01
# 275 2012-11-01
# 276 2012-12-01
# 277 2013-01-01
# 278 2013-02-01
# 279 2013-03-01
# 280 2013-04-01
# 281 2013-05-01
# 282 2013-06-01
# 283 2013-07-01
# 284 2013-08-01
# 285 2013-09-01
# 286 2013-10-01
# 287 2013-11-01
# 288 2013-12-01
# 289 2014-01-01
# 290 2014-02-01
# 291 2014-03-01
# 292 2014-04-01
# 293 2014-05-01
# 294 2014-06-01
# 295 2014-07-01
# 296 2014-08-01
# 297 2014-09-01
# 298 2014-10-01
# 299 2014-11-01
# 300 2014-12-01
# 301 2015-01-01
# 302 2015-02-01
# 303 2015-03-01
# 304 2015-04-01
# 305 2015-05-01
# 306 2015-06-01
# 307 2015-07-01
# 308 2015-08-01
# 309 2015-09-01
# 310 2015-10-01
# 311 2015-11-01
# 312 2015-12-01
# 313 2016-01-01
# 314 2016-02-01
# 315 2016-03-01
# 316 2016-04-01
# 317 2016-05-01
# 318 2016-06-01
# 319 2016-07-01
# 320 2016-08-01
# 321 2016-09-01
# 322 2016-10-01
# 323 2016-11-01
# 324 2016-12-01
# 325 2017-01-01
# 326 2017-02-01
# 327 2017-03-01
# 328 2017-04-01
# 329 2017-05-01
# 330 2017-06-01
# 331 2017-07-01

# %%
training_periods = 332 # number of model training and evaluation periods
Y.dropna(inplace=True)
dates = Y.drop_duplicates('date')
dates = list(dates['date'][0:training_periods])

beta_interacts = {}

models["LASSO"] = []
betas['LASSO'] = []
beta_interacts['LASSO'] = []
training_LASSO(X, Y, dates)

# %%
def save_all_models():
    
    for model_type, model_list in models.items():
        i=0
        if model_type == "PLS_NN":
            continue
            for model_to_save in model_list:
                name = '../models/%s/%i/model_%s' % (model_type, vars_explained[i//training_periods], dates[i%training_periods])
                model_to_save.save(name)
                i+=1
        else
            for model_to_save in model_list:
                name = '../models/%s/model_%s' % (model_type, dates[i])
                model_to_save.save(name)
                i+=1
        
save_all_models()

# %% [markdown]
# # Performance evaluation

# %%
testing_periods=training_periods-1

# %%
MSE = 0
r2_sum = 0
y_hat_linear = []
MSE_array_linear=np.array([np.nan]*training_periods,dtype='float64')
r2_array_linear_oos = np.array([np.nan]*training_periods,dtype='float64')

for i in range(training_periods):
    x= sm.add_constant(xs['test_linear'][i].values, has_constant='add')
    y_hat_linear.append(models['linear'][i].predict(x))
    
    r2 = r2_score(ys['test_linear'][i].values, y_hat_linear[-1])
    r2_array_linear_oos[i] = r2
    r2_sum += r2

    MSE_test_linear= mean_squared_error(y_hat_linear[-1], ys['test_linear'][i].values)
    #print(i,MSE_test_linear)
    MSE_array_linear[i]=MSE_test_linear
    MSE+=MSE_test_linear
    
print("MSE:" + str(MSE/training_periods))   
MSE_linear=MSE/training_periods
print("R²: " + str(r2_sum/testing_periods))
r2_linear_oos = r2_sum/testing_periods
# Out:
# MSE:67.89308746781825
# R²: -2033.556004340574

# %%
# L_inf linear (testing)

# %%
L_inf = 0
y_hat_linear = []
L_inf_array_linear=np.array([np.nan]*training_periods,dtype='float64')

for i in range(training_periods):
    x= sm.add_constant(xs['test'][i].values, has_constant='add')
    y_hat_linear.append(models['linear'][i].predict(x))
    L_inf_test_linear= np.max(np.abs(np.array(y_hat_linear[-1]- ys['test'][i].values)))
    #print(i,MSE_test_linear)
    L_inf_array_linear[i]=L_inf_test_linear
    L_inf+=L_inf_test_linear
    
print("L_inf:" + str(L_inf/training_periods))
L_inf_linear=L_inf/training_periods
# Out:
# L_inf:19.4621971621287

# %%
# MSEs linear (training)

# %%
MSE = 0
r2_sum = 0
MSE_array_linear_in=np.array([0]*training_periods,dtype='float64')
y_hat_linear_is =[]
r2_array_linear_is = np.array([np.nan]*training_periods,dtype='float64')

for i in range(training_periods):
    x= sm.add_constant(xs['train_linear'][i].values, has_constant='add')
    y_hat_linear_is.append(models['linear'][i].predict(x))
    
    r2 = r2_score(ys['train_linear'][i].values, y_hat_linear_is[-1])
    r2_array_linear_is[i] = r2
    r2_sum += r2
    
    MSE_test_linear= mean_squared_error(y_hat_linear_is[-1], ys['train_linear'][i].values)
    #print(i,MSE_test_linear)
    MSE_array_linear_in[i]=MSE_test_linear
    MSE+=MSE_test_linear
    
print("MSE:" + str(MSE/training_periods))
MSE_linear_in=MSE/training_periods
print("R²: " + str(r2_sum/training_periods))
r2_linear_is = r2_sum/training_periods
# Out:
# MSE:0.021586397407386812
# R²: 0.2449443992086715

# %%
# L_inf linear (training)

# %%
L_inf = 0
y_hat_linear_is = []
L_inf_array_linear_in=np.array([0]*training_periods,dtype='float64')

for i in range(training_periods):
    x= sm.add_constant(xs['train_linear'][i].values, has_constant='add')
    y_hat_linear_is.append(models['linear'][i].predict(x))
    L_inf_test_linear= np.max(np.abs(np.array(y_hat_linear_is[-1]- ys['train_linear'][i].values)))
    #print(i,MSE_test_linear)
    L_inf_array_linear_in[i]=L_inf_test_linear
    L_inf+=L_inf_test_linear
    
print("L_inf:" + str(L_inf/training_periods))    
L_inf_linear_in=L_inf/training_periods
# Out:
# L_inf:1.458423237777348

# %%
# MSEs NNs (testing)

# %%
MSE =0
r2_sum = 0
MSE_array_NN=np.array([np.nan]*testing_periods, dtype='float64')
r2_array_NN_oos = np.array([np.nan]*training_periods,dtype='float64')
y_hat_NN=[]

for i in range(testing_periods):
    y_hat_NN.append(models['NN'][i].predict(xs['test'][i].values))
    
    r2 = r2_score(ys['test'][i].values, y_hat_NN[-1])
    r2_array_NN_oos[i] = r2
    r2_sum += r2
    
    MSE_test_NN= mean_squared_error(y_hat_NN[-1], ys['test'][i].values)
    MSE_array_NN[i]=MSE_test_NN
    MSE+=MSE_test_NN
    
print("MSE:" + str(MSE/testing_periods))
MSE_NN=MSE/testing_periods
print("R²:" + str(r2_sum/testing_periods))
r2_NN_oos = r2_sum/testing_periods
# Out:
# MSE:0.028383798041404524
# R²:0.03222167460692729

# %%
# L_inf NNs (testing)

# %%
L_inf =0
L_inf_array_NN=np.array([np.nan]*testing_periods, dtype='float64')
y_hat_NN=[]

for i in range(testing_periods):
    y_hat_NN.append(models['NN'][i].predict(xs['test'][i].values))
    L_inf_test_NN= np.max(np.abs(np.array(y_hat_NN[-1]- ys['test'][i].values)))
    L_inf_array_NN[i]=L_inf_test_NN
    L_inf+=L_inf_test_NN
    
print("L_inf:" + str(L_inf/testing_periods))  
L_inf_NN=L_inf/testing_periods
# Out:
# L_inf:1.0652164468241456

# %%
# MSEs NN (training)

# %%
MSE = 0
r2_sum = 0
MSE_array_NN_in=np.array([np.nan]*training_periods, dtype='float64')
r2_array_NN_is = np.array([np.nan]*training_periods,dtype='float64')
y_hat_NN_is =[]

for i in range(training_periods):
    y_hat_NN_is.append(models['NN'][i].predict(xs['train'][i].values))
    
    r2 = r2_score(ys['train'][i].values, y_hat_NN_is[-1])
    r2_array_NN_is[i] = r2
    r2_sum += r2
    
    MSE_test_NN= mean_squared_error(y_hat_NN_is[-1], ys['train'][i].values)
    MSE_array_NN_in[i]=MSE_test_NN
    MSE+=MSE_test_NN
    
print("MSE:" + str(MSE/training_periods)) 
MSE_NN_in=MSE/training_periods
print("R²" + str(r2_sum/training_periods))
r2_NN_is = r2_sum/training_periods
# Out:
# MSE:0.01853721598588011
# R²0.32696165939460514

# %%
# L_inf NNS (training)

# %%
L_inf =0
L_inf_array_NN_in=np.array([np.nan]*training_periods, dtype='float64')
y_hat_NN_is =[]

for i in range(training_periods):
    y_hat_NN_is.append(models['NN'][i].predict(xs['train'][i].values))
    L_inf_test_NN= np.max(np.abs(np.array(y_hat_NN_is[-1]- ys['train'][i].values)))
    L_inf_array_NN_in[i]=L_inf_test_NN
    L_inf+=L_inf_test_NN
    
print("L_inf:" + str(L_inf/training_periods)) 
L_inf_NN_in = L_inf/training_periods
# Out:
# L_inf:0.7982862604103197

# %%
# MSE PLS+NN (testing)

# %%
MSE_array_PLS_NN = {}
y_hat_PLS_NN={}
MSE_PLS_NN = {}
r2_PLS_NN_oos = {}
r2_array_PLS_NN_oos = {}

var_index = 0

for var in vars_explained:
    MSE = 0
    r2_sum = 0
    MSE_array_PLS_NN[var] = np.array([np.nan]*testing_periods, dtype='float64')
    r2_array_PLS_NN_oos[var] = np.array([np.nan]*testing_periods, dtype='float64')
    y_hat_PLS_NN[var] = []
    
    for i in range(testing_periods):
        y_hat_PLS_NN[var].append(models['PLS_NN'][i+var_index].predict(xs['test_PLS'][i+var_index].values))
        
        r2 = r2_score(ys['test_PLS'][i+var_index].values, y_hat_PLS_NN[var][-1])
        r2_array_PLS_NN_oos[var][i] = r2
        r2_sum += r2
        
        MSE_test_PLS_NN = mean_squared_error(y_hat_PLS_NN[var][-1], ys['test_PLS'][i+var_index].values)
        MSE_array_PLS_NN[var][i] = MSE_test_PLS_NN
        MSE += MSE_test_PLS_NN
    
    var_index += testing_periods
    print("MSE " + str(var) + "% : " + str(MSE/testing_periods))
    print("R²  oos " + str(var) + "% : " + str(r2_sum/testing_periods))
    MSE_PLS_NN[var] = MSE/testing_periods
    r2_PLS_NN_oos[var] = r2_sum/testing_periods
# Out:
# MSE 50% : 0.032858924302592754
# R²  oos 50% : 0.0533301438528541
# MSE 80% : 0.02965777519812537
# R²  oos 80% : 0.11947844236201673
# MSE 95% : 0.03732664723990724
# R²  oos 95% : -0.09451736215645704

# %%
# L_inf PLS+NN (testing)

# %%
L_inf_array_PLS_NN = {}
y_hat_PLS_NN={}
L_inf_PLS_NN = {}

var_index = 0

for var in vars_explained:
    L_inf = 0
    L_inf_array_PLS_NN[var] = np.array([0]*testing_periods, dtype='float64')
    y_hat_PLS_NN[var] = []
    
    for i in range(testing_periods):
        y_hat_PLS_NN[var].append(models['PLS_NN'][i+var_index].predict(xs['test_PLS'][i+var_index].values))
        L_inf_test_PLS_NN= np.max(np.abs(np.array(y_hat_PLS_NN[var][-1]- ys['test_PLS'][i+var_index].values)))
        #print(i,L_inf_test_PLS_NN)
        L_inf_array_PLS_NN[var][i]=L_inf_test_PLS_NN
        L_inf+=L_inf_test_PLS_NN
    
    var_index += training_periods
    print("L_inf " + str(var) + "% : " + str(L_inf/testing_periods))  
    L_inf_PLS_NN[var] = L_inf/testing_periods
# Out:
# L_inf 50% : 0.9625064188560376
# L_inf 80% : 0.9710842192102542
# L_inf 95% : 0.9775535006834565

# %%
# MSE PLS+NN (training)

# %%
MSE_array_PLS_NN_in = {}
y_hat_PLS_NN_is = {}
MSE_PLS_NN_in = {}
r2_PLS_NN_is = {}
r2_array_PLS_NN_is = {}


var_index = 0

for var in vars_explained:
    MSE = 0
    r2_sum = 0
    MSE_array_PLS_NN_in[var] = np.array([np.nan]*training_periods, dtype='float64')
    r2_array_PLS_NN_is[var] = np.array([np.nan]*training_periods, dtype='float64')
    y_hat_PLS_NN_is[var] =[]
    
    for i in range(testing_periods):
        y_hat_PLS_NN_is[var].append(models['PLS_NN'][i+var_index].predict(xs['train_PLS'][i+var_index].values))
        
        r2 = r2_score(ys['train_PLS'][i+var_index].values, y_hat_PLS_NN_is[var][-1])
        r2_array_PLS_NN_is[var][i] = r2
        r2_sum += r2

        MSE_test_PLS_NN= mean_squared_error(y_hat_PLS_NN_is[var][-1], ys['train_PLS'][i+var_index].values)
        MSE_array_PLS_NN_in[var][i] = MSE_test_PLS_NN
        MSE += MSE_test_PLS_NN
        
    var_index += training_periods
    print("MSE " + str(var) + "% : " + str(MSE/training_periods)) 
    print("R²  is " + str(var) + "% : " + str(r2_sum/testing_periods))
    MSE_PLS_NN_in[var] = MSE/training_periods
    r2_PLS_NN_is[var] = r2_sum/testing_periods
# Out:
# MSE 50% : 0.021626527844287584
# R²  is 50% : 0.24242973759925737
# MSE 80% : 0.021194633802690866
# R²  is 80% : 0.2498926563009545
# MSE 95% : 0.018485198242380547
# R²  is 95% : 0.3395084495171722

# %%
# L_inf PLS+NN (training)

# %%
L_inf_array_PLS_NN_in = {}
y_hat_PLS_NN_is = {}
L_inf_PLS_NN_in = {}

var_index = 0

for var in vars_explained:
    L_inf =0
    L_inf_array_PLS_NN_in[var] = np.array([0]*training_periods, dtype='float64')
    y_hat_PLS_NN_is[var] = []
    
    for i in range(training_periods):
        y_hat_PLS_NN_is[var].append(models['PLS_NN'][i+var_index].predict(xs['train_PLS'][i+var_index].values))
        #L_inf_test_NN= mean_squared_error(y_hat_NN_is[-1], ys['train'][i].values)
        L_inf_test_PLS_NN= np.max(np.abs(np.array(y_hat_PLS_NN_is[var][-1]- ys['train_PLS'][i+var_index].values)))
        #print(i,MSE_test_NN)
        L_inf_array_PLS_NN_in[var][i]=L_inf_test_PLS_NN
        L_inf+=L_inf_test_PLS_NN
        
    var_index += training_periods
    print("L_inf " + str(var) + "% : " + str(L_inf/training_periods)) 
    L_inf_PLS_NN_in[var] = L_inf/training_periods
# Out:
# L_inf 50% : 0.9081263900885309
# L_inf 80% : 0.9087508878962685
# L_inf 95% : 0.7984578969919015

# %% [markdown]
# # Plot the error norms over time

# %%
Y_to_plot = pd.read_csv('../../data/Y_untouched.csv')
Y_to_plot.dropna(inplace=True)
dates_df = Y_to_plot.drop_duplicates('date')
dates_to_plot = dates_df['date'].str[:7]
dates_to_plot = np.array(dates_to_plot[0:training_periods])

# %%
#colors_PLS = ['steelblue', 'cyan', 'yellow', 'greenyellow', 'forestgreen', 'darkgreen']
colors_PLS = ['steelblue',  'cyan', 'lime']

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

k = 0
for var in vars_explained:
    PLS_NN_label='DPLS ' + str(var) + '% (' + str(round(r2_PLS_NN_oos[var],3)) + ')'
    plt.plot(r2_array_PLS_NN_oos[var], label=PLS_NN_label, color=colors_PLS[k])
    k+=1
    
NN_label='NN (' + str(round(r2_NN_oos,3)) +')'
OLS_label='OLS (' + str(round(r2_linear_oos,3)) +')'

plt.plot(r2_array_NN_oos, color='red', label=NN_label, linewidth=1.0)
plt.plot(r2_array_linear_oos, color='orange', label=OLS_label,  linewidth=1.0)

#plt.yscale('log')
plt.ylabel('R² (out-of-sample)')
plt.xlabel('dates')
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
plt.ylim([-0.5, 1])
plt.savefig('../figure/png_low/R2_oos.png', dpi=100, bbox_inches = "tight")
plt.savefig('../figure/eps_low/R2_oos.eps', format='eps', dpi=100, bbox_inches = "tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

k = 0
for var in vars_explained:
    PLS_NN_label='DPLS ' + str(var) + '% (' + str(round(r2_PLS_NN_is[var],3)) + ')'
    plt.plot(r2_array_PLS_NN_is[var], label=PLS_NN_label, color=colors_PLS[k])
    k+=1
    
NN_label='NN (' + str(round(r2_NN_is,3)) +')'
OLS_label='OLS (' + str(round(r2_linear_is,3)) +')'

plt.plot(r2_array_NN_is, color='red', label=NN_label, linewidth=1.0)
plt.plot(r2_array_linear_is, color='orange', label=OLS_label,  linewidth=1.0)

#plt.yscale('log')
plt.ylabel('R² (in-sample)')
plt.xlabel('dates')
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
plt.ylim([-0.5, 1])
plt.savefig('../figure/png_low/R2_is.png', dpi=100, bbox_inches = "tight")
plt.savefig('../figure/eps_low/R2_is.eps', format='eps', dpi=100, bbox_inches = "tight")
#plt.savefig('../figure/New_PLS_Comparison/R2_is.png', dpi=600, bbox_inches = "tight")
#plt.savefig('MSE_in_error.eps', format='eps',dpi=1200,bbox_inches = "tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

k = 0
for var in vars_explained:
    PLS_NN_label='DPLS ' + str(var) + '% (' + str(round(MSE_PLS_NN_in[var],3)) + ')'
    plt.plot(MSE_array_PLS_NN_in[var], label=PLS_NN_label, color=colors_PLS[k])
    k+=1
    
NN_label='NN (' + str(round(MSE_NN_in,3)) +')'
OLS_label='OLS (' + str(round(MSE_linear_in,3)) +')'

plt.plot(MSE_array_NN_in, color='red', label=NN_label, linewidth=1.0)
plt.plot(MSE_array_linear_in, color='orange', label=OLS_label,  linewidth=1.0)

plt.yscale('log')
plt.ylabel('MSE (in-sample)')
plt.xlabel('dates')
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
plt.savefig('../figure/eps_low/MSE_is_error.eps', format='eps',dpi=100,bbox_inches = "tight")
plt.savefig('../figure/png_low/MSE_is_error.png',dpi=100,bbox_inches = "tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

k = 0
for var in vars_explained:
    PLS_NN_label='DPLS ' + str(var) + '% (' + str(round(L_inf_PLS_NN_in[var],3)) + ')'
    plt.plot(L_inf_array_PLS_NN_in[var], label=PLS_NN_label, color=colors_PLS[k])
    k+=1

NN_label='NN (' + str(round(L_inf_NN_in,3)) +')'
OLS_label='OLS (' + str(round(L_inf_linear_in,3)) +')'

plt.plot(L_inf_array_NN_in, color='red', label=NN_label, linewidth=1.0)
plt.plot(L_inf_array_linear_in, color='orange', label=OLS_label, linewidth=1.0)

plt.yscale('log')
plt.ylabel('$L_{\infty}$ Error (in-sample)')
plt.xlabel('dates')
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
#plt.savefig('L_inf_in_error.eps', format='eps',dpi=1200,bbox_inches = "tight")
plt.savefig('../figure/eps_low/L_inf_is_error.eps', format='eps',dpi=100,bbox_inches = "tight")
plt.savefig('../figure/png_low/L_inf_is_error.png',dpi=100,bbox_inches = "tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

k = 0
for var in vars_explained:
    PLS_NN_label='DPLS ' + str(var) + '% (' + str(round(MSE_PLS_NN[var],3)) + ')'
    plt.plot(MSE_array_PLS_NN[var], label=PLS_NN_label, color=colors_PLS[k])
    k+=1

NN_label='NN (' + str(round(MSE_NN,3)) +')'
OLS_label='OLS (' + str(round(MSE_linear,3)) +')'

plt.plot(MSE_array_NN[:-1], color='red', label=NN_label, linewidth=1.0)
plt.plot(MSE_array_linear[:-1], color='orange', label=OLS_label, linewidth=1.0)

plt.yscale('log')
plt.ylabel('MSE (out-of-sample)')
plt.xlabel('dates')
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
#plt.savefig('MSE_error.eps', format='eps',dpi=1200,bbox_inches = "tight")
plt.ylim([5e-3, 5])
plt.savefig('../figure/eps_low/MSE_oos_error.eps', format='eps',dpi=100,bbox_inches = "tight")
plt.savefig('../figure/png_low/MSE_oos_error.png',dpi=100,bbox_inches = "tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

k = 0
for var in vars_explained:
    PLS_NN_label='DPLS ' + str(var) + '% (' + str(round(L_inf_PLS_NN[var],3)) + ')' 
    plt.plot(L_inf_array_PLS_NN[var], label=PLS_NN_label, color=colors_PLS[k])
    k+=1

NN_label='NN (' + str(round(L_inf_NN,3)) +')'
OLS_label='OLS (' + str(round(L_inf_linear,3)) +')'

plt.plot(L_inf_array_NN[:-1], color='red', label=NN_label, linewidth=1.0)
plt.plot(L_inf_array_linear[:-1], color='orange', label=OLS_label, linewidth=1.0)

plt.yscale('log')
plt.ylabel('$L_{\infty}$ Error (out-of-sample)')
plt.xlabel('dates')
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
#plt.savefig('L_inf_error.eps', format='eps',dpi=1200,bbox_inches = "tight")
#plt.savefig('../figure/eps_low/L_inf_oos_error.eps', format='eps',dpi=100,bbox_inches = "tight")
#plt.savefig('../figure/png_low/L_inf_oos_error.png',dpi=100,bbox_inches = "tight")

# %%
from importlib import reload
plt = reload(matplotlib.pyplot)

list_mean = lambda x : np.mean(x)
returns_50 = np.array(list(map(list_mean, y_hat_PLS_NN[50])))
returns_80 = np.array(list(map(list_mean, y_hat_PLS_NN[80])))
returns_95 = np.array(list(map(list_mean, y_hat_PLS_NN[95])))
returns_NN = np.array(list(map(list_mean, y_hat_NN)))
returns_OLS = np.array(list(map(list_mean, y_hat_linear)))


plt.figure(num=None, figsize=(8, 6), facecolor='w', edgecolor='black')
plt.plot(np.cumsum(returns_50), label="DPLS 50%")
plt.plot(np.cumsum(returns_80), label="DPLS 80%")
plt.plot(np.cumsum(returns_95), label="DPLS 95%")
plt.plot(np.cumsum(returns_NN), label="NN")
plt.plot(np.cumsum(returns_OLS), label="OLS")

#ax.set_xticks(np.arange(0,len(dates_to_plot)-1,20))
#ax.set_xticklabels(dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)])
legend = plt.legend()
frame = legend.get_frame()
frame.set_facecolor('white')
frame.set_edgecolor('gray')
plt.show()

# %% [markdown]
# # Additional analysis of outliers

# %%
# analysis with removal of outlier

# %%
outlier_index=np.argsort(MSE_array_linear)[len(MSE_array_linear)-2:len(MSE_array_linear)]

# %%
outlier_index
# Out:
# array([303, 111], dtype=int64)

# %%
# MSE without outliers

# %%
(np.sum(MSE_array_linear) - np.sum(MSE_array_linear[outlier_index]))/(testing_periods-2)
# Out:
# 0.23737731260443648

# %%
# L_inf without outliers

# %%
(np.sum(L_inf_array_linear) - np.sum(L_inf_array_linear[outlier_index]))/(testing_periods-2)
# Out:
# 2.6601951374289214

# %%
print(testing_periods-120)
print(303-211)
# Out:
# 211
# 92

# %%
for index in outlier_index:
    print(index)
    print(dates[index])
# Out:
# 303
# 2015-03-01
# 111
# 1999-03-01

# %% [markdown]
# # Calculate information ratios

# %%
"""
 Information Ratio Calculation over most recent 10 year period
"""    

info_ratio = []
info_ratio_linear = []
info_ratio_NN = []
info_ratio_PLS_NN_50 = []
info_ratio_PLS_NN_80 = []
info_ratio_PLS_NN_95 = []
info_ratio_wn = []

m_range = [10,15,20,25,30,35,40,45,50]
for m in m_range:
    excess_returns_linear = []
    excess_returns_NN = []
    excess_returns_PLS_NN_50 = []
    excess_returns_PLS_NN_80 = []
    excess_returns_PLS_NN_95 = []
    excess_returns_wn = []
    
    excess_returns_std_linear = []
    excess_returns_std_NN = []
    excess_returns_std_PLS_NN_50 = []
    excess_returns_std_PLS_NN_80 = []
    excess_returns_std_PLS_NN_95 = []
    excess_returns_std_wn = []
    
    idx_linear = []
    idx_NN = []
    idx_PLS_NN_50 = []
    idx_PLS_NN_80 = []
    idx_PLS_NN_95 = []
    
    for i in range((testing_periods-120),testing_periods):
        idx_linear.append(np.argsort(-y_hat_linear[i].flatten())[:m])
        excess_returns_linear.append(np.mean(np.array(ys['test'][i])[idx_linear[-1]] ))
        
        idx_NN.append(np.argsort(-y_hat_NN[i].flatten())[:m])
        excess_returns_NN.append(np.mean(np.array(ys['test'][i])[idx_NN[-1]] ))
        
        idx_PLS_NN_50.append(np.argsort(-y_hat_PLS_NN[50][i].flatten())[:m])
        excess_returns_PLS_NN_50.append(np.mean(np.array(ys['test'][i])[idx_PLS_NN_50[-1]] ))
        
        idx_PLS_NN_80.append(np.argsort(-y_hat_PLS_NN[80][i].flatten())[:m])
        excess_returns_PLS_NN_80.append(np.mean(np.array(ys['test'][i])[idx_PLS_NN_80[-1]] ))

        idx_PLS_NN_95.append(np.argsort(-y_hat_PLS_NN[95][i].flatten())[:m])
        excess_returns_PLS_NN_95.append(np.mean(np.array(ys['test'][i])[idx_PLS_NN_95[-1]] ))
        
        #White Noise IR
        wn = np.asarray(random.sample(range(1, len(ys['test'][i])),m))
        excess_returns_wn.append(np.mean(np.array(ys['test'][i])[wn]))
        
    excess_returns_std_linear.append(np.std(excess_returns_linear))
    info_ratio_linear.append(np.mean(excess_returns_linear)/excess_returns_std_linear)
    
    excess_returns_std_NN.append(np.std(excess_returns_NN))
    info_ratio_NN.append(np.mean(excess_returns_NN)/excess_returns_std_NN)
    
    excess_returns_std_PLS_NN_50.append(np.std(excess_returns_PLS_NN_50))
    info_ratio_PLS_NN_50.append(np.mean(excess_returns_PLS_NN_50)/excess_returns_std_PLS_NN_50)
    
    excess_returns_std_PLS_NN_80.append(np.std(excess_returns_PLS_NN_80))
    info_ratio_PLS_NN_80.append(np.mean(excess_returns_PLS_NN_80)/excess_returns_std_PLS_NN_80)
    
    excess_returns_std_PLS_NN_95.append(np.std(excess_returns_PLS_NN_95))
    info_ratio_PLS_NN_95.append(np.mean(excess_returns_PLS_NN_95)/excess_returns_std_PLS_NN_95)
    
    excess_returns_std_wn.append(np.std(excess_returns_wn))
    info_ratio_wn.append(np.mean(excess_returns_wn)/excess_returns_std_wn)

# %%
plt.figure(figsize=(8,5))
wn_label='Random (' + str(round(np.mean(info_ratio_wn),3)) + ')'
plt.plot(m_range, info_ratio_wn, label=wn_label, color='black')

OLS_label='OLS (' + str(round(np.mean(info_ratio_linear),3)) + ')'
plt.plot(m_range, info_ratio_linear, label=OLS_label, color='blue')

NN_label='NN (' + str(round(np.mean(info_ratio_NN),3)) + ')'
plt.plot(m_range, info_ratio_NN, label=NN_label, color='red')

PLS_NN_label='DPLS 50% (' + str(round(np.mean(info_ratio_PLS_NN_50),3)) + ')'
plt.plot(m_range, info_ratio_PLS_NN_50, label=PLS_NN_label, color='steelblue')

PLS_NN_label='DPLS 80% (' + str(round(np.mean(info_ratio_PLS_NN_80),3)) + ')'
plt.plot(m_range, info_ratio_PLS_NN_80, label=PLS_NN_label, color='cyan')

PLS_NN_label='DPLS 95% (' + str(round(np.mean(info_ratio_PLS_NN_95),3)) + ')'
plt.plot(m_range, info_ratio_PLS_NN_95, label=PLS_NN_label, color='green')

#plt.plot(m_range, info_ratio_NN_relu, label='NN (ReLU 10)', color='red', linestyle='--')
plt.xlabel('Number of Stocks')
plt.ylabel('Information Ratio')
plt.legend(loc='best', bbox_to_anchor=(0.63, 0.3, 0, 0))
plt.savefig('../figure/eps_low/IR.eps', format='eps', dpi=100,bbox_inches = "tight")
plt.savefig('../figure/png_low/IR.png', format='png', dpi=100,bbox_inches = "tight")
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
X.columns = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9',
       'F10', 'F11', 'F12', 'F13', 'F14', 'F15', 'F16', 'F17', 'F18',
       'I0', 'I1', 'I2', 'I3', 'I4', 'I5', 'SI0', 'SI1', 'SI2', 'SI3',
       'SI4', 'SI5', 'SI6', 'SI7', 'SI8', 'SI9', 'SI10', 'S0', 'S1',
       'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'IG0',
       'IG1', 'IG2', 'IG3', 'date']

# %%
len(test)
# Out:
# 50

# %% [markdown]
# # Sector analysis

# %%
"""
 Sector analysis over most recent 10 year period.
"""    


m_range = [50]

df_WN = pd.DataFrame(columns=['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9'])
df_linear = pd.DataFrame(columns=['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9'])
df_NN = pd.DataFrame(columns=['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9'])
df_PLS_NN_50 = pd.DataFrame(columns=['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9'])
df_PLS_NN_80 = pd.DataFrame(columns=['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9'])
df_PLS_NN_95 = pd.DataFrame(columns=['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9'])



for m in m_range:
    idx_linear = []
    idx_NN = []
    idx_PLS_NN_50 = []
    idx_PLS_NN_80 = []
    idx_PLS_NN_95 = []
    idx_WN = []
    for i in range((testing_periods-120),testing_periods):
        idx_linear.append(np.argsort(-y_hat_linear[i].flatten())[:m])
        series=pd.Series(X[['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']].iloc[idx_linear[-1]].mean())
        df_linear=df_linear.append(series, ignore_index=True)
                
        idx_NN.append(np.argsort(-y_hat_NN[i].flatten())[:m])
        series=pd.Series(X[['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']].iloc[idx_NN[-1]].mean())
        df_NN=df_NN.append(series, ignore_index=True)
        
        idx_PLS_NN_50.append(np.argsort(-y_hat_PLS_NN[50][i].flatten())[:m])
        series=pd.Series(X[['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']].iloc[idx_PLS_NN_50[-1]].mean())
        df_PLS_NN_50=df_PLS_NN_50.append(series, ignore_index=True)
        
        idx_PLS_NN_80.append(np.argsort(-y_hat_PLS_NN[80][i].flatten())[:m])
        series=pd.Series(X[['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']].iloc[idx_PLS_NN_80[-1]].mean())
        df_PLS_NN_80=df_PLS_NN_80.append(series, ignore_index=True)
        
        idx_PLS_NN_95.append(np.argsort(-y_hat_PLS_NN[95][i].flatten())[:m])
        series=pd.Series(X[['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']].iloc[idx_PLS_NN_95[-1]].mean())
        df_PLS_NN_95=df_PLS_NN_95.append(series, ignore_index=True)
 
        #White Noise IR
        idx_WN.append(np.random.choice(np.arange(0,len(ys['test'][i])),m))
        series=pd.Series(X[['S0', 'S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9']].iloc[idx_WN[-1]].mean())
        df_WN=df_WN.append(series, ignore_index=True)

# %%
GICS={'S0':'Energy','S1':'Materials','S2':'Industrials','S3':'Consumer\nDiscretionary','S4':'Consumer\nStaples','S5':'Health Care','S6':'Financials','S7':'Information\nTechnology','S8':'Communication\nServices','S9':'Utilities','S10':'Real\nEstate'}

# %%
GICS_to_save={'S0':'Energy','S1':'Materials','S2':'Industrials','S3':'Consumer_Discretionary','S4':'Consumer_Staples','S5':'Health_Care','S6':'Financials','S7':'Information_Technology','S8':'Communication_Services','S9':'Utilities','S10':'Real_Estate'}

# %%
def trim_axs(axs, N):
    """
    Reduce *axs* to *N* Axes. All further Axes are removed from the figure.
    """
    axs = axs.flat
    for ax in axs[N:]:
        ax.remove()
    return axs[:N]

# %%
import seaborn as sns

# %%
df_PLS_50_to_plot_sectors = df_PLS_NN_50.T
df_PLS_50_to_plot_sectors.columns = dates_to_plot[np.arange(1-120,1)]
df_PLS_50_to_plot_sectors = df_PLS_50_to_plot_sectors.rename(index=GICS)

df_PLS_80_to_plot_sectors = df_PLS_NN_80.T
df_PLS_80_to_plot_sectors.columns = dates_to_plot[np.arange(1-120,1)]
df_PLS_80_to_plot_sectors = df_PLS_80_to_plot_sectors.rename(index=GICS)

df_PLS_95_to_plot_sectors = df_PLS_NN_95.T
df_PLS_95_to_plot_sectors.columns = dates_to_plot[np.arange(1-120,1)]
df_PLS_95_to_plot_sectors = df_PLS_95_to_plot_sectors.rename(index=GICS)

df_NN_to_plot_sectors = df_NN.T
df_NN_to_plot_sectors.columns = dates_to_plot[np.arange(1-120,1)]
df_NN_to_plot_sectors = df_NN_to_plot_sectors.rename(index=GICS)

df_linear_to_plot_sectors = df_linear.T
df_linear_to_plot_sectors.columns = dates_to_plot[np.arange(1-120,1)]
df_linear_to_plot_sectors = df_linear_to_plot_sectors.rename(index=GICS)

df_WN_to_plot_sectors = df_WN.T
df_WN_to_plot_sectors.columns = dates_to_plot[np.arange(1-120,1)]
df_WN_to_plot_sectors = df_WN_to_plot_sectors.rename(index=GICS)

# %%
names_fig_sector = ["heatmap_sector_DPLS50", "heatmap_sector_DPLS80", "heatmap_sector_DPLS95", "heatmap_sector_NN", "heatmap_sector_linear", "heatmap_sector_WN"]
for i,df in enumerate([df_PLS_50_to_plot_sectors, df_PLS_80_to_plot_sectors, df_PLS_95_to_plot_sectors, df_NN_to_plot_sectors, df_linear_to_plot_sectors, df_WN_to_plot_sectors]):
    plt.figure(figsize=(16.7,6.7))
    indx_sorted = np.mean(df, axis=1).sort_values(ascending=False).index
    sns.heatmap(df.reindex(index = indx_sorted), cmap = 'Blues', linewidths=0, vmin=-0.5, vmax=0.9)
    plt.tick_params(axis='y',rotation=0)
    name_fig = "../figure/heatmaps/"+names_fig_sector[i]+".png"
    plt.savefig(name_fig)

# %%
models_sector = pd.concat([np.mean(df_PLS_50_to_plot_sectors, axis=1),
                           np.mean(df_PLS_80_to_plot_sectors, axis=1),
                           np.mean(df_PLS_95_to_plot_sectors, axis=1),
                           np.mean(df_NN_to_plot_sectors, axis=1), 
                           np.mean(df_linear_to_plot_sectors, axis=1),
                           np.mean(df_WN_to_plot_sectors, axis=1)], axis=1)
models_sector.columns = ["DPLS 50%", "DPLS 80%", "DPLS 95%", "NN", "OLS", "WN"]

# %%
#yticklabels = ['Energy','Materials','Industrials','Consumer Discretionary','Consumer Staples','Health Care','Financials','Information Technology','Communication Services','Utilities']
indx_sorted = np.mean(models_sector, axis=1).sort_values(ascending=False).index

cmap = sns.color_palette("mako")
sns.set(rc={'figure.figsize':(9,10)})
sns.heatmap(models_sector.reindex(index = indx_sorted), cmap = 'Blues', linewidths=0.01, annot=True, robust=True)
#plt.title("Mean of the Sector Heatmap for all the models")
plt.tick_params(axis='both',rotation=0)
plt.savefig('../figure/heatmaps/heatmap_sectors_mean_models.png', bbox_inches = "tight")

# %%
rows=2
cols = 4
#figsize=(20.5, 10)

n = 0

sectors = ['S6','S3','S2','S9','S1','S4','S7','S5'] # ,'S0','S8']

#fig1, axs = plt.subplots(rows, cols, figsize=figsize, constrained_layout=True)
#axs = trim_axs(axs, len(sectors))
for sector in sectors:
    fig = plt.figure(figsize=[10, 5])
    ax = fig.add_subplot(1, 1, 1)
    ax.set_title('%s' % str(GICS[sector]))
    #set(ax,'xtickl',get(ax,'xtick'))
    wn_label='Random: ' + str(round(np.mean(df_WN[sector]),3)) + ' (' + str(round(np.std(df_WN[sector]),3))  + ')'
    OLS_label='OLS: ' + str(round(np.mean(df_linear[sector]),3)) +  ' (' + str(round(np.std(df_linear[sector]),3)) + ')'
    NN_label='NN: ' + str(round(np.mean(df_NN[sector]),3)) +  ' (' + str(round(np.std(df_NN[sector]),3)) +  ')'
    PLS_NN_50_label='DPLS 50%: ' + str(round(np.mean(df_PLS_NN_50[sector]),3)) +  ' (' + str(round(np.std(df_PLS_NN_50[sector]),3)) +  ')'
    
    ax.plot(range(0,len(df_NN)), df_NN[sector], 'o', ls='--', ms=2, color='red', linewidth=0.75, label=NN_label)
    ax.plot(range(0,len(df_linear)), df_linear[sector], 'o', ls='--', ms=2, color='blue', linewidth=0.75, label=OLS_label)
    ax.plot(range(0,len(df_PLS_NN_50)), df_PLS_NN_50[sector], 'o', ls='--', ms=2, color='green', linewidth=0.75, label=PLS_NN_50_label)
    #ax.plot(range(0,len(df_WN)), df_WN[sector], 'o', ls='--', ms=4, color='black', label=wn_label)
    
    #ax.xlabel('dates')
    #ax.set_xticklabels(np.arange(0,120,12), dates[np.arange(n-120,n,12)], rotation=70)
    fontdict= {'fontsize': 10,
    'fontweight': 1,
     'verticalalignment': 'bottom'}
    ax.set_ylim([np.min(df_NN[sector])-0.020,np.max(df_linear[sector])+0.20])
    ax.set_xticks(np.arange(0,120,12))
    ax.set_xticklabels(dates_to_plot[np.arange(n-120,n,12)])#, fontdict=fontdict) #, rotation=70)
    ax.tick_params(axis='x', rotation=50)
    ax.axvline(x=92, linestyle='--', color='black')
    ax.legend(loc='upper left')#, bbox_to_anchor=(1, 0.5))
    name = "../figure/png_low/sector_tilts_hi/Sector_%s.png" % (str(GICS_to_save[sector]))
    fig.savefig(name, format='png',dpi=100, bbox_inches = "tight")
    
    name = "../figure/eps_low/sector_tilts_hi/Sector_%s.eps" % (str(GICS_to_save[sector]))
    fig.savefig(name, format='eps',dpi=100, bbox_inches = "tight")
    
    name_pickle = "../data/figure_data/sector_analysis/%s.fig.pickle" % ('Sector_' + str(GICS_to_save[sector]))
    pickle.dump(fig, open(name_pickle, 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# show factor tilts on 2015-10-01 - the date of the outlier

# %%
print([GICS[sector] for sector in sectors])
# Out:
# ['Financials', 'Consumer Discretionary', 'Industrials', 'Utilities', 'Materials', 'Consumer Staples', 'Information Technology', 'Health Care']

# %%
print(len(df_NN))
print(testing_periods-120)
print((testing_periods-120)-303)
# Out:
# 120
# 211
# -92

# %%
NN_outlier = df_NN.iloc[90].values
OLS_outlier = df_linear.iloc[90].values
PLS_NN_outlier = df_PLS_NN_50.iloc[90].values

plt.plot(range(0,10), NN_outlier, color='red', label='NN')
plt.plot(range(0,10), OLS_outlier, color='blue', label='OLS')
plt.plot(range(0,10), PLS_NN_outlier, color='green', label='DPLS 50%')
plt.xticks(range(0,10), [ GICS[sector] for sector in sectors ], rotation=70)
plt.legend()
#plt.ylim([-0.2, 0.2])
plt.savefig('../figure/png_low/sector_tilts_2015-03-01.png', format='png',dpi=100,bbox_inches = "tight")
plt.savefig('../figure/eps_low/sector_tilts_2015-03-01.eps', format='eps',dpi=100,bbox_inches = "tight")

name_pickle = "../data/figure_data/outliers_analysis/sector_tilts_2015-03-01.fig.pickle"
pickle.dump(fig, open(name_pickle, 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
 
# Data
r = [0,1,2]

keys = df_WN.columns
raw_data = {}
for key in keys:
   raw_data[key]=[]
   raw_data[key].append(df_linear.mean()[key]) 
   raw_data[key].append(df_NN.mean()[key]) 
   raw_data[key].append(df_WN.mean()[key]) 

df = pd.DataFrame(raw_data)

# %%
# From raw value to percentage
plt.figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')
totals = [i+j+k+l+m+n+o+p+q+r for i,j,k,l,m,n,o,p,q,r in zip(df['S0'], df['S1'], df['S2'], df['S3'], df['S4'],df['S5'],df['S6'], df['S7'], df['S8'], df['S9'] )]
S0Bars = [i / j * 100 for i,j in zip(df['S0'], totals)]
S1Bars = [i / j * 100 for i,j in zip(df['S1'], totals)]
S2Bars = [i / j * 100 for i,j in zip(df['S2'], totals)]
S3Bars = [i / j * 100 for i,j in zip(df['S3'], totals)]
S4Bars = [i / j * 100 for i,j in zip(df['S4'], totals)]
S5Bars = [i / j * 100 for i,j in zip(df['S5'], totals)]
S6Bars = [i / j * 100 for i,j in zip(df['S6'], totals)]
S7Bars = [i / j * 100 for i,j in zip(df['S7'], totals)]
S8Bars = [i / j * 100 for i,j in zip(df['S8'], totals)]
S9Bars = [i / j * 100 for i,j in zip(df['S9'], totals)]
#S10Bars = [i / j * 100 for i,j in zip(df['S10'], totals)]
 
# plot
barWidth = 0.85
names = ('DNN','Linear','Universe')
# Create green Bars
plt.bar(r, S0Bars, color='#b5ffb9', edgecolor='white', width=barWidth, label=GICS['S0'])
# Create orange Bars
plt.bar(r, S1Bars, bottom=S0Bars, color='#f9bc86', edgecolor='white', width=barWidth, label=GICS['S1'])
# Create blue Bars
plt.bar(r, S2Bars, bottom=[i+j for i,j in zip(S0Bars, S1Bars)], color='#a3acff', edgecolor='white', width=barWidth, label=GICS['S2'])
# Create blue Bars
plt.bar(r, S3Bars, bottom=[i+j+k for i,j,k in zip(S0Bars, S1Bars, S2Bars)], color='#5b3475', edgecolor='white', width=barWidth, label=GICS['S3'])
# Create blue Bars
plt.bar(r, S4Bars, bottom=[i+j+k+l for i,j,k,l in zip(S0Bars, S1Bars, S2Bars, S3Bars)], color='#e80027', edgecolor='white', width=barWidth, label=GICS['S4'])
# Create blue Bars
plt.bar(r, S5Bars, bottom=[i+j+k+l+m for i,j,k,l,m in zip(S0Bars, S1Bars, S2Bars, S3Bars, S4Bars)], color='#471e02', edgecolor='white', width=barWidth, label=GICS['S5'])
# Create blue Bars
plt.bar(r, S6Bars, bottom=[i+j+k+l+m+n for i,j,k,l,m,n in zip(S0Bars, S1Bars, S2Bars, S3Bars, S4Bars, S5Bars)], color='#f40088', edgecolor='white', width=barWidth, label=GICS['S6'])
# Create blue Bars
plt.bar(r, S7Bars, bottom=[i+j+k+l+m+n+o for i,j,k,l,m,n,o in zip(S0Bars, S1Bars, S2Bars, S3Bars, S4Bars, S5Bars,S6Bars)], color='#c9f7ca', edgecolor='white', width=barWidth, label=GICS['S7'])
# Create blue Bars
plt.bar(r, S8Bars, bottom=[i+j+k+l+m+n+o+p for i,j,k,l,m,n,o,p in zip(S0Bars, S1Bars, S2Bars, S3Bars, S4Bars, S5Bars,S6Bars,S7Bars)], color='#ca642d', edgecolor='white', width=barWidth, label=GICS['S8'])
# Create blue Bars
plt.bar(r, S9Bars, bottom=[i+j+k+l+m+n+o+p+q for i,j,k,l,m,n,o,p,q in zip(S0Bars, S1Bars, S2Bars, S3Bars, S4Bars, S5Bars,S6Bars,S7Bars,S8Bars)], color='#295151', edgecolor='white', width=barWidth, label=GICS['S9'])

#plt.bar(r, S10Bars, bottom=[i+j+k+l+m+n+o+p+q+r for i,j,k,l,m,n,o,p,q,r in zip(S0Bars, S1Bars, S2Bars, S3Bars, S4Bars, S5Bars,S6Bars,S7Bars,S8Bars,S9Bars)], color='#a3ff00', edgecolor='white', width=barWidth, label=GICS['S10'])

    
# Custom x axis
plt.xticks(r, names)
#plt.xlabel("group")
plt.legend(loc='upper left', bbox_to_anchor=(1,1), ncol=1)

# Show graphic
#plt.show()
plt.savefig('sectors.png', format='png',dpi=1200)#,bbox_inches = "tight")

# %% [markdown]
# # factor analysis

# %%
"""
 factor analysis over most recent 10 year period.
"""    


m_range = [50]
columns=['F2', 'F3', 'F5', 'F6', 'F7','F8', 'F9', 'F12', 'F13', 'F14', 'F16', 'F17','F18']

df_WN = pd.DataFrame(columns=columns)
df_linear = pd.DataFrame(columns=columns)
df_NN = pd.DataFrame(columns=columns)
df_PLS_NN_50 = pd.DataFrame(columns=columns)
df_PLS_NN_80 = pd.DataFrame(columns=columns)
df_PLS_NN_95 = pd.DataFrame(columns=columns)

for m in m_range:
    idx_linear = []
    idx_NN = []
    idx_PLS_NN_50 = []
    idx_PLS_NN_80 = []
    idx_PLS_NN_95 = []
    idx_WN = []
    for i in range((testing_periods-120),testing_periods):
        idx_linear.append(np.argsort(-y_hat_linear[i].flatten())[:m])
        series=pd.Series(X[columns].iloc[idx_linear[-1]].mean())
        df_linear=df_linear.append(series, ignore_index=True)
        
        idx_NN.append(np.argsort(-y_hat_NN[i].flatten())[:m])
        series=pd.Series(X[columns].iloc[idx_NN[-1]].mean())
        df_NN=df_NN.append(series, ignore_index=True)
         
        idx_PLS_NN_50.append(np.argsort(-y_hat_PLS_NN[50][i].flatten())[:m])
        series=pd.Series(X[columns].iloc[idx_PLS_NN_50[-1]].mean())
        df_PLS_NN_50 = df_PLS_NN_50.append(series, ignore_index=True)
        
        idx_PLS_NN_80.append(np.argsort(-y_hat_PLS_NN[80][i].flatten())[:m])
        series=pd.Series(X[columns].iloc[idx_PLS_NN_80[-1]].mean())
        df_PLS_NN_80 = df_PLS_NN_80.append(series, ignore_index=True)
        
        idx_PLS_NN_95.append(np.argsort(-y_hat_PLS_NN[95][i].flatten())[:m])
        series=pd.Series(X[columns].iloc[idx_PLS_NN_95[-1]].mean())
        df_PLS_NN_95 = df_PLS_NN_95.append(series, ignore_index=True)

        #White Noise IR
        idx_WN.append(np.random.choice(np.arange(0,len(ys['test'][i])),m))
        series=pd.Series(X[columns].iloc[idx_WN[-1]].mean())
        df_WN=df_WN.append(series, ignore_index=True)

# %%
# show factor tilts on 2015-10-01 - the date of the outlier

# %%
names_factors={'F1':'B/P', 'F2':'CF/P', 'F3':'E/P', 'F4':'S/EV', 'F5':'EB/EV', 'F6':'FE/P', 'F7':'TAG', 'F8':'MC', 'F9':'S', 'F10':'TA', 'F11':'TrA', 'F12':'EaV/TA', 'F13':'CFV/TA', 'F14':'SV/TA','F15':'RV', 'F16':'CB','F17':'Div', 'F18':'EG'}

# %%
names_to_save={'F1':'B-P', 'F2':'CF-P', 'F3':'E-P', 'F4':'S-EV', 'F5':'EB-EV', 'F6':'FE-P', 'F7':'TAG', 'F8':'MC', 'F9':'S', 'F10':'TA', 'F11':'TrA', 'F12':'EaV-TA', 'F13':'CFV-TA', 'F14':'SV-TA','F15':'RV', 'F16':'CB','F17':'Div', 'F18':'EG'}

# %%
full_names={'F1':'Book to Price (B/P)', 'F2': 'Cash Flow to Price (CF/P)', 'F3':'Earning to Price (E/P)', 'F5': 'EBIDTA to EV (EB/EV)', 'F7': 'Total Asset Growth (TAG)', 'F13':'Cash Flow Volatility to Total Assets (CFV/TA)', 'F14':'Sales Volatility to Total Assets (SV/TA)', 'F16': 'Rolling CAPM Beta (CB)'}

# %%
df_PLS_NN_50_to_plot_factors = df_PLS_NN_50.T
df_PLS_NN_50_to_plot_factors.columns = dates_to_plot[np.arange(1-120,1)]
df_PLS_NN_50_to_plot_factors = df_PLS_NN_50_to_plot_factors.rename(index=names_factors)

df_PLS_NN_80_to_plot_factors = df_PLS_NN_80.T
df_PLS_NN_80_to_plot_factors.columns = dates_to_plot[np.arange(1-120,1)]
df_PLS_NN_80_to_plot_factors = df_PLS_NN_80_to_plot_factors.rename(index=names_factors)

df_PLS_NN_95_to_plot_factors = df_PLS_NN_95.T
df_PLS_NN_95_to_plot_factors.columns = dates_to_plot[np.arange(1-120,1)]
df_PLS_NN_95_to_plot_factors = df_PLS_NN_95_to_plot_factors.rename(index=names_factors)

df_NN_to_plot_factors = df_NN.T
df_NN_to_plot_factors.columns = dates_to_plot[np.arange(1-120,1)]
df_NN_to_plot_factors = df_NN_to_plot_factors.rename(index=names_factors)

df_linear_to_plot_factors = df_linear.T
df_linear_to_plot_factors.columns = dates_to_plot[np.arange(1-120,1)]
df_linear_to_plot_factors = df_linear_to_plot_factors.rename(index=names_factors)

df_WN_to_plot_factors = df_WN.T
df_WN_to_plot_factors.columns = dates_to_plot[np.arange(1-120,1)]
df_WN_to_plot_factors = df_WN_to_plot_factors.rename(index=names_factors)

# %%
names_fig_factor = ["heatmap_factor_DPLS50", "heatmap_factor_DPLS80", "heatmap_factor_DPLS95", "heatmap_factor_NN", "heatmap_factor_linear", "heatmap_factor_WN"]
#yticklabels=['F2:CF-P', 'F3:E-P', 'F5:EB-EV', 'F6:FE-P', 'F7:TAG', 'F8:MC', 'F9:S', 'F12:EaV-TA', 'F13:CFV-TA', 'F14:SV-TA', 'F16:CB','F17:Div', 'F18:EG']

for i,df in enumerate([df_PLS_NN_50_to_plot_factors, df_PLS_NN_80_to_plot_factors, df_PLS_NN_95_to_plot_factors, df_NN_to_plot_factors, df_linear_to_plot_factors, df_WN_to_plot_factors]):
    plt.figure(figsize=(16.7,6.7))    
    cmap = sns.color_palette("mako")
    indx_sorted = np.mean(df, axis=1).sort_values(ascending=False).index
    sns.heatmap(df.reindex(index = indx_sorted), cmap = 'Blues', linewidths=0, vmin=-0.3, vmax=0.5)
    plt.tick_params(axis='y',rotation=0)
    name_fig = "../figure/heatmaps/"+names_fig_factor[i]+".png"
    plt.savefig(name_fig)

# %%
models_factor = pd.concat([np.mean(df_PLS_NN_50_to_plot_factors, axis=1), 
                           np.mean(df_PLS_NN_80_to_plot_factors, axis=1), 
                           np.mean(df_PLS_NN_95_to_plot_factors, axis=1), 
                           np.mean(df_NN_to_plot_factors, axis=1), 
                           np.mean(df_linear_to_plot_factors, axis=1),
                           np.mean(df_WN_to_plot_factors, axis=1)], axis=1)
models_factor.columns = ["DPLS 50%", "DPLS 80%", "DPLS 95%", "NN", "OLS", "WN"]
#models_factor.rename(index=names)
#models_factor.index = ['F1:B-P', 'F2:CF-P', 'F3:E-P', 'F4:S-EV', 'F5:EB-EV', 'F6:FE-P', 'F7:TAG', 'F8:MC', 'F9:S', 'F10:TA', 'F11:TrA', 'F12:EaV-TA', 'F13:CFV-TA', 'F14:SV-TA','F15:RV', 'F16:CB','F17:Div', 'F18:EG']
#models_factor.index = ['F1:B-P', 'F2:CF-P', 'F3:E-P', 'F4:S-EV', 'F5:EB-EV', 'F6:FE-P', 'F7:TAG', 'F8:MC', 'F9:S', 'F10:TA', 'F11:TrA', 'F12:EaV-TA', 'F13:CFV-TA', 'F14:SV-TA','F15:RV', 'F16:CB','F17:Div', 'F18:EG']

# %%
#yticklabels=['F2:CF-P', 'F3:E-P', 'F5:EB-EV', 'F6:FE-P', 'F7:TAG', 'F8:MC', 'F9:S', 'F12:EaV-TA', 'F13:CFV-TA', 'F14:SV-TA', 'F16:CB','F17:Div', 'F18:EG']
cmap = sns.color_palette("mako")
indx_sorted = np.mean(models_factor, axis=1).sort_values(ascending=False).index
sns.set(rc={'figure.figsize':(9,10)})
sns.heatmap(models_factor.reindex(index = indx_sorted), cmap = 'Blues', linewidths=0.01, annot=True, robust=True)
plt.tick_params(axis='both',rotation=0)

plt.savefig('../figure/heatmaps/heatmap_factors_mean_models.png', bbox_inches = "tight")

# %%
df_NN.iloc[90].values
# Out:
# array([-0.97556396, -0.2803169 , -0.00283392,  0.01089372, -0.00192857,
#         0.08437857, -0.21372287, -0.19813805, -0.0281002 ,  0.00676939,
#        -0.11293519, -0.21470165, -0.1686803 ,  0.03397986])

# %%
NN_outlier = df_NN.iloc[90].values
OLS_outlier = df_linear.iloc[90].values
PLS_NN_outlier = df_PLS_NN_50.iloc[90].values

plt.plot(range(0,14), NN_outlier, color='red', label='NN')
plt.plot(range(0,14), OLS_outlier, color='blue', label='OLS')
plt.plot(range(0,14), PLS_NN_outlier, color='green', label='DPLS 50%')
plt.xticks(range(0,14), [ names[column] for column in columns ], rotation=70)
plt.legend()
#plt.ylim([-0.2, 0.2])
plt.savefig('../figure/png_low/factor_tilts_2015-03-01.png', format='png',dpi=100,bbox_inches = "tight")
plt.savefig('../figure/eps_low/factor_tilts_2015-03-01.eps', format='eps',dpi=100,bbox_inches = "tight")


name_pickle = "../data/figure_data/outliers_analysis/factor_tilts_2015-03-01.fig.pickle"
pickle.dump(fig, open(name_pickle, 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
rows=2
cols = 4
#figsize=(20.5, 10)
# plot a subset of factors
factors=['F1', 'F2', 'F3', 'F5',  'F7', 'F13', 'F14','F16']

#factors=columns #uncomment for all factors
#fig1, axs = plt.subplots(rows, cols, figsize=figsize, constrained_layout=True)
#axs = trim_axs(axs, len(factors))
for factor in factors:
    fig = plt.figure(figsize=[10, 5])
    ax = fig.add_subplot(1, 1, 1)
    ax.set_title('%s' % str(full_names[factor]))
    
    wn_label='Random: ' + str(round(np.mean(df_WN[factor]),3)) + ' (' + str(round(np.std(df_WN[factor]),3))  + ')'
    OLS_label='OLS: ' + str(round(np.mean(df_linear[factor]),3)) +  ' (' + str(round(np.std(df_linear[factor]),3)) + ')'
    NN_label='NN: ' + str(round(np.mean(df_NN[factor]),3)) +  ' (' + str(round(np.std(df_NN[factor]),3)) +  ')'
    PLS_NN_label='DPLS 50%: ' + str(round(np.mean(df_PLS_NN_50[factor]),3)) +  ' (' + str(round(np.std(df_PLS_NN_50[factor]),3)) +  ')'
    
    ax.plot(range(0,len(df_NN)), df_NN[factor], 'o', ls='--', ms=2, color='red',linewidth=0.75, label=NN_label)
    ax.plot(range(0,len(df_linear)), df_linear[factor], 'o', ls='--', ms=2, color='blue',linewidth=0.75, label=OLS_label)
    ax.plot(range(0,len(df_PLS_NN_50)), df_PLS_NN_50[factor], 'o', ls='--', ms=2, color='green',linewidth=0.75, label=PLS_NN_label)
    #ax.plot(range(0,len(df_WN)), df_WN[sector], 'o', ls='--', ms=4, color='black', label=wn_label)
    
    #ax.xlabel('dates')
    #ax.set_xticklabels(np.arange(0,120,12), dates[np.arange(n-120,n,12)], rotation=70)
    fontdict= {'fontsize': 10,
    'fontweight': 1,
     'verticalalignment': 'baseline'}
    if factor == 'F5':
        #ax.set_ylim([np.min(df_NN[factor])-0.025,np.max(df_linear[factor])+0.15])
        ax.set_ylim([-0.007,0.022])
    elif factor == 'F3':
        #ax.set_ylim([np.min(df_NN[factor])-0.025,np.max(df_linear[factor])+0.15])
        ax.set_ylim([-0.0033,-0.0023])
    else:
        
        ax.set_ylim([np.min(df_NN[factor])-0.025,np.max(df_linear[factor])+0.15])
    ax.set_xticks(np.arange(0,120,12), minor=False)
    ax.set_xticklabels(dates_to_plot[np.arange(n-120,n,12)])#, fontdict=fontdict) #, rotation=70)
    ax.tick_params(axis='x', rotation=50)
    ax.axvline(x=90, linestyle='--', color='black')
    ax.legend(loc='upper left')#, bbox_to_anchor=(1, 0.5))

    name_png = "../figure/png_low/factor_tilts_hi/%s.png" % ('Factor_' + str(names_to_save[factor]))
    fig.savefig(name_png, format='png', dpi=100, bbox_inches = "tight")
    
    name_png = "../figure/eps_low/factor_tilts_hi/%s.eps" % ('Factor_' + str(names_to_save[factor]))
    fig.savefig(name_png, format='eps', dpi=100, bbox_inches = "tight")
    
    name_pickle = "../data/figure_data/factor_analysis/%s.fig.pickle" % ('Factor_' + str(names_to_save[factor]))
    pickle.dump(fig, open(name_pickle, 'wb')) # This is for Python 3 - py2 may need `file` instead of `open`
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
list_mean = lambda x : np.mean(x)
returns_50 = np.array(list(map(list_mean, y_hat_PLS_NN[50])))
returns_80 = np.array(list(map(list_mean, y_hat_PLS_NN[80])))
returns_95 = np.array(list(map(list_mean, y_hat_PLS_NN[95])))
returns_NN = np.array(list(map(list_mean, y_hat_NN)))
returns_OLS = np.array(list(map(list_mean, y_hat_linear)))

plt.figure(num=None, figsize=(8, 6), facecolor='w', edgecolor='k')
plt.plot(np.cumsum(returns_50), label="DPLS 50%")
plt.plot(np.cumsum(returns_80), label="DPLS 80%")
plt.plot(np.cumsum(returns_95), label="DPLS 95%")
plt.plot(np.cumsum(returns_NN), label="NN")
plt.plot(np.cumsum(returns_OLS), label="OLS")
ax = plt.axes()
ax.set_facecolor("white")
plt.xticks(np.arange(0,len(dates_to_plot)-1,20), dates_to_plot[np.arange(0,len(dates_to_plot)-1,20)], rotation=70)
plt.legend()
# Out:
# C:\Users\kemen\anaconda3\envs\MLFenv\lib\site-packages\ipykernel_launcher.py:14: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %%
len(y_hat_NN)
# Out:
# 331
